# %%
import itertools
import pandas as pd
import matplotlib.pyplot as plt

# %%
matches_data = [
    {
        'match': 'Club Brugge vs Aston Villa',
        'home_team': 'Club Brugge', 'home_win_prob': 0.286, 'home_win_odds': 3.50, 'home_xg': 1.2,
        'draw_prob': 0.294, 'draw_odds': 3.40,
        'away_team': 'Aston Villa', 'away_win_prob': 0.500, 'away_win_odds': 2.00, 'away_xg': 1.8,
    },
    {
        'match': 'Shakhtar Donetsk vs Young Boys',
        'home_team': 'Shakhtar Donetsk', 'home_win_prob': 0.476, 'home_win_odds': 2.10, 'home_xg': 1.5,
        'draw_prob': 0.303, 'draw_odds': 3.30,
        'away_team': 'Young Boys', 'away_win_prob': 0.278, 'away_win_odds': 3.60, 'away_xg': 1.1,
    },
    {
        'match': 'Bayern Munich vs Benfica',
        'home_team': 'Bayern Munich', 'home_win_prob': 0.714, 'home_win_odds': 1.40, 'home_xg': 2.3,
        'draw_prob': 0.211, 'draw_odds': 4.75,
        'away_team': 'Benfica', 'away_win_prob': 0.133, 'away_win_odds': 7.50, 'away_xg': 0.8,
    },
    {
        'match': 'Crvena Zvezda vs Barcelona',
        'home_team': 'Crvena Zvezda', 'home_win_prob': 0.167, 'home_win_odds': 6.00, 'home_xg': 0.9,
        'draw_prob': 0.250, 'draw_odds': 4.00,
        'away_team': 'Barcelona', 'away_win_prob': 0.667, 'away_win_odds': 1.50, 'away_xg': 2.1,
    },
    {
        'match': 'Feyenoord vs FC Salzburg',
        'home_team': 'Feyenoord', 'home_win_prob': 0.444, 'home_win_odds': 2.25, 'home_xg': 1.6,
        'draw_prob': 0.286, 'draw_odds': 3.50,
        'away_team': 'FC Salzburg', 'away_win_prob': 0.323, 'away_win_odds': 3.10, 'away_xg': 1.3,
    },
    {
        'match': 'Inter Milan vs Arsenal',
        'home_team': 'Inter Milan', 'home_win_prob': 0.400, 'home_win_odds': 2.50, 'home_xg': 1.4,
        'draw_prob': 0.303, 'draw_odds': 3.30,
        'away_team': 'Arsenal', 'away_win_prob': 0.357, 'away_win_odds': 2.80, 'away_xg': 1.2,
    },
    {
        'match': 'PSG vs Atletico Madrid',
        'home_team': 'PSG', 'home_win_prob': 0.556, 'home_win_odds': 1.80, 'home_xg': 1.7,
        'draw_prob': 0.278, 'draw_odds': 3.60,
        'away_team': 'Atletico Madrid', 'away_win_prob': 0.222, 'away_win_odds': 4.50, 'away_xg': 0.9,
    },
    {
        'match': 'Sparta Prague vs Brest',
        'home_team': 'Sparta Prague', 'home_win_prob': 0.625, 'home_win_odds': 1.60, 'home_xg': 1.8,
        'draw_prob': 0.250, 'draw_odds': 4.00,
        'away_team': 'Brest', 'away_win_prob': 0.182, 'away_win_odds': 5.50, 'away_xg': 0.7,
    },
]

# %%
# Step 2: Generate all possible combinations of outcomes (win, draw, loss)
outcomes = ['win', 'draw', 'loss']
combinations = list(itertools.product(outcomes, repeat=len(matches)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Step 2: Generate all possible combinations of outcomes (win, draw, loss)
#       2 outcomes = ['win', 'draw', 'loss']
# ----> 3 combinations = list(itertools.product(outcomes, repeat=len(matches)))
#
# NameError: name 'itertools' is not defined

# %%
# Step 3: Calculate total probability, total odds, and expected value for each combination
results = []
for combo in combinations:
    total_prob = 1.0
    total_odds = 1.0
    match_labels = []
    
    for i, outcome in enumerate(combo):
        match = matches[i]
        total_prob *= match[outcome]
        total_odds *= match[f'{outcome}_odds']
        match_labels.append(f"{match['team']} ({outcome})")
    
    # Calculate the expected value for the combination
    expected_value = (total_prob * total_odds) - (1 - total_prob)
    
    # Append the results with match labels
    results.append((*match_labels, total_prob, total_odds, expected_value))

# Convert results to a DataFrame for easier handling and viewing
columns = [f'Match {i+1}' for i in range(len(matches))] + ['Total Probability', 'Total Odds', 'Expected Value']
df_results_results = pd.DataFrame(results, columns=columns)

# Display the results
df_results_results.head()
# Out:
#                        Match 1                                Match 2  \
# 0  Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 1  Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2  Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 3  Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4  Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
#
#                            Match 3                            Match 4  \
# 0  FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 1  FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 2  FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 3  FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 4  FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
#
#                                Match 5                            Match 6  \
# 0  Örgryte IS vs Landskrona BoIS (win)  FC Fredericia vs Aalborg BK (win)
# 1  Örgryte IS vs Landskrona BoIS (win)  FC Fredericia vs Aalborg BK (win)
# 2  Örgryte IS vs Landskrona BoIS (win)  FC Fredericia vs Aalborg BK (win)
# 3  Örgryte IS vs Landskrona BoIS (win)  FC Fredericia vs Aalborg BK (win)
# 4  Örgryte IS vs Landskrona BoIS (win)  FC Fredericia vs Aalborg BK (win)
#
#                                 Match 7                          Match 8  \
# 0   CD Leganés vs Athletic Bilbao (win)   Crvena Zvezda vs Benfica (win)
# 1   CD Leganés vs Athletic Bilbao (win)  Crvena Zvezda vs Benfica (draw)
# 2   CD Leganés vs Athletic Bilbao (win)  Crvena Zvezda vs Benfica (loss)
# 3  CD Leganés vs Athletic Bilbao (draw)   Crvena Zvezda vs Benfica (win)
# 4  CD Leganés vs Athletic Bilbao (draw)  Crvena Zvezda vs Benfica (draw)
#
#    Total Probability   Total Odds  Expected Value
# 0           0.000191  3047.496952       -0.418769
# 1           0.000191  2742.747257       -0.476873
# 2           0.000381  1500.892249       -0.427294
# 3           0.000243  2318.747681       -0.437090
# 4           0.000243  2086.872913       -0.493357

# %%
# Assuming 'combinations' is a list of tuples where each tuple represents a combination of outcomes (e.g., ('win', 'draw', 'loss'))
from itertools import product

# Generate all possible combinations of 'win', 'draw', 'loss' for each match
outcome_types = ['win', 'draw', 'loss']
combinations = list(product(outcome_types, repeat=len(matches)))

# Step 3: Calculate total probability, total odds, and expected value for each combination
results = []
for combo in combinations:
    total_prob = 1.0
    total_odds = 1.0
    match_labels = []
    
    for i, outcome in enumerate(combo):
        match = matches[i]
        total_prob *= match[outcome]
        total_odds *= match[f'{outcome}_odds']
        match_labels.append(f"{match['team']} ({outcome})")
    
    # Calculate the expected value for the combination
    expected_value = (total_prob * total_odds) - (1 - total_prob)
    
    # Append the results with match labels
    results.append((*match_labels, total_prob, total_odds, expected_value))

# Convert results to a DataFrame for easier handling and viewing
columns = [f'Match {i+1}' for i in range(len(matches))] + ['Total Probability', 'Total Odds', 'Expected Value']
df_results_results = pd.DataFrame(results, columns=columns)

# Display the results
df_results_results.head()
# Out:
#                        Match 1                                Match 2  \
# 0  Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 1  Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2  Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 3  Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4  Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
#
#                            Match 3                            Match 4  \
# 0  FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 1  FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 2  FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 3  FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 4  FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
#
#                                Match 5                            Match 6  \
# 0  Örgryte IS vs Landskrona BoIS (win)  FC Fredericia vs Aalborg BK (win)
# 1  Örgryte IS vs Landskrona BoIS (win)  FC Fredericia vs Aalborg BK (win)
# 2  Örgryte IS vs Landskrona BoIS (win)  FC Fredericia vs Aalborg BK (win)
# 3  Örgryte IS vs Landskrona BoIS (win)  FC Fredericia vs Aalborg BK (win)
# 4  Örgryte IS vs Landskrona BoIS (win)  FC Fredericia vs Aalborg BK (win)
#
#                                 Match 7                          Match 8  \
# 0   CD Leganés vs Athletic Bilbao (win)   Crvena Zvezda vs Benfica (win)
# 1   CD Leganés vs Athletic Bilbao (win)  Crvena Zvezda vs Benfica (draw)
# 2   CD Leganés vs Athletic Bilbao (win)  Crvena Zvezda vs Benfica (loss)
# 3  CD Leganés vs Athletic Bilbao (draw)   Crvena Zvezda vs Benfica (win)
# 4  CD Leganés vs Athletic Bilbao (draw)  Crvena Zvezda vs Benfica (draw)
#
#    Total Probability   Total Odds  Expected Value
# 0           0.000191  3047.496952       -0.418769
# 1           0.000191  2742.747257       -0.476873
# 2           0.000381  1500.892249       -0.427294
# 3           0.000243  2318.747681       -0.437090
# 4           0.000243  2086.872913       -0.493357

# %%
len(df_results_results)
# Out:
# 6561

# %%
# Step 5: Filter combinations with a positive expected value
positive_ev_bets = df_results_results[df_results_results['Expected Value'] > df_results_results['Expected Value'].quantile(0.60) ]
positive_ev_bets
# Out:
#                            Match 1                                 Match 2  \
# 6      Al Orubah vs Al-Fateh (win)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 8      Al Orubah vs Al-Fateh (win)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 18     Al Orubah vs Al-Fateh (win)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 20     Al Orubah vs Al-Fateh (win)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 21     Al Orubah vs Al-Fateh (win)   Al-Wehda FC Mecca vs Al-Kholood (win)
# ...                            ...                                     ...
# 6555  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
# 6557  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
# 6558  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
# 6559  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
# 6560  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
#
#                                Match 3                             Match 4  \
# 6      FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 8      FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 18     FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 20     FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 21     FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# ...                                ...                                 ...
# 6555  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 6557  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 6558  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 6559  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 6560  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
#
#                                    Match 5  \
# 6      Örgryte IS vs Landskrona BoIS (win)
# 8      Örgryte IS vs Landskrona BoIS (win)
# 18     Örgryte IS vs Landskrona BoIS (win)
# 20     Örgryte IS vs Landskrona BoIS (win)
# 21     Örgryte IS vs Landskrona BoIS (win)
# ...                                    ...
# 6555  Örgryte IS vs Landskrona BoIS (loss)
# 6557  Örgryte IS vs Landskrona BoIS (loss)
# 6558  Örgryte IS vs Landskrona BoIS (loss)
# 6559  Örgryte IS vs Landskrona BoIS (loss)
# 6560  Örgryte IS vs Landskrona BoIS (loss)
#
#                                  Match 6  \
# 6      FC Fredericia vs Aalborg BK (win)
# 8      FC Fredericia vs Aalborg BK (win)
# 18    FC Fredericia vs Aalborg BK (loss)
# 20    FC Fredericia vs Aalborg BK (loss)
# 21    FC Fredericia vs Aalborg BK (loss)
# ...                                  ...
# 6555  FC Fredericia vs Aalborg BK (loss)
# 6557  FC Fredericia vs Aalborg BK (loss)
# 6558  FC Fredericia vs Aalborg BK (loss)
# 6559  FC Fredericia vs Aalborg BK (loss)
# 6560  FC Fredericia vs Aalborg BK (loss)
#
#                                    Match 7                          Match 8  \
# 6     CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 8     CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 18     CD Leganés vs Athletic Bilbao (win)   Crvena Zvezda vs Benfica (win)
# 20     CD Leganés vs Athletic Bilbao (win)  Crvena Zvezda vs Benfica (loss)
# 21    CD Leganés vs Athletic Bilbao (draw)   Crvena Zvezda vs Benfica (win)
# ...                                    ...                              ...
# 6555  CD Leganés vs Athletic Bilbao (draw)   Crvena Zvezda vs Benfica (win)
# 6557  CD Leganés vs Athletic Bilbao (draw)  Crvena Zvezda vs Benfica (loss)
# 6558  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 6559  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (draw)
# 6560  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
#
#       Total Probability   Total Odds  Expected Value
# 6              0.000433  1391.248609       -0.396709
# 8              0.000867   685.189940       -0.405319
# 18             0.000320  1939.316242       -0.379024
# 20             0.000640   955.113249       -0.388014
# 21             0.000407  1475.566706       -0.398562
# ...                 ...          ...             ...
# 6555           0.000064  9600.158400       -0.382955
# 6557           0.000129  4728.078012       -0.392145
# 6558           0.000115  5760.095040       -0.338834
# 6559           0.000115  5184.085536       -0.404939
# 6560           0.000230  2836.846807       -0.348635
#
# [2624 rows x 11 columns]

# %%
# Step 6: Sort by Expected Value, then by Total Probability, then by Total Odds
sorted_bets = positive_ev_bets.sort_values(by=['Total Probability'], ascending=[False])

# %%
sorted_bets.head(25)
# Out:
#                            Match 1                                Match 2  \
# 4400  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2213  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2699  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4886  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2456  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4643  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 26     Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 512    Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2240  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4427  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 269    Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2267  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4454  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4382  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2195  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4562  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2375  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2210  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4397  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2726  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4913  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4940  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2753  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4391  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2204  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
#
#                                Match 3                             Match 4  \
# 4400   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 2213   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 2699  FC Lahti vs IFK Mariehamn (loss)   BK Häcken vs Djurgårdens IF (win)
# 4886  FC Lahti vs IFK Mariehamn (loss)   BK Häcken vs Djurgårdens IF (win)
# 2456  FC Lahti vs IFK Mariehamn (draw)   BK Häcken vs Djurgårdens IF (win)
# 4643  FC Lahti vs IFK Mariehamn (draw)   BK Häcken vs Djurgårdens IF (win)
# 26     FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 512   FC Lahti vs IFK Mariehamn (loss)   BK Häcken vs Djurgårdens IF (win)
# 2240   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 4427   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 269   FC Lahti vs IFK Mariehamn (draw)   BK Häcken vs Djurgårdens IF (win)
# 2267   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 4454   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 4382   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 2195   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 4562   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (loss)
# 2375   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (loss)
# 2210   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 4397   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 2726  FC Lahti vs IFK Mariehamn (loss)   BK Häcken vs Djurgårdens IF (win)
# 4913  FC Lahti vs IFK Mariehamn (loss)   BK Häcken vs Djurgårdens IF (win)
# 4940  FC Lahti vs IFK Mariehamn (loss)   BK Häcken vs Djurgårdens IF (win)
# 2753  FC Lahti vs IFK Mariehamn (loss)   BK Häcken vs Djurgårdens IF (win)
# 4391   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 2204   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
#
#                                    Match 5  \
# 4400   Örgryte IS vs Landskrona BoIS (win)
# 2213   Örgryte IS vs Landskrona BoIS (win)
# 2699   Örgryte IS vs Landskrona BoIS (win)
# 4886   Örgryte IS vs Landskrona BoIS (win)
# 2456   Örgryte IS vs Landskrona BoIS (win)
# 4643   Örgryte IS vs Landskrona BoIS (win)
# 26     Örgryte IS vs Landskrona BoIS (win)
# 512    Örgryte IS vs Landskrona BoIS (win)
# 2240  Örgryte IS vs Landskrona BoIS (draw)
# 4427  Örgryte IS vs Landskrona BoIS (draw)
# 269    Örgryte IS vs Landskrona BoIS (win)
# 2267  Örgryte IS vs Landskrona BoIS (loss)
# 4454  Örgryte IS vs Landskrona BoIS (loss)
# 4382   Örgryte IS vs Landskrona BoIS (win)
# 2195   Örgryte IS vs Landskrona BoIS (win)
# 4562   Örgryte IS vs Landskrona BoIS (win)
# 2375   Örgryte IS vs Landskrona BoIS (win)
# 2210   Örgryte IS vs Landskrona BoIS (win)
# 4397   Örgryte IS vs Landskrona BoIS (win)
# 2726  Örgryte IS vs Landskrona BoIS (draw)
# 4913  Örgryte IS vs Landskrona BoIS (draw)
# 4940  Örgryte IS vs Landskrona BoIS (loss)
# 2753  Örgryte IS vs Landskrona BoIS (loss)
# 4391   Örgryte IS vs Landskrona BoIS (win)
# 2204   Örgryte IS vs Landskrona BoIS (win)
#
#                                  Match 6  \
# 4400  FC Fredericia vs Aalborg BK (loss)
# 2213  FC Fredericia vs Aalborg BK (loss)
# 2699  FC Fredericia vs Aalborg BK (loss)
# 4886  FC Fredericia vs Aalborg BK (loss)
# 2456  FC Fredericia vs Aalborg BK (loss)
# 4643  FC Fredericia vs Aalborg BK (loss)
# 26    FC Fredericia vs Aalborg BK (loss)
# 512   FC Fredericia vs Aalborg BK (loss)
# 2240  FC Fredericia vs Aalborg BK (loss)
# 4427  FC Fredericia vs Aalborg BK (loss)
# 269   FC Fredericia vs Aalborg BK (loss)
# 2267  FC Fredericia vs Aalborg BK (loss)
# 4454  FC Fredericia vs Aalborg BK (loss)
# 4382   FC Fredericia vs Aalborg BK (win)
# 2195   FC Fredericia vs Aalborg BK (win)
# 4562  FC Fredericia vs Aalborg BK (loss)
# 2375  FC Fredericia vs Aalborg BK (loss)
# 2210  FC Fredericia vs Aalborg BK (loss)
# 4397  FC Fredericia vs Aalborg BK (loss)
# 2726  FC Fredericia vs Aalborg BK (loss)
# 4913  FC Fredericia vs Aalborg BK (loss)
# 4940  FC Fredericia vs Aalborg BK (loss)
# 2753  FC Fredericia vs Aalborg BK (loss)
# 4391  FC Fredericia vs Aalborg BK (draw)
# 2204  FC Fredericia vs Aalborg BK (draw)
#
#                                    Match 7                          Match 8  \
# 4400  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2213  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2699  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4886  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2456  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4643  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 26    CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 512   CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2240  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4427  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 269   CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2267  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4454  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4382  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2195  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4562  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2375  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2210  CD Leganés vs Athletic Bilbao (draw)  Crvena Zvezda vs Benfica (loss)
# 4397  CD Leganés vs Athletic Bilbao (draw)  Crvena Zvezda vs Benfica (loss)
# 2726  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4913  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4940  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2753  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4391  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2204  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
#
#       Total Probability   Total Odds  Expected Value
# 4400           0.001940   391.604267       -0.238494
# 2213           0.001940   559.434668        0.087035
# 2699           0.001730   626.566828        0.085652
# 4886           0.001730   438.596780       -0.239524
# 2456           0.001573   693.698988        0.092533
# 4643           0.001573   485.589292       -0.234755
# 26             0.001455   436.029962       -0.364243
# 512            0.001297   488.353557       -0.365086
# 2240           0.001207   852.471875        0.030038
# 4427           0.001207   596.730312       -0.278611
# 269            0.001180   540.677153       -0.361090
# 2267           0.001164   932.391113        0.086259
# 4454           0.001164   652.673779       -0.239269
# 4382           0.001156   615.378135       -0.287761
# 2195           0.001156   879.111621        0.016990
# 4562           0.001103   702.879454       -0.223673
# 2375           0.001103  1004.113506        0.108566
# 2210           0.001086   932.391113        0.013842
# 4397           0.001086   652.673779       -0.289985
# 2726           0.001076   954.768500        0.028795
# 4913           0.001076   668.337950       -0.279520
# 4940           0.001038   730.994633       -0.240216
# 2753           0.001038  1044.278047        0.084960
# 4391           0.001032   578.082490       -0.402551
# 2204           0.001032   825.832129       -0.146943

# %%
# Step 6: Sort by Expected Value, then by Total Probability, then by Total Odds
sorted_bets = positive_ev_bets.sort_values(by=['Expected Value', 'Total Probability', 'Total Odds'], ascending=[False, False, False])
sorted_bets
# Out:
#                            Match 1                                 Match 2  \
# 2616  Al Orubah vs Al-Fateh (draw)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 2670  Al Orubah vs Al-Fateh (draw)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 2373  Al Orubah vs Al-Fateh (draw)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 2427  Al Orubah vs Al-Fateh (draw)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 2859  Al Orubah vs Al-Fateh (draw)   Al-Wehda FC Mecca vs Al-Kholood (win)
# ...                            ...                                     ...
# 5857  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
# 3045  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (draw)
# 5879  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
# 4383  Al Orubah vs Al-Fateh (loss)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 5911  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
#
#                                Match 3                             Match 4  \
# 2616  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
# 2670  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
# 2373   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (loss)
# 2427   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (loss)
# 2859  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# ...                                ...                                 ...
# 5857   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 3045   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (draw)
# 5879   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 4383   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 5911   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
#
#                                    Match 5  \
# 2616   Örgryte IS vs Landskrona BoIS (win)
# 2670  Örgryte IS vs Landskrona BoIS (loss)
# 2373   Örgryte IS vs Landskrona BoIS (win)
# 2427  Örgryte IS vs Landskrona BoIS (loss)
# 2859   Örgryte IS vs Landskrona BoIS (win)
# ...                                    ...
# 5857   Örgryte IS vs Landskrona BoIS (win)
# 3045  Örgryte IS vs Landskrona BoIS (draw)
# 5879  Örgryte IS vs Landskrona BoIS (draw)
# 4383   Örgryte IS vs Landskrona BoIS (win)
# 5911  Örgryte IS vs Landskrona BoIS (loss)
#
#                                  Match 6  \
# 2616  FC Fredericia vs Aalborg BK (loss)
# 2670  FC Fredericia vs Aalborg BK (loss)
# 2373  FC Fredericia vs Aalborg BK (loss)
# 2427  FC Fredericia vs Aalborg BK (loss)
# 2859  FC Fredericia vs Aalborg BK (loss)
# ...                                  ...
# 5857  FC Fredericia vs Aalborg BK (loss)
# 3045  FC Fredericia vs Aalborg BK (loss)
# 5879  FC Fredericia vs Aalborg BK (loss)
# 4383  FC Fredericia vs Aalborg BK (draw)
# 5911  FC Fredericia vs Aalborg BK (loss)
#
#                                    Match 7                          Match 8  \
# 2616  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2670  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2373  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2427  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2859  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# ...                                    ...                              ...
# 5857  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (draw)
# 3045  CD Leganés vs Athletic Bilbao (draw)   Crvena Zvezda vs Benfica (win)
# 5879   CD Leganés vs Athletic Bilbao (win)  Crvena Zvezda vs Benfica (loss)
# 4383   CD Leganés vs Athletic Bilbao (win)   Crvena Zvezda vs Benfica (win)
# 5911  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (draw)
#
#       Total Probability   Total Odds  Expected Value
# 2616           0.000447  2528.123346        0.130852
# 2670           0.000268  4213.538910        0.130674
# 2373           0.000551  2038.809150        0.124879
# 2427           0.000331  3398.015250        0.124659
# 2859           0.000492  2283.466248        0.123604
# ...                 ...          ...             ...
# 5857           0.000377  1547.290836       -0.416062
# 3045           0.000061  9516.192000       -0.416102
# 5879           0.000207  2826.213062       -0.416151
# 4383           0.000227  2571.118641       -0.416186
# 5911           0.000226  2578.818060       -0.416213
#
# [2624 rows x 11 columns]

# %%
# Step 7: Select the top 10 bets (adjust the number based on your preference)
top_bets = sorted_bets.head(10)
top_bets
# Out:
#                            Match 1                                Match 2  \
# 2616  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2670  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2373  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2427  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2859  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2913  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2618  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2672  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2375  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2454  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
#
#                                Match 3                             Match 4  \
# 2616  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
# 2670  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
# 2373   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (loss)
# 2427   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (loss)
# 2859  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 2913  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 2618  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
# 2672  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
# 2375   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (loss)
# 2454  FC Lahti vs IFK Mariehamn (draw)   BK Häcken vs Djurgårdens IF (win)
#
#                                    Match 5  \
# 2616   Örgryte IS vs Landskrona BoIS (win)
# 2670  Örgryte IS vs Landskrona BoIS (loss)
# 2373   Örgryte IS vs Landskrona BoIS (win)
# 2427  Örgryte IS vs Landskrona BoIS (loss)
# 2859   Örgryte IS vs Landskrona BoIS (win)
# 2913  Örgryte IS vs Landskrona BoIS (loss)
# 2618   Örgryte IS vs Landskrona BoIS (win)
# 2672  Örgryte IS vs Landskrona BoIS (loss)
# 2375   Örgryte IS vs Landskrona BoIS (win)
# 2454   Örgryte IS vs Landskrona BoIS (win)
#
#                                  Match 6  \
# 2616  FC Fredericia vs Aalborg BK (loss)
# 2670  FC Fredericia vs Aalborg BK (loss)
# 2373  FC Fredericia vs Aalborg BK (loss)
# 2427  FC Fredericia vs Aalborg BK (loss)
# 2859  FC Fredericia vs Aalborg BK (loss)
# 2913  FC Fredericia vs Aalborg BK (loss)
# 2618  FC Fredericia vs Aalborg BK (loss)
# 2672  FC Fredericia vs Aalborg BK (loss)
# 2375  FC Fredericia vs Aalborg BK (loss)
# 2454  FC Fredericia vs Aalborg BK (loss)
#
#                                    Match 7                          Match 8  \
# 2616  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2670  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2373  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2427  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2859  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2913  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2618  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2672  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2375  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2454  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
#
#       Total Probability   Total Odds  Expected Value
# 2616           0.000447  2528.123346        0.130852
# 2670           0.000268  4213.538910        0.130674
# 2373           0.000551  2038.809150        0.124879
# 2427           0.000331  3398.015250        0.124659
# 2859           0.000492  2283.466248        0.123604
# 2913           0.000295  3805.777080        0.123407
# 2618           0.000894  1245.100748        0.114343
# 2672           0.000537  2075.167913        0.113986
# 2375           0.001103  1004.113506        0.108566
# 2454           0.000786  1408.525864        0.108361

# %%
# Step 8: Visualize the relationship between expected value, probability, and odds
plt.figure(figsize=(10, 6))
plt.scatter(sorted_bets['Total Probability'], sorted_bets['Expected Value'], c=sorted_bets['Total Odds'], cmap='viridis', s=50)
plt.colorbar(label='Total Odds')
plt.xlabel('Total Probability')
plt.ylabel('Expected Value')
plt.title('Expected Value vs Probability (Color indicates Total Odds)')
plt.show()

# %%
import numpy as np

# Define thresholds for high expected value, reasonable probability, and balanced odds
expected_value_threshold = df_results_results['Expected Value'].quantile(0.85)  # Top 25% for expected value
probability_threshold_min = df_results_results['Total Probability'].quantile(0.45)  # Above the 25th percentile for probability
probability_threshold_max = df_results_results['Total Probability'].quantile(0.90)  # Below the 75th percentile for probability
odds_threshold_min = df_results_results['Total Odds'].quantile(0.25)  # Avoid very high odds, which might be too risky

# Apply filtering based on the criteria
filtered_bets = df_results_results[
    (df_results_results['Expected Value'] >= expected_value_threshold) &
    (df_results_results['Total Probability'] >= probability_threshold_min) &
    (df_results_results['Total Probability'] <= probability_threshold_max) &
    (df_results_results['Total Odds'] >= odds_threshold_min)
]

# Sort by Expected Value in descending order to get the best bets at the top
best_bets = filtered_bets.sort_values(by='Expected Value', ascending=False)

# Display the top 10 best bets based on these criteria
top_bets_based_on_criteria = best_bets.head(10)
print(top_bets_based_on_criteria)

# Optionally, you could visualize these on the graph
plt.figure(figsize=(10, 6))
plt.scatter(df_results_results['Total Probability'], df_results_results['Expected Value'], c=df_results_results['Total Odds'], cmap='viridis', s=50)
plt.colorbar(label='Total Odds')
plt.xlabel('Total Probability')
plt.ylabel('Expected Value')
plt.title('Expected Value vs Probability (Best Bets Highlighted)')
plt.scatter(
    top_bets_based_on_criteria['Total Probability'],
    top_bets_based_on_criteria['Expected Value'],
    color='red', s=100, label='Best Bets'
)
plt.scatter(
    top_bets['Total Probability'],
    top_bets['Expected Value'],
    color='pink', s=100, label='Top Bets'
)
plt.legend()
plt.show()
# Out:
#                            Match 1                                Match 2  \
# 2670  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2913  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2610  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2664  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2367  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2421  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2853  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2907  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2666  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2643  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
#
#                                Match 3                             Match 4  \
# 2670  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
# 2913  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 2610  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
# 2664  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
# 2367   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (loss)
# 2421   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (loss)
# 2853  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 2907  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 2666  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
# 2643  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
#
#                                    Match 5  \
# 2670  Örgryte IS vs Landskrona BoIS (loss)
# 2913  Örgryte IS vs Landskrona BoIS (loss)
# 2610   Örgryte IS vs Landskrona BoIS (win)
# 2664  Örgryte IS vs Landskrona BoIS (loss)
# 2367   Örgryte IS vs Landskrona BoIS (win)
# 2421  Örgryte IS vs Landskrona BoIS (loss)
# 2853   Örgryte IS vs Landskrona BoIS (win)
# 2907  Örgryte IS vs Landskrona BoIS (loss)
# 2666  Örgryte IS vs Landskrona BoIS (loss)
# 2643  Örgryte IS vs Landskrona BoIS (draw)
#
#                                  Match 6  \
# 2670  FC Fredericia vs Aalborg BK (loss)
# 2913  FC Fredericia vs Aalborg BK (loss)
# 2610  FC Fredericia vs Aalborg BK (loss)
# 2664  FC Fredericia vs Aalborg BK (loss)
# 2367  FC Fredericia vs Aalborg BK (loss)
# 2421  FC Fredericia vs Aalborg BK (loss)
# 2853  FC Fredericia vs Aalborg BK (loss)
# 2907  FC Fredericia vs Aalborg BK (loss)
# 2666  FC Fredericia vs Aalborg BK (loss)
# 2643  FC Fredericia vs Aalborg BK (loss)
#
#                                    Match 7                          Match 8  \
# 2670  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2913  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2610   CD Leganés vs Athletic Bilbao (win)   Crvena Zvezda vs Benfica (win)
# 2664   CD Leganés vs Athletic Bilbao (win)   Crvena Zvezda vs Benfica (win)
# 2367   CD Leganés vs Athletic Bilbao (win)   Crvena Zvezda vs Benfica (win)
# 2421   CD Leganés vs Athletic Bilbao (win)   Crvena Zvezda vs Benfica (win)
# 2853   CD Leganés vs Athletic Bilbao (win)   Crvena Zvezda vs Benfica (win)
# 2907   CD Leganés vs Athletic Bilbao (win)   Crvena Zvezda vs Benfica (win)
# 2666   CD Leganés vs Athletic Bilbao (win)  Crvena Zvezda vs Benfica (loss)
# 2643  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
#
#       Total Probability   Total Odds  Expected Value
# 2670           0.000268  4213.538910        0.130674
# 2913           0.000295  3805.777080        0.123407
# 2610           0.000197  5537.793996        0.089692
# 2664           0.000118  9229.656660        0.089613
# 2367           0.000243  4465.962900        0.083880
# 2421           0.000146  7443.271500        0.083783
# 2853           0.000216  5001.878448        0.082683
# 2907           0.000130  8336.464080        0.082596
# 2666           0.000236  4545.605905        0.073389
# 2643           0.000278  3852.378432        0.072070

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Assuming df_results_results is your DataFrame containing all combinations data

# Define the Total Probability and Expected Value for the winning bet
winning_total_probability = 0.002314
winning_expected_value = -0.172201

# Add a column to identify if a row matches the winning bet based on probability and expected value
df_results_results['is_winning_bet'] = (df_results_results['Total Probability'] == winning_total_probability) & \
                                    (df_results_results['Expected Value'] == winning_expected_value)

# Define the x and y variables for regression
x = df_results_results['Total Probability'].values
y = df_results_results['Expected Value'].values

# Perform linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

# Calculate the regression line
best_bet_line = slope * x + intercept

# Plot the data
plt.figure(figsize=(10, 6))

# Plot all bets with default color
plt.scatter(x[~df_results_results['is_winning_bet']], y[~df_results_results['is_winning_bet']], 
            c='purple', alpha=0.5, label="All Bets")

# Highlight the winning bet in blue
plt.scatter(x[df_results_results['is_winning_bet']], y[df_results_results['is_winning_bet']], 
            c='yellow', s=1000, label="Winning Bet", edgecolor='black', zorder=5)

# Plot the regression line
plt.plot(x, best_bet_line, color='red', label=f"Line of Best Bet (R²={r_value:.2f})")

# Set plot limits to ensure negative values are shown
plt.ylim(min(y) * 1.1, max(y) * 1.1)

# Set plot labels and title
plt.xlabel('Total Probability')
plt.ylabel('Expected Value')
plt.title('Expected Value vs Probability with Winning Bet Highlighted')
plt.legend()
plt.show()

# %%
df_results_results
# Out:
#                            Match 1                                 Match 2  \
# 0      Al Orubah vs Al-Fateh (win)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 1      Al Orubah vs Al-Fateh (win)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 2      Al Orubah vs Al-Fateh (win)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 3      Al Orubah vs Al-Fateh (win)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 4      Al Orubah vs Al-Fateh (win)   Al-Wehda FC Mecca vs Al-Kholood (win)
# ...                            ...                                     ...
# 6556  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
# 6557  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
# 6558  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
# 6559  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
# 6560  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
#
#                                Match 3                             Match 4  \
# 0      FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 1      FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 2      FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 3      FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 4      FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# ...                                ...                                 ...
# 6556  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 6557  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 6558  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 6559  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 6560  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
#
#                                    Match 5  \
# 0      Örgryte IS vs Landskrona BoIS (win)
# 1      Örgryte IS vs Landskrona BoIS (win)
# 2      Örgryte IS vs Landskrona BoIS (win)
# 3      Örgryte IS vs Landskrona BoIS (win)
# 4      Örgryte IS vs Landskrona BoIS (win)
# ...                                    ...
# 6556  Örgryte IS vs Landskrona BoIS (loss)
# 6557  Örgryte IS vs Landskrona BoIS (loss)
# 6558  Örgryte IS vs Landskrona BoIS (loss)
# 6559  Örgryte IS vs Landskrona BoIS (loss)
# 6560  Örgryte IS vs Landskrona BoIS (loss)
#
#                                  Match 6  \
# 0      FC Fredericia vs Aalborg BK (win)
# 1      FC Fredericia vs Aalborg BK (win)
# 2      FC Fredericia vs Aalborg BK (win)
# 3      FC Fredericia vs Aalborg BK (win)
# 4      FC Fredericia vs Aalborg BK (win)
# ...                                  ...
# 6556  FC Fredericia vs Aalborg BK (loss)
# 6557  FC Fredericia vs Aalborg BK (loss)
# 6558  FC Fredericia vs Aalborg BK (loss)
# 6559  FC Fredericia vs Aalborg BK (loss)
# 6560  FC Fredericia vs Aalborg BK (loss)
#
#                                    Match 7                          Match 8  \
# 0      CD Leganés vs Athletic Bilbao (win)   Crvena Zvezda vs Benfica (win)
# 1      CD Leganés vs Athletic Bilbao (win)  Crvena Zvezda vs Benfica (draw)
# 2      CD Leganés vs Athletic Bilbao (win)  Crvena Zvezda vs Benfica (loss)
# 3     CD Leganés vs Athletic Bilbao (draw)   Crvena Zvezda vs Benfica (win)
# 4     CD Leganés vs Athletic Bilbao (draw)  Crvena Zvezda vs Benfica (draw)
# ...                                    ...                              ...
# 6556  CD Leganés vs Athletic Bilbao (draw)  Crvena Zvezda vs Benfica (draw)
# 6557  CD Leganés vs Athletic Bilbao (draw)  Crvena Zvezda vs Benfica (loss)
# 6558  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 6559  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (draw)
# 6560  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
#
#       Total Probability   Total Odds  Expected Value  is_winning_bet
# 0              0.000191  3047.496952       -0.418769           False
# 1              0.000191  2742.747257       -0.476873           False
# 2              0.000381  1500.892249       -0.427294           False
# 3              0.000243  2318.747681       -0.437090           False
# 4              0.000243  2086.872913       -0.493357           False
# ...                 ...          ...             ...             ...
# 6556           0.000064  8640.142560       -0.444653           False
# 6557           0.000129  4728.078012       -0.392145           False
# 6558           0.000115  5760.095040       -0.338834           False
# 6559           0.000115  5184.085536       -0.404939           False
# 6560           0.000230  2836.846807       -0.348635           False
#
# [6561 rows x 12 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score

# Assuming 'df_results_results' is the DataFrame with your data

# Define the x and y variables
x = df_results_results['Total Probability'].values
y = df_results_results['Expected Value'].values

# 1. Gradient Boosting Regression
gb_model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
gb_model.fit(x.reshape(-1, 1), y)

# Predict using the Gradient Boosting model
x_new = np.linspace(x.min(), x.max(), 500)
y_gb = gb_model.predict(x_new.reshape(-1, 1))

# Perform cross-validation to assess the model's performance
scores = cross_val_score(gb_model, x.reshape(-1, 1), y, cv=5, scoring='neg_mean_squared_error')
print(f"Cross-validated MSE: {-scores.mean()}")

# Plot the existing scatter plot with all elements
plt.figure(figsize=(20, 16))
plt.scatter(df_results_results['Total Probability'], df_results_results['Expected Value'], c=df_results_results['Total Odds'], cmap='viridis', s=50, alpha=0.6)
plt.colorbar(label='Total Odds')
plt.xlabel('Total Probability')
plt.ylabel('Expected Value')
plt.title('Expected Value vs Probability (Winning Bet Highlighted)')

# # Highlight the winning bet
# plt.scatter(won_bet['Total Probability'], won_bet['Expected Value'], color='red', s=200, edgecolor='black', label='Won Bet')

# Plot the "Best Bets" and "Top Bets" as before
plt.scatter(top_bets_based_on_criteria['Total Probability'], top_bets_based_on_criteria['Expected Value'], 
            color='red', s=100, label='Best Bets')
plt.scatter(top_bets['Total Probability'], top_bets['Expected Value'], color='pink', s=100, label='Top Bets')

# Plot the Gradient Boosting Regression curve
plt.plot(x_new, y_gb, color='magenta', linewidth=2, label="Gradient Boosting Regression")

# Show the legend and plot
plt.legend()
plt.savefig('/Users/user/Downloads/expected_value_vs_probability_with_gradient_boosting.jpeg')
plt.show()
# Out:
# Cross-validated MSE: 0.031934141465165565

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error

# Assuming 'df_results_results' is the DataFrame with your data
# Assuming 'won_bet' is the DataFrame or Series with the winning bet data

# Define the x and y variables
x = df_results_results['Total Probability'].values
y = df_results_results['Expected Value'].values

# Assign higher weight to the winning bet (e.g., weight of 10)
weights = np.ones_like(y)
weights[df_results_results.index == top_bets.index[0]] = 10  # Increase the weight of the winning bet
weights[df_results_results.index == best_bets.index[0]] = 10
# Train Gradient Boosting Regression with weighted data
gb_model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
gb_model.fit(x.reshape(-1, 1), y, sample_weight=weights)

# Predict using the Gradient Boosting model
x_new = np.linspace(x.min(), x.max(), 500)
y_gb = gb_model.predict(x_new.reshape(-1, 1))

# Calculate the distance from the regression line for each bet
y_pred = gb_model.predict(x.reshape(-1, 1))
distances = np.abs(y - y_pred)

# Define a threshold for 'closeness' (e.g., within 0.01 units of expected value)
threshold = 0.3
close_bets = df_results_results[distances < threshold]

# Output the bets that are close to the regression line
print("Bets close to the regression line:")
print(close_bets)

# Plot the existing scatter plot with all elements
plt.figure(figsize=(20, 16))
plt.scatter(df_results_results['Total Probability'], df_results_results['Expected Value'], c=df_results_results['Total Odds'], cmap='viridis', s=50, alpha=0.6)
plt.colorbar(label='Total Odds')
plt.xlabel('Total Probability')
plt.ylabel('Expected Value')
plt.title('Expected Value vs Probability (Winning Bet Highlighted)')

# # Highlight the winning bet
# plt.scatter(won_bet['Total Probability'], won_bet['Expected Value'], color='red', s=200, edgecolor='black', label='Won Bet')

# Plot the "Best Bets" and "Top Bets" as before
plt.scatter(top_bets_based_on_criteria['Total Probability'], top_bets_based_on_criteria['Expected Value'], 
            color='red', s=100, label='Best Bets')
plt.scatter(top_bets['Total Probability'], top_bets['Expected Value'], color='pink', s=100, label='Top Bets')

# Highlight bets close to the regression line
plt.scatter(close_bets['Total Probability'], close_bets['Expected Value'], color='blue', s=100, label='Close Bets')

# Plot the Gradient Boosting Regression curve
plt.plot(x_new, y_gb, color='magenta', linewidth=2, label="Gradient Boosting Regression")

# Show the legend and plot
plt.legend()
plt.savefig('/Users/user/Downloads/expected_value_vs_probability_with_gradient_boosting_and_close_bets.jpeg')
plt.show()
# Out:
# Bets close to the regression line:
#                            Match 1                                 Match 2  \
# 0      Al Orubah vs Al-Fateh (win)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 1      Al Orubah vs Al-Fateh (win)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 2      Al Orubah vs Al-Fateh (win)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 3      Al Orubah vs Al-Fateh (win)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 4      Al Orubah vs Al-Fateh (win)   Al-Wehda FC Mecca vs Al-Kholood (win)
# ...                            ...                                     ...
# 6556  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
# 6557  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
# 6558  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
# 6559  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
# 6560  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (loss)
#
#                                Match 3                             Match 4  \
# 0      FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 1      FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 2      FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 3      FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 4      FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# ...                                ...                                 ...
# 6556  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 6557  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 6558  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 6559  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 6560  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
#
#                                    Match 5  \
# 0      Örgryte IS vs Landskrona BoIS (win)
# 1      Örgryte IS vs Landskrona BoIS (win)
# 2      Örgryte IS vs Landskrona BoIS (win)
# 3      Örgryte IS vs Landskrona BoIS (win)
# 4      Örgryte IS vs Landskrona BoIS (win)
# ...                                    ...
# 6556  Örgryte IS vs Landskrona BoIS (loss)
# 6557  Örgryte IS vs Landskrona BoIS (loss)
# 6558  Örgryte IS vs Landskrona BoIS (loss)
# 6559  Örgryte IS vs Landskrona BoIS (loss)
# 6560  Örgryte IS vs Landskrona BoIS (loss)
#
#                                  Match 6  \
# 0      FC Fredericia vs Aalborg BK (win)
# 1      FC Fredericia vs Aalborg BK (win)
# 2      FC Fredericia vs Aalborg BK (win)
# 3      FC Fredericia vs Aalborg BK (win)
# 4      FC Fredericia vs Aalborg BK (win)
# ...                                  ...
# 6556  FC Fredericia vs Aalborg BK (loss)
# 6557  FC Fredericia vs Aalborg BK (loss)
# 6558  FC Fredericia vs Aalborg BK (loss)
# 6559  FC Fredericia vs Aalborg BK (loss)
# 6560  FC Fredericia vs Aalborg BK (loss)
#
#                                    Match 7                          Match 8  \
# 0      CD Leganés vs Athletic Bilbao (win)   Crvena Zvezda vs Benfica (win)
# 1      CD Leganés vs Athletic Bilbao (win)  Crvena Zvezda vs Benfica (draw)
# 2      CD Leganés vs Athletic Bilbao (win)  Crvena Zvezda vs Benfica (loss)
# 3     CD Leganés vs Athletic Bilbao (draw)   Crvena Zvezda vs Benfica (win)
# 4     CD Leganés vs Athletic Bilbao (draw)  Crvena Zvezda vs Benfica (draw)
# ...                                    ...                              ...
# 6556  CD Leganés vs Athletic Bilbao (draw)  Crvena Zvezda vs Benfica (draw)
# 6557  CD Leganés vs Athletic Bilbao (draw)  Crvena Zvezda vs Benfica (loss)
# 6558  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 6559  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (draw)
# 6560  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
#
#       Total Probability   Total Odds  Expected Value  is_winning_bet
# 0              0.000191  3047.496952       -0.418769           False
# 1              0.000191  2742.747257       -0.476873           False
# 2              0.000381  1500.892249       -0.427294           False
# 3              0.000243  2318.747681       -0.437090           False
# 4              0.000243  2086.872913       -0.493357           False
# ...                 ...          ...             ...             ...
# 6556           0.000064  8640.142560       -0.444653           False
# 6557           0.000129  4728.078012       -0.392145           False
# 6558           0.000115  5760.095040       -0.338834           False
# 6559           0.000115  5184.085536       -0.404939           False
# 6560           0.000230  2836.846807       -0.348635           False
#
# [6236 rows x 12 columns]

# %%
df_results_results.sort_values(by = ['Total Probability']  ,ascending=False).head(15)
# Out:
#                            Match 1                                Match 2  \
# 4400  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2213  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2699  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4886  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2456  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4643  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 26     Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 512    Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2240  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4427  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 269    Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2267  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4454  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2195  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4382  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
#
#                                Match 3                            Match 4  \
# 4400   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 2213   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 2699  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (win)
# 4886  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (win)
# 2456  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (win)
# 4643  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (win)
# 26     FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 512   FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (win)
# 2240   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 4427   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 269   FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (win)
# 2267   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 4454   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 2195   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 4382   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
#
#                                    Match 5  \
# 4400   Örgryte IS vs Landskrona BoIS (win)
# 2213   Örgryte IS vs Landskrona BoIS (win)
# 2699   Örgryte IS vs Landskrona BoIS (win)
# 4886   Örgryte IS vs Landskrona BoIS (win)
# 2456   Örgryte IS vs Landskrona BoIS (win)
# 4643   Örgryte IS vs Landskrona BoIS (win)
# 26     Örgryte IS vs Landskrona BoIS (win)
# 512    Örgryte IS vs Landskrona BoIS (win)
# 2240  Örgryte IS vs Landskrona BoIS (draw)
# 4427  Örgryte IS vs Landskrona BoIS (draw)
# 269    Örgryte IS vs Landskrona BoIS (win)
# 2267  Örgryte IS vs Landskrona BoIS (loss)
# 4454  Örgryte IS vs Landskrona BoIS (loss)
# 2195   Örgryte IS vs Landskrona BoIS (win)
# 4382   Örgryte IS vs Landskrona BoIS (win)
#
#                                  Match 6  \
# 4400  FC Fredericia vs Aalborg BK (loss)
# 2213  FC Fredericia vs Aalborg BK (loss)
# 2699  FC Fredericia vs Aalborg BK (loss)
# 4886  FC Fredericia vs Aalborg BK (loss)
# 2456  FC Fredericia vs Aalborg BK (loss)
# 4643  FC Fredericia vs Aalborg BK (loss)
# 26    FC Fredericia vs Aalborg BK (loss)
# 512   FC Fredericia vs Aalborg BK (loss)
# 2240  FC Fredericia vs Aalborg BK (loss)
# 4427  FC Fredericia vs Aalborg BK (loss)
# 269   FC Fredericia vs Aalborg BK (loss)
# 2267  FC Fredericia vs Aalborg BK (loss)
# 4454  FC Fredericia vs Aalborg BK (loss)
# 2195   FC Fredericia vs Aalborg BK (win)
# 4382   FC Fredericia vs Aalborg BK (win)
#
#                                    Match 7                          Match 8  \
# 4400  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2213  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2699  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4886  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2456  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4643  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 26    CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 512   CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2240  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4427  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 269   CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2267  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4454  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2195  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4382  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
#
#       Total Probability  Total Odds  Expected Value  is_winning_bet
# 4400           0.001940  391.604267       -0.238494           False
# 2213           0.001940  559.434668        0.087035           False
# 2699           0.001730  626.566828        0.085652           False
# 4886           0.001730  438.596780       -0.239524           False
# 2456           0.001573  693.698988        0.092533           False
# 4643           0.001573  485.589292       -0.234755           False
# 26             0.001455  436.029962       -0.364243           False
# 512            0.001297  488.353557       -0.365086           False
# 2240           0.001207  852.471875        0.030038           False
# 4427           0.001207  596.730312       -0.278611           False
# 269            0.001180  540.677153       -0.361090           False
# 2267           0.001164  932.391113        0.086259           False
# 4454           0.001164  652.673779       -0.239269           False
# 2195           0.001156  879.111621        0.016990           False
# 4382           0.001156  615.378135       -0.287761           False

# %%
close_bets.sort_values(by = ['Total Probability']  ,ascending=False).head(15)
# Out:
#                            Match 1                                Match 2  \
# 4400  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2213  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4886  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2699  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4643  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2456  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 26     Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 512    Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4427  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2240  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 269    Al Orubah vs Al-Fateh (win)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2267  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4454  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 4382  Al Orubah vs Al-Fateh (loss)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2195  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
#
#                                Match 3                            Match 4  \
# 4400   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 2213   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 4886  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (win)
# 2699  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (win)
# 4643  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (win)
# 2456  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (win)
# 26     FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 512   FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (win)
# 4427   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 2240   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 269   FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (win)
# 2267   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 4454   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 4382   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
# 2195   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (win)
#
#                                    Match 5  \
# 4400   Örgryte IS vs Landskrona BoIS (win)
# 2213   Örgryte IS vs Landskrona BoIS (win)
# 4886   Örgryte IS vs Landskrona BoIS (win)
# 2699   Örgryte IS vs Landskrona BoIS (win)
# 4643   Örgryte IS vs Landskrona BoIS (win)
# 2456   Örgryte IS vs Landskrona BoIS (win)
# 26     Örgryte IS vs Landskrona BoIS (win)
# 512    Örgryte IS vs Landskrona BoIS (win)
# 4427  Örgryte IS vs Landskrona BoIS (draw)
# 2240  Örgryte IS vs Landskrona BoIS (draw)
# 269    Örgryte IS vs Landskrona BoIS (win)
# 2267  Örgryte IS vs Landskrona BoIS (loss)
# 4454  Örgryte IS vs Landskrona BoIS (loss)
# 4382   Örgryte IS vs Landskrona BoIS (win)
# 2195   Örgryte IS vs Landskrona BoIS (win)
#
#                                  Match 6  \
# 4400  FC Fredericia vs Aalborg BK (loss)
# 2213  FC Fredericia vs Aalborg BK (loss)
# 4886  FC Fredericia vs Aalborg BK (loss)
# 2699  FC Fredericia vs Aalborg BK (loss)
# 4643  FC Fredericia vs Aalborg BK (loss)
# 2456  FC Fredericia vs Aalborg BK (loss)
# 26    FC Fredericia vs Aalborg BK (loss)
# 512   FC Fredericia vs Aalborg BK (loss)
# 4427  FC Fredericia vs Aalborg BK (loss)
# 2240  FC Fredericia vs Aalborg BK (loss)
# 269   FC Fredericia vs Aalborg BK (loss)
# 2267  FC Fredericia vs Aalborg BK (loss)
# 4454  FC Fredericia vs Aalborg BK (loss)
# 4382   FC Fredericia vs Aalborg BK (win)
# 2195   FC Fredericia vs Aalborg BK (win)
#
#                                    Match 7                          Match 8  \
# 4400  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2213  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4886  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2699  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4643  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2456  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 26    CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 512   CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4427  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2240  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 269   CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2267  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4454  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 4382  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2195  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
#
#       Total Probability  Total Odds  Expected Value  is_winning_bet
# 4400           0.001940  391.604267       -0.238494           False
# 2213           0.001940  559.434668        0.087035           False
# 4886           0.001730  438.596780       -0.239524           False
# 2699           0.001730  626.566828        0.085652           False
# 4643           0.001573  485.589292       -0.234755           False
# 2456           0.001573  693.698988        0.092533           False
# 26             0.001455  436.029962       -0.364243           False
# 512            0.001297  488.353557       -0.365086           False
# 4427           0.001207  596.730312       -0.278611           False
# 2240           0.001207  852.471875        0.030038           False
# 269            0.001180  540.677153       -0.361090           False
# 2267           0.001164  932.391113        0.086259           False
# 4454           0.001164  652.673779       -0.239269           False
# 4382           0.001156  615.378135       -0.287761           False
# 2195           0.001156  879.111621        0.016990           False

# %%
top_bets.sort_values(by = ['Total Probability']  ,ascending=False)
# Out:
#                            Match 1                                Match 2  \
# 2375  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2618  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2454  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2373  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2672  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2859  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2616  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2427  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2913  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2670  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
#
#                                Match 3                             Match 4  \
# 2375   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (loss)
# 2618  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
# 2454  FC Lahti vs IFK Mariehamn (draw)   BK Häcken vs Djurgårdens IF (win)
# 2373   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (loss)
# 2672  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
# 2859  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 2616  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
# 2427   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (loss)
# 2913  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 2670  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
#
#                                    Match 5  \
# 2375   Örgryte IS vs Landskrona BoIS (win)
# 2618   Örgryte IS vs Landskrona BoIS (win)
# 2454   Örgryte IS vs Landskrona BoIS (win)
# 2373   Örgryte IS vs Landskrona BoIS (win)
# 2672  Örgryte IS vs Landskrona BoIS (loss)
# 2859   Örgryte IS vs Landskrona BoIS (win)
# 2616   Örgryte IS vs Landskrona BoIS (win)
# 2427  Örgryte IS vs Landskrona BoIS (loss)
# 2913  Örgryte IS vs Landskrona BoIS (loss)
# 2670  Örgryte IS vs Landskrona BoIS (loss)
#
#                                  Match 6  \
# 2375  FC Fredericia vs Aalborg BK (loss)
# 2618  FC Fredericia vs Aalborg BK (loss)
# 2454  FC Fredericia vs Aalborg BK (loss)
# 2373  FC Fredericia vs Aalborg BK (loss)
# 2672  FC Fredericia vs Aalborg BK (loss)
# 2859  FC Fredericia vs Aalborg BK (loss)
# 2616  FC Fredericia vs Aalborg BK (loss)
# 2427  FC Fredericia vs Aalborg BK (loss)
# 2913  FC Fredericia vs Aalborg BK (loss)
# 2670  FC Fredericia vs Aalborg BK (loss)
#
#                                    Match 7                          Match 8  \
# 2375  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2618  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2454  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2373  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2672  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (loss)
# 2859  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2616  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2427  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2913  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2670  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
#
#       Total Probability   Total Odds  Expected Value
# 2375           0.001103  1004.113506        0.108566
# 2618           0.000894  1245.100748        0.114343
# 2454           0.000786  1408.525864        0.108361
# 2373           0.000551  2038.809150        0.124879
# 2672           0.000537  2075.167913        0.113986
# 2859           0.000492  2283.466248        0.123604
# 2616           0.000447  2528.123346        0.130852
# 2427           0.000331  3398.015250        0.124659
# 2913           0.000295  3805.777080        0.123407
# 2670           0.000268  4213.538910        0.130674

# %%
best_bets.sort_values(by = ['Total Probability']  ,ascending=False).head(15)
# Out:
#                            Match 1                                Match 2  \
# 2733  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2370  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2886  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2243  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2396  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2721  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2669  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2597  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2913  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2914  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2841  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2842  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2463  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2423  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
# 2748  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (win)
#
#                                Match 3                             Match 4  \
# 2733  FC Lahti vs IFK Mariehamn (loss)   BK Häcken vs Djurgårdens IF (win)
# 2370   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (loss)
# 2886  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 2243   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 2396   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (loss)
# 2721  FC Lahti vs IFK Mariehamn (loss)   BK Häcken vs Djurgårdens IF (win)
# 2669  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
# 2597  FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
# 2913  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 2914  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 2841  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 2842  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 2463  FC Lahti vs IFK Mariehamn (draw)   BK Häcken vs Djurgårdens IF (win)
# 2423   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (loss)
# 2748  FC Lahti vs IFK Mariehamn (loss)   BK Häcken vs Djurgårdens IF (win)
#
#                                    Match 5  \
# 2733  Örgryte IS vs Landskrona BoIS (loss)
# 2370   Örgryte IS vs Landskrona BoIS (win)
# 2886  Örgryte IS vs Landskrona BoIS (draw)
# 2243  Örgryte IS vs Landskrona BoIS (loss)
# 2396  Örgryte IS vs Landskrona BoIS (draw)
# 2721  Örgryte IS vs Landskrona BoIS (draw)
# 2669  Örgryte IS vs Landskrona BoIS (loss)
# 2597   Örgryte IS vs Landskrona BoIS (win)
# 2913  Örgryte IS vs Landskrona BoIS (loss)
# 2914  Örgryte IS vs Landskrona BoIS (loss)
# 2841   Örgryte IS vs Landskrona BoIS (win)
# 2842   Örgryte IS vs Landskrona BoIS (win)
# 2463  Örgryte IS vs Landskrona BoIS (draw)
# 2423  Örgryte IS vs Landskrona BoIS (loss)
# 2748  Örgryte IS vs Landskrona BoIS (loss)
#
#                                  Match 6  \
# 2733   FC Fredericia vs Aalborg BK (win)
# 2370  FC Fredericia vs Aalborg BK (loss)
# 2886  FC Fredericia vs Aalborg BK (loss)
# 2243   FC Fredericia vs Aalborg BK (win)
# 2396  FC Fredericia vs Aalborg BK (loss)
# 2721  FC Fredericia vs Aalborg BK (loss)
# 2669  FC Fredericia vs Aalborg BK (loss)
# 2597   FC Fredericia vs Aalborg BK (win)
# 2913  FC Fredericia vs Aalborg BK (loss)
# 2914  FC Fredericia vs Aalborg BK (loss)
# 2841   FC Fredericia vs Aalborg BK (win)
# 2842   FC Fredericia vs Aalborg BK (win)
# 2463   FC Fredericia vs Aalborg BK (win)
# 2423  FC Fredericia vs Aalborg BK (loss)
# 2748  FC Fredericia vs Aalborg BK (loss)
#
#                                    Match 7                          Match 8  \
# 2733  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2370  CD Leganés vs Athletic Bilbao (draw)   Crvena Zvezda vs Benfica (win)
# 2886  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2243   CD Leganés vs Athletic Bilbao (win)  Crvena Zvezda vs Benfica (loss)
# 2396   CD Leganés vs Athletic Bilbao (win)  Crvena Zvezda vs Benfica (loss)
# 2721  CD Leganés vs Athletic Bilbao (draw)   Crvena Zvezda vs Benfica (win)
# 2669  CD Leganés vs Athletic Bilbao (draw)  Crvena Zvezda vs Benfica (loss)
# 2597  CD Leganés vs Athletic Bilbao (draw)  Crvena Zvezda vs Benfica (loss)
# 2913  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2914  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (draw)
# 2841  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2842  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (draw)
# 2463  CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# 2423   CD Leganés vs Athletic Bilbao (win)  Crvena Zvezda vs Benfica (loss)
# 2748  CD Leganés vs Athletic Bilbao (draw)   Crvena Zvezda vs Benfica (win)
#
#       Total Probability   Total Odds  Expected Value
# 2733           0.000309  3331.996668        0.030498
# 2370           0.000309  3398.015250        0.049681
# 2886           0.000306  3479.567616        0.065183
# 2243           0.000305  3209.455124       -0.020624
# 2396           0.000302  3351.598824        0.012339
# 2721           0.000301  3231.027072       -0.025887
# 2669           0.000300  3458.613189        0.039520
# 2597           0.000298  3260.978149       -0.026816
# 2913           0.000295  3805.777080        0.123407
# 2914           0.000295  3425.199372        0.011096
# 2841           0.000293  3588.304104        0.051717
# 2842           0.000293  3229.473694       -0.053425
# 2463           0.000291  3372.796627       -0.016594
# 2423           0.000291  3665.811214        0.067674
# 2748           0.000291  3533.935860        0.027357

# %%
best_bets.merge(close_bets).sort_values(by = ['Total Probability']  ,ascending=False)
# Out:
#                           Match 1                                 Match 2  \
# 9    Al Orubah vs Al-Fateh (draw)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 11   Al Orubah vs Al-Fateh (draw)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 12   Al Orubah vs Al-Fateh (draw)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 22   Al Orubah vs Al-Fateh (draw)   Al-Wehda FC Mecca vs Al-Kholood (win)
# 7    Al Orubah vs Al-Fateh (draw)   Al-Wehda FC Mecca vs Al-Kholood (win)
# ..                            ...                                     ...
# 355  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (draw)
# 357  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (draw)
# 323  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (draw)
# 282  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (loss)
# 328  Al Orubah vs Al-Fateh (draw)  Al-Wehda FC Mecca vs Al-Kholood (draw)
#
#                               Match 3                             Match 4  \
# 9     FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
# 11   FC Lahti vs IFK Mariehamn (loss)   BK Häcken vs Djurgårdens IF (win)
# 12   FC Lahti vs IFK Mariehamn (draw)  BK Häcken vs Djurgårdens IF (loss)
# 22   FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 7    FC Lahti vs IFK Mariehamn (draw)   BK Häcken vs Djurgårdens IF (win)
# ..                                ...                                 ...
# 355  FC Lahti vs IFK Mariehamn (draw)   BK Häcken vs Djurgårdens IF (win)
# 357   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (loss)
# 323  FC Lahti vs IFK Mariehamn (loss)  BK Häcken vs Djurgårdens IF (loss)
# 282   FC Lahti vs IFK Mariehamn (win)  BK Häcken vs Djurgårdens IF (loss)
# 328   FC Lahti vs IFK Mariehamn (win)   BK Häcken vs Djurgårdens IF (win)
#
#                                   Match 5                             Match 6  \
# 9    Örgryte IS vs Landskrona BoIS (loss)   FC Fredericia vs Aalborg BK (win)
# 11   Örgryte IS vs Landskrona BoIS (draw)  FC Fredericia vs Aalborg BK (loss)
# 12    Örgryte IS vs Landskrona BoIS (win)   FC Fredericia vs Aalborg BK (win)
# 22    Örgryte IS vs Landskrona BoIS (win)   FC Fredericia vs Aalborg BK (win)
# 7    Örgryte IS vs Landskrona BoIS (draw)   FC Fredericia vs Aalborg BK (win)
# ..                                    ...                                 ...
# 355   Örgryte IS vs Landskrona BoIS (win)   FC Fredericia vs Aalborg BK (win)
# 357  Örgryte IS vs Landskrona BoIS (draw)   FC Fredericia vs Aalborg BK (win)
# 323  Örgryte IS vs Landskrona BoIS (draw)   FC Fredericia vs Aalborg BK (win)
# 282   Örgryte IS vs Landskrona BoIS (win)  FC Fredericia vs Aalborg BK (loss)
# 328  Örgryte IS vs Landskrona BoIS (draw)   FC Fredericia vs Aalborg BK (win)
#
#                                   Match 7                          Match 8  \
# 9     CD Leganés vs Athletic Bilbao (win)  Crvena Zvezda vs Benfica (loss)
# 11   CD Leganés vs Athletic Bilbao (draw)   Crvena Zvezda vs Benfica (win)
# 12   CD Leganés vs Athletic Bilbao (draw)  Crvena Zvezda vs Benfica (loss)
# 22   CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (draw)
# 7    CD Leganés vs Athletic Bilbao (loss)   Crvena Zvezda vs Benfica (win)
# ..                                    ...                              ...
# 355   CD Leganés vs Athletic Bilbao (win)  Crvena Zvezda vs Benfica (draw)
# 357  CD Leganés vs Athletic Bilbao (loss)  Crvena Zvezda vs Benfica (draw)
# 323  CD Leganés vs Athletic Bilbao (draw)  Crvena Zvezda vs Benfica (loss)
# 282   CD Leganés vs Athletic Bilbao (win)  Crvena Zvezda vs Benfica (draw)
# 328  CD Leganés vs Athletic Bilbao (draw)   Crvena Zvezda vs Benfica (win)
#
#      Total Probability   Total Odds  Expected Value  is_winning_bet
# 9             0.000305  3209.455124       -0.020624           False
# 11            0.000301  3231.027072       -0.025887           False
# 12            0.000298  3260.978149       -0.026816           False
# 22            0.000293  3229.473694       -0.053425           False
# 7             0.000291  3372.796627       -0.016594           False
# ..                 ...          ...             ...             ...
# 355           0.000095  8255.375528       -0.212126           False
# 357           0.000095  8312.673600       -0.213206           False
# 323           0.000095  8491.242144       -0.197175           False
# 282           0.000094  8690.522400       -0.179855           False
# 328           0.000093  8576.568000       -0.200547           False
#
# [371 rows x 12 columns]
