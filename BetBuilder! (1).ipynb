# %%
import itertools
import pandas as pd

# Define probabilities and odds for each match
matches = [
    {'team': 'Malmö FF vs PAOK', 'win': 0.55, 'draw': 0.25, 'loss': 0.20, 'win_odds': 1.8, 'draw_odds': 3.4, 'loss_odds': 4.0},
    {'team': 'Dynamo Kyiv vs Rangers', 'win': 0.40, 'draw': 0.30, 'loss': 0.30, 'win_odds': 2.5, 'draw_odds': 3.2, 'loss_odds': 2.6},
    {'team': 'Lille vs Fenerbahçe', 'win': 0.60, 'draw': 0.25, 'loss': 0.15, 'win_odds': 1.7, 'draw_odds': 3.5, 'loss_odds': 4.5},
    {'team': 'Midtjylland vs Ferencváros', 'win': 0.55, 'draw': 0.25, 'loss': 0.20, 'win_odds': 1.8, 'draw_odds': 3.4, 'loss_odds': 4.0},
    {'team': 'Salzburg vs Twente', 'win': 0.70, 'draw': 0.20, 'loss': 0.10, 'win_odds': 1.5, 'draw_odds': 4.0, 'loss_odds': 6.0},
    {'team': 'Qarabağ vs Ludogorets', 'win': 0.60, 'draw': 0.25, 'loss': 0.15, 'win_odds': 1.7, 'draw_odds': 3.5, 'loss_odds': 4.5},
    {'team': 'Petrocub vs The New Saints', 'win': 0.40, 'draw': 0.30, 'loss': 0.30, 'win_odds': 2.5, 'draw_odds': 3.2, 'loss_odds': 2.6},
    {'team': 'Sparta Praha vs FCSB', 'win': 0.65, 'draw': 0.20, 'loss': 0.15, 'win_odds': 1.6, 'draw_odds': 3.8, 'loss_odds': 5.0},
]

# Generate all possible combinations of outcomes (win, draw, loss)
outcomes = ['win', 'draw', 'loss']
combinations = list(itertools.product(outcomes, repeat=len(matches)))

# Calculate total probability and total odds for each combination
results = []
for combo in combinations:
    total_prob = 1.0
    total_odds = 1.0
    for i, outcome in enumerate(combo):
        match = matches[i]
        total_prob *= match[outcome]
        total_odds *= match[f'{outcome}_odds']
    results.append((combo, total_prob, total_odds))

# Sort the results by total probability in descending order
results.sort(key=lambda x: x[1], reverse=True)

# Calculate the desired proportions based on win percentages
total_combinations = len(combinations)
desired_counts = {outcome: sum(match[outcome] for match in matches) / len(matches) for outcome in outcomes}
desired_counts = {outcome: int(total_combinations * proportion) for outcome, proportion in desired_counts.items()}

# Collect top combinations ensuring desired proportions
selected_combinations = []
outcome_counts = {outcome: 0 for outcome in outcomes}

for result in results:
    combo, prob, odds = result
    temp_counts = outcome_counts.copy()
    for outcome in combo:
        temp_counts[outcome] += 1
    
    if all(temp_counts[outcome] <= desired_counts[outcome] for outcome in outcomes):
        selected_combinations.append(result)
        for outcome in combo:
            outcome_counts[outcome] += 1
    
    if all(outcome_counts[outcome] >= desired_counts[outcome] for outcome in outcomes):
        break

# Create a DataFrame with each match in its own column, including team names and outcomes
columns = [f'Match {i+1} ({matches[i]["team"]})' for i in range(len(matches))]
columns.extend(['Total Probability', 'Total Odds'])
data = []
for combo, prob, odds in selected_combinations:
    data.append(list(combo) + [prob, odds])

df = pd.DataFrame(data, columns=columns)

# Ensure the proportions are correct
outcome_counts_df = pd.DataFrame()
for column in columns[:-2]:  # Exclude 'Total Probability' and 'Total Odds'
    counts = df[column].value_counts()
    outcome_counts_df[column] = counts

df
# Out:
#     Match 1 (Malmö FF vs PAOK) Match 2 (Dynamo Kyiv vs Rangers)  \
# 0                          win                              win
# 1                          win                              win
# 2                          win                              win
# 3                          win                             draw
# 4                          win                             loss
# ..                         ...                              ...
# 794                       draw                             draw
# 795                       draw                             draw
# 796                       draw                             draw
# 797                       loss                             loss
# 798                       loss                             loss
#
#     Match 3 (Lille vs Fenerbahçe) Match 4 (Midtjylland vs Ferencváros)  \
# 0                             win                                  win
# 1                             win                                  win
# 2                             win                                  win
# 3                             win                                  win
# 4                             win                                  win
# ..                            ...                                  ...
# 794                          draw                                 loss
# 795                          loss                                 draw
# 796                          loss                                 draw
# 797                          draw                                 loss
# 798                          loss                                 loss
#
#     Match 5 (Salzburg vs Twente) Match 6 (Qarabağ vs Ludogorets)  \
# 0                            win                             win
# 1                            win                             win
# 2                            win                             win
# 3                            win                             win
# 4                            win                             win
# ..                           ...                             ...
# 794                         draw                            draw
# 795                         draw                            draw
# 796                         draw                            draw
# 797                         draw                            draw
# 798                         loss                            loss
#
#     Match 7 (Petrocub vs The New Saints) Match 8 (Sparta Praha vs FCSB)  \
# 0                                    win                            win
# 1                                   draw                            win
# 2                                   loss                            win
# 3                                    win                            win
# 4                                    win                            win
# ..                                   ...                            ...
# 794                                 loss                           loss
# 795                                 draw                           draw
# 796                                 loss                           draw
# 797                                 loss                           loss
# 798                                 loss                           loss
#
#      Total Probability   Total Odds
# 0             0.007928    140.45400
# 1             0.005946    179.78112
# 2             0.005946    146.07216
# 3             0.005946    179.78112
# 4             0.005946    146.07216
# ..                 ...          ...
# 794           0.000008  27722.24000
# 795           0.000008  28338.83136
# 796           0.000008  23025.30048
# 797           0.000007  26499.20000
# 798           0.000001  65707.20000
#
# [799 rows x 10 columns]

# %%
df.head(60)
# Out:
#    Match 1 (Malmö FF vs PAOK) Match 2 (Dynamo Kyiv vs Rangers)  \
# 0                         win                              win
# 1                         win                              win
# 2                         win                              win
# 3                         win                             draw
# 4                         win                             loss
# 5                         win                             draw
# 6                         win                             draw
# 7                         win                             loss
# 8                         win                             loss
# 9                         win                              win
# 10                       draw                              win
# 11                        win                              win
# 12                        win                              win
# 13                       loss                              win
# 14                        win                              win
# 15                        win                             draw
# 16                        win                             loss
# 17                       draw                             draw
# 18                       draw                             loss
# 19                        win                              win
# 20                        win                              win
# 21                       draw                              win
# 22                       draw                              win
# 23                        win                             draw
# 24                        win                             loss
# 25                        win                              win
# 26                        win                              win
# 27                        win                              win
# 28                        win                              win
# 29                        win                             draw
# 30                        win                             loss
# 31                        win                              win
# 32                        win                              win
# 33                       loss                              win
# 34                       loss                              win
# 35                        win                             draw
# 36                        win                             loss
# 37                       loss                             draw
# 38                       loss                             loss
# 39                        win                              win
# 40                        win                              win
# 41                        win                             draw
# 42                        win                             draw
# 43                        win                             loss
# 44                        win                             loss
# 45                       draw                             draw
# 46                       draw                             draw
# 47                       draw                             loss
# 48                       draw                             loss
# 49                        win                              win
# 50                        win                              win
# 51                        win                             draw
# 52                        win                             draw
# 53                        win                             loss
# 54                        win                             loss
# 55                        win                             draw
# 56                        win                             draw
# 57                        win                             loss
# 58                        win                             loss
# 59                        win                              win
#
#    Match 3 (Lille vs Fenerbahçe) Match 4 (Midtjylland vs Ferencváros)  \
# 0                            win                                  win
# 1                            win                                  win
# 2                            win                                  win
# 3                            win                                  win
# 4                            win                                  win
# 5                            win                                  win
# 6                            win                                  win
# 7                            win                                  win
# 8                            win                                  win
# 9                            win                                 draw
# 10                           win                                  win
# 11                           win                                  win
# 12                          draw                                  win
# 13                           win                                  win
# 14                           win                                 loss
# 15                           win                                 draw
# 16                           win                                 draw
# 17                           win                                  win
# 18                           win                                  win
# 19                           win                                 draw
# 20                           win                                 draw
# 21                           win                                  win
# 22                           win                                  win
# 23                           win                                  win
# 24                           win                                  win
# 25                           win                                  win
# 26                           win                                  win
# 27                          draw                                  win
# 28                          draw                                  win
# 29                          draw                                  win
# 30                          draw                                  win
# 31                           win                                  win
# 32                           win                                  win
# 33                           win                                  win
# 34                           win                                  win
# 35                           win                                 loss
# 36                           win                                 loss
# 37                           win                                  win
# 38                           win                                  win
# 39                           win                                 loss
# 40                           win                                 loss
# 41                           win                                 draw
# 42                           win                                 draw
# 43                           win                                 draw
# 44                           win                                 draw
# 45                           win                                  win
# 46                           win                                  win
# 47                           win                                  win
# 48                           win                                  win
# 49                           win                                  win
# 50                          loss                                  win
# 51                           win                                  win
# 52                           win                                  win
# 53                           win                                  win
# 54                           win                                  win
# 55                          draw                                  win
# 56                          draw                                  win
# 57                          draw                                  win
# 58                          draw                                  win
# 59                           win                                  win
#
#    Match 5 (Salzburg vs Twente) Match 6 (Qarabağ vs Ludogorets)  \
# 0                           win                             win
# 1                           win                             win
# 2                           win                             win
# 3                           win                             win
# 4                           win                             win
# 5                           win                             win
# 6                           win                             win
# 7                           win                             win
# 8                           win                             win
# 9                           win                             win
# 10                          win                             win
# 11                          win                            draw
# 12                          win                             win
# 13                          win                             win
# 14                          win                             win
# 15                          win                             win
# 16                          win                             win
# 17                          win                             win
# 18                          win                             win
# 19                          win                             win
# 20                          win                             win
# 21                          win                             win
# 22                          win                             win
# 23                          win                            draw
# 24                          win                            draw
# 25                          win                            draw
# 26                          win                            draw
# 27                          win                             win
# 28                          win                             win
# 29                          win                             win
# 30                          win                             win
# 31                          win                             win
# 32                         draw                             win
# 33                          win                             win
# 34                          win                             win
# 35                          win                             win
# 36                          win                             win
# 37                          win                             win
# 38                          win                             win
# 39                          win                             win
# 40                          win                             win
# 41                          win                             win
# 42                          win                             win
# 43                          win                             win
# 44                          win                             win
# 45                          win                             win
# 46                          win                             win
# 47                          win                             win
# 48                          win                             win
# 49                          win                            loss
# 50                          win                             win
# 51                          win                            draw
# 52                          win                            draw
# 53                          win                            draw
# 54                          win                            draw
# 55                          win                             win
# 56                          win                             win
# 57                          win                             win
# 58                          win                             win
# 59                          win                             win
#
#    Match 7 (Petrocub vs The New Saints) Match 8 (Sparta Praha vs FCSB)  \
# 0                                   win                            win
# 1                                  draw                            win
# 2                                  loss                            win
# 3                                   win                            win
# 4                                   win                            win
# 5                                  draw                            win
# 6                                  loss                            win
# 7                                  draw                            win
# 8                                  loss                            win
# 9                                   win                            win
# 10                                  win                            win
# 11                                  win                            win
# 12                                  win                            win
# 13                                  win                            win
# 14                                  win                            win
# 15                                  win                            win
# 16                                  win                            win
# 17                                  win                            win
# 18                                  win                            win
# 19                                 draw                            win
# 20                                 loss                            win
# 21                                 draw                            win
# 22                                 loss                            win
# 23                                  win                            win
# 24                                  win                            win
# 25                                 draw                            win
# 26                                 loss                            win
# 27                                 draw                            win
# 28                                 loss                            win
# 29                                  win                            win
# 30                                  win                            win
# 31                                  win                           draw
# 32                                  win                            win
# 33                                 draw                            win
# 34                                 loss                            win
# 35                                  win                            win
# 36                                  win                            win
# 37                                  win                            win
# 38                                  win                            win
# 39                                 draw                            win
# 40                                 loss                            win
# 41                                 draw                            win
# 42                                 loss                            win
# 43                                 draw                            win
# 44                                 loss                            win
# 45                                 draw                            win
# 46                                 loss                            win
# 47                                 draw                            win
# 48                                 loss                            win
# 49                                  win                            win
# 50                                  win                            win
# 51                                 draw                            win
# 52                                 loss                            win
# 53                                 draw                            win
# 54                                 loss                            win
# 55                                 draw                            win
# 56                                 loss                            win
# 57                                 draw                            win
# 58                                 loss                            win
# 59                                 draw                           draw
#
#     Total Probability  Total Odds
# 0            0.007928  140.454000
# 1            0.005946  179.781120
# 2            0.005946  146.072160
# 3            0.005946  179.781120
# 4            0.005946  146.072160
# 5            0.004459  230.119834
# 6            0.004459  186.972365
# 7            0.004459  186.972365
# 8            0.004459  151.915046
# 9            0.003604  265.302000
# 10           0.003604  265.302000
# 11           0.003303  289.170000
# 12           0.003303  289.170000
# 13           0.002883  312.120000
# 14           0.002883  312.120000
# 15           0.002703  339.586560
# 16           0.002703  275.914080
# 17           0.002703  339.586560
# 18           0.002703  275.914080
# 19           0.002703  339.586560
# 20           0.002703  275.914080
# 21           0.002703  339.586560
# 22           0.002703  275.914080
# 23           0.002477  370.137600
# 24           0.002477  300.736800
# 25           0.002477  370.137600
# 26           0.002477  300.736800
# 27           0.002477  370.137600
# 28           0.002477  300.736800
# 29           0.002477  370.137600
# 30           0.002477  300.736800
# 31           0.002439  333.578250
# 32           0.002265  374.544000
# 33           0.002162  399.513600
# 34           0.002162  324.604800
# 35           0.002162  399.513600
# 36           0.002162  324.604800
# 37           0.002162  399.513600
# 38           0.002162  324.604800
# 39           0.002162  399.513600
# 40           0.002162  324.604800
# 41           0.002027  434.670797
# 42           0.002027  353.170022
# 43           0.002027  353.170022
# 44           0.002027  286.950643
# 45           0.002027  434.670797
# 46           0.002027  353.170022
# 47           0.002027  353.170022
# 48           0.002027  286.950643
# 49           0.001982  371.790000
# 50           0.001982  371.790000
# 51           0.001858  473.776128
# 52           0.001858  384.943104
# 53           0.001858  384.943104
# 54           0.001858  312.766272
# 55           0.001858  473.776128
# 56           0.001858  384.943104
# 57           0.001858  384.943104
# 58           0.001858  312.766272
# 59           0.001830  426.980160

# %%
import itertools
import pandas as pd

# Define probabilities and odds for each match
matches = [
    {'team': 'Jahn Regensburg vs Ulm', 'win': 0.45, 'draw': 0.30, 'loss': 0.25, 'win_odds': 2.20, 'draw_odds': 3.33, 'loss_odds': 4.00},
    {'team': 'FCSB vs FCV Farul Constanța', 'win': 0.50, 'draw': 0.30, 'loss': 0.20, 'win_odds': 2.00, 'draw_odds': 3.33, 'loss_odds': 5.00},
    {'team': 'Queen\'s Park vs Livingston', 'win': 0.40, 'draw': 0.35, 'loss': 0.25, 'win_odds': 2.50, 'draw_odds': 2.86, 'loss_odds': 4.00},
    {'team': 'Ayr United vs Airdrieonians', 'win': 0.45, 'draw': 0.30, 'loss': 0.25, 'win_odds': 2.20, 'draw_odds': 3.33, 'loss_odds': 4.00},
    {'team': 'Blackburn Rovers vs Derby County', 'win': 0.55, 'draw': 0.25, 'loss': 0.20, 'win_odds': 1.80, 'draw_odds': 4.00, 'loss_odds': 5.00},
    {'team': 'Preston North End vs Sheffield United', 'win': 0.35, 'draw': 0.30, 'loss': 0.35, 'win_odds': 2.86, 'draw_odds': 3.33, 'loss_odds': 2.86},
    {'team': 'Paysandu vs Santos', 'win': 0.40, 'draw': 0.30, 'loss': 0.30, 'win_odds': 2.50, 'draw_odds': 3.33, 'loss_odds': 3.33},
]

# Generate all possible combinations of outcomes (win, draw, loss)
outcomes = ['win', 'draw', 'loss']
combinations = list(itertools.product(outcomes, repeat=len(matches)))

# Calculate total probability and total odds for each combination
results = []
for combo in combinations:
    total_prob = 1.0
    total_odds = 1.0
    for i, outcome in enumerate(combo):
        match = matches[i]
        total_prob *= match[outcome]
        total_odds *= match[f'{outcome}_odds']
    results.append((combo, total_prob, total_odds))

# Sort the results by total probability in descending order
results.sort(key=lambda x: x[1], reverse=True)

# Calculate the desired proportions based on win percentages
total_combinations = len(combinations)
desired_counts = {outcome: sum(match[outcome] for match in matches) / len(matches) for outcome in outcomes}
desired_counts = {outcome: int(total_combinations * proportion) for outcome, proportion in desired_counts.items()}

# Collect top combinations ensuring desired proportions
selected_combinations = []
outcome_counts = {outcome: 0 for outcome in outcomes}

for result in results:
    combo, prob, odds = result
    temp_counts = outcome_counts.copy()
    for outcome in combo:
        temp_counts[outcome] += 1
    
    if all(temp_counts[outcome] <= desired_counts[outcome] for outcome in outcomes):
        selected_combinations.append(result)
        for outcome in combo:
            outcome_counts[outcome] += 1
    
    if all(outcome_counts[outcome] >= desired_counts[outcome] for outcome in outcomes):
        break

# Create a DataFrame with each match in its own column, including team names and outcomes
columns = [f'Match {i+1} ({matches[i]["team"]})' for i in range(len(matches))]
columns.extend(['Total Probability', 'Total Odds'])
data = []

for combo, prob, odds in selected_combinations:
    data.append(list(combo) + [prob, odds])

df = pd.DataFrame(data, columns=columns)

# Ensure the proportions are correct
outcome_counts_df = pd.DataFrame()
for column in columns[:-2]:  # Exclude 'Total Probability' and 'Total Odds'
    counts = df[column].value_counts()
    outcome_counts_df[column] = counts

outcome_counts_df

# Extend the list to match the number of rows in the DataFrame
desired_column_values = [1.8, 2.45, 3.00, 2.38, 2.25, 1.40, 2.25]
desired_column_values *= (len(df) // len(desired_column_values)) + 1
desired_column_values = desired_column_values[:len(df)]

# Add the desired column to the DataFrame
df['Desired Column'] = desired_column_values

df
# Out:
#     Match 1 (Jahn Regensburg vs Ulm) Match 2 (FCSB vs FCV Farul Constanța)  \
# 0                                win                                   win
# 1                                win                                   win
# 2                                win                                   win
# 3                                win                                   win
# 4                                win                                   win
# ..                               ...                                   ...
# 290                             draw                                  draw
# 291                             draw                                  draw
# 292                             draw                                  loss
# 293                             loss                                  draw
# 294                             loss                                  loss
#
#     Match 3 (Queen's Park vs Livingston)  \
# 0                                    win
# 1                                    win
# 2                                   draw
# 3                                   draw
# 4                                    win
# ..                                   ...
# 290                                 loss
# 291                                 loss
# 292                                 draw
# 293                                 loss
# 294                                 loss
#
#     Match 4 (Ayr United vs Airdrieonians)  \
# 0                                     win
# 1                                     win
# 2                                     win
# 3                                     win
# 4                                     win
# ..                                    ...
# 290                                  loss
# 291                                  loss
# 292                                  loss
# 293                                  loss
# 294                                  loss
#
#     Match 5 (Blackburn Rovers vs Derby County)  \
# 0                                          win
# 1                                          win
# 2                                          win
# 3                                          win
# 4                                          win
# ..                                         ...
# 290                                       loss
# 291                                       loss
# 292                                       draw
# 293                                       loss
# 294                                       loss
#
#     Match 6 (Preston North End vs Sheffield United)  \
# 0                                               win
# 1                                              loss
# 2                                               win
# 3                                              loss
# 4                                              draw
# ..                                              ...
# 290                                            loss
# 291                                            loss
# 292                                            draw
# 293                                            loss
# 294                                            loss
#
#     Match 7 (Paysandu vs Santos)  Total Probability    Total Odds  \
# 0                            win           0.003119    311.454000
# 1                            win           0.003119    311.454000
# 2                            win           0.002729    356.303376
# 3                            win           0.002729    356.303376
# 4                            win           0.002673    362.637000
# ..                           ...                ...           ...
# 290                         draw           0.000118   8448.677266
# 291                         loss           0.000118   8448.677266
# 292                         draw           0.000118   8448.677266
# 293                         loss           0.000098  10148.561280
# 294                         loss           0.000066  15238.080000
#
#      Desired Column
# 0              1.80
# 1              2.45
# 2              3.00
# 3              2.38
# 4              2.25
# ..              ...
# 290            2.38
# 291            2.25
# 292            1.40
# 293            2.25
# 294            1.80
#
# [295 rows x 10 columns]

# %%
import itertools
import pandas as pd

# Define probabilities and odds for each match
matches = [
    {'team': 'Jahn Regensburg vs Ulm', 'win': 0.45, 'draw': 0.30, 'loss': 0.25, 'win_odds': 2.20, 'draw_odds': 3.33, 'loss_odds': 4.00},
    {'team': 'FCSB vs FCV Farul Constanța', 'win': 0.50, 'draw': 0.30, 'loss': 0.20, 'win_odds': 2.00, 'draw_odds': 3.33, 'loss_odds': 5.00},
    {'team': 'Queen\'s Park vs Livingston', 'win': 0.40, 'draw': 0.35, 'loss': 0.25, 'win_odds': 2.50, 'draw_odds': 2.86, 'loss_odds': 4.00},
    {'team': 'Ayr United vs Airdrieonians', 'win': 0.45, 'draw': 0.30, 'loss': 0.25, 'win_odds': 2.20, 'draw_odds': 3.33, 'loss_odds': 4.00},
    {'team': 'Blackburn Rovers vs Derby County', 'win': 0.55, 'draw': 0.25, 'loss': 0.20, 'win_odds': 1.80, 'draw_odds': 4.00, 'loss_odds': 5.00},
    {'team': 'Preston North End vs Sheffield United', 'win': 0.35, 'draw': 0.30, 'loss': 0.35, 'win_odds': 2.86, 'draw_odds': 3.33, 'loss_odds': 2.86},
    {'team': 'Paysandu vs Santos', 'win': 0.40, 'draw': 0.30, 'loss': 0.30, 'win_odds': 2.50, 'draw_odds': 3.33, 'loss_odds': 3.33},
]

# Generate all possible combinations of outcomes (win, draw, loss)
outcomes = ['win', 'draw', 'loss']
combinations = list(itertools.product(outcomes, repeat=len(matches)))

# Calculate total probability and total odds for each combination
results = []
for combo in combinations:
    total_prob = 1.0
    total_odds = 1.0
    for i, outcome in enumerate(combo):
        match = matches[i]
        total_prob *= match[outcome]
        total_odds *= match[f'{outcome}_odds']
    expected_value = (total_prob * total_odds) - (1 - total_prob)  # Calculate expected value
    results.append((combo, total_prob, total_odds, expected_value))

# Sort the results by expected value in descending order
results.sort(key=lambda x: x[3], reverse=True)

# Create a DataFrame with each match in its own column, including team names and outcomes
columns = [
    'Match 7 (Paysandu vs Santos - Sat 00:00)',
    'Match 1 (Jahn Regensburg vs Ulm - Fri 17:30)',
    'Match 3 (Queen\'s Park vs Livingston - Fri 19:45)',
    'Match 2 (FCSB vs FCV Farul Constanța - Fri 19:00)',
    'Match 4 (Ayr United vs Airdrieonians - Fri 19:45)',
    'Match 5 (Blackburn Rovers vs Derby County - Fri 20:00)',
    'Match 6 (Preston North End vs Sheffield United - Fri 20:00)',
]
columns.extend(['Total Probability', 'Total Odds', 'Expected Value'])
data = []

for combo, prob, odds, ev in results:
    reordered_combo = [combo[6], combo[0], combo[2], combo[1], combo[3], combo[4], combo[5]]
    data.append(reordered_combo + [prob, odds, ev])

df = pd.DataFrame(data, columns=columns)

# Ensure the proportions are correct
outcome_counts_df = pd.DataFrame()
for column in columns[:-3]:  # Exclude 'Total Probability', 'Total Odds', and 'Expected Value'
    counts = df[column].value_counts()
    outcome_counts_df[column] = counts

outcome_counts_df

# Extend the list to match the number of rows in the DataFrame
desired_column_values = [2.25, 2.20, 2.50, 2.00, 2.20, 1.80, 2.86]
desired_column_values *= (len(df) // len(desired_column_values)) + 1
desired_column_values = desired_column_values[:len(df)]

# Add the desired column to the DataFrame
df['Desired Column'] = desired_column_values

df
# Out:
#      Match 7 (Paysandu vs Santos - Sat 00:00)  \
# 0                                         win
# 1                                         win
# 2                                         win
# 3                                         win
# 4                                         win
# ...                                       ...
# 2182                                     loss
# 2183                                     draw
# 2184                                     loss
# 2185                                     draw
# 2186                                     loss
#
#      Match 1 (Jahn Regensburg vs Ulm - Fri 17:30)  \
# 0                                            loss
# 1                                            loss
# 2                                            loss
# 3                                            loss
# 4                                            loss
# ...                                           ...
# 2182                                          win
# 2183                                          win
# 2184                                          win
# 2185                                          win
# 2186                                          win
#
#      Match 3 (Queen's Park vs Livingston - Fri 19:45)  \
# 0                                                draw
# 1                                                draw
# 2                                                draw
# 3                                                draw
# 4                                                draw
# ...                                               ...
# 2182                                             loss
# 2183                                              win
# 2184                                              win
# 2185                                             loss
# 2186                                             loss
#
#      Match 2 (FCSB vs FCV Farul Constanța - Fri 19:00)  \
# 0                                                  win
# 1                                                  win
# 2                                                  win
# 3                                                  win
# 4                                                 loss
# ...                                                ...
# 2182                                              loss
# 2183                                              draw
# 2184                                              draw
# 2185                                              draw
# 2186                                              draw
#
#      Match 4 (Ayr United vs Airdrieonians - Fri 19:45)  \
# 0                                                 loss
# 1                                                 loss
# 2                                                 loss
# 3                                                 loss
# 4                                                 loss
# ...                                                ...
# 2182                                               win
# 2183                                               win
# 2184                                               win
# 2185                                               win
# 2186                                               win
#
#      Match 5 (Blackburn Rovers vs Derby County - Fri 20:00)  \
# 0                                                  draw
# 1                                                  draw
# 2                                                  loss
# 3                                                  loss
# 4                                                  draw
# ...                                                 ...
# 2182                                                win
# 2183                                                win
# 2184                                                win
# 2185                                                win
# 2186                                                win
#
#      Match 6 (Preston North End vs Sheffield United - Fri 20:00)  \
# 0                                                   win
# 1                                                  loss
# 2                                                   win
# 3                                                  loss
# 4                                                   win
# ...                                                 ...
# 2182                                               draw
# 2183                                               draw
# 2184                                               draw
# 2185                                               draw
# 2186                                               draw
#
#       Total Probability   Total Odds  Expected Value  Desired Column
# 0              0.000383  2617.472000        0.002384            2.25
# 1              0.000383  2617.472000        0.002384            2.20
# 2              0.000306  3271.840000        0.002307            2.50
# 3              0.000306  3271.840000        0.002307            2.00
# 4              0.000153  6543.680000        0.002154            2.20
# ...                 ...          ...             ...             ...
# 2182           0.000501  1932.129936       -0.031139            1.80
# 2183           0.001203   804.249086       -0.031406            2.86
# 2184           0.001203   804.249086       -0.031406            2.25
# 2185           0.000752  1286.798537       -0.031857            2.20
# 2186           0.000752  1286.798537       -0.031857            2.50
#
# [2187 rows x 11 columns]

# %%
df.sample(50).sort_values(by = ['Desired Column'])
# Out:
#      Match 7 (Paysandu vs Santos - Sat 00:00)  \
# 1132                                     loss
# 481                                      draw
# 1587                                     draw
# 761                                      loss
# 1426                                      win
# 1825                                      win
# 703                                      loss
# 2061                                     loss
# 906                                      loss
# 367                                      draw
# 1844                                     loss
# 1718                                     draw
# 416                                      draw
# 745                                       win
# 1688                                      win
# 1380                                     draw
# 435                                      draw
# 106                                       win
# 4                                         win
# 2111                                      win
# 263                                       win
# 18                                        win
# 1271                                     draw
# 1289                                      win
# 386                                      draw
# 844                                      loss
# 1747                                     loss
# 1047                                     draw
# 81                                        win
# 1712                                     draw
# 1240                                     draw
# 620                                      draw
# 1456                                     draw
# 819                                      draw
# 1211                                      win
# 1444                                     loss
# 1486                                     draw
# 751                                       win
# 156                                      draw
# 1493                                      win
# 177                                      draw
# 1458                                     draw
# 254                                       win
# 1801                                     loss
# 13                                        win
# 1119                                     draw
# 636                                      draw
# 1567                                     loss
# 279                                      loss
# 2015                                     draw
#
#      Match 1 (Jahn Regensburg vs Ulm - Fri 17:30)  \
# 1132                                         draw
# 481                                          draw
# 1587                                         draw
# 761                                           win
# 1426                                         loss
# 1825                                          win
# 703                                          loss
# 2061                                          win
# 906                                          loss
# 367                                          draw
# 1844                                          win
# 1718                                          win
# 416                                          loss
# 745                                           win
# 1688                                          win
# 1380                                         draw
# 435                                          draw
# 106                                          draw
# 4                                            loss
# 2111                                          win
# 263                                          draw
# 18                                           loss
# 1271                                          win
# 1289                                         loss
# 386                                          draw
# 844                                           win
# 1747                                          win
# 1047                                          win
# 81                                           draw
# 1712                                          win
# 1240                                         loss
# 620                                          draw
# 1456                                         loss
# 819                                           win
# 1211                                          win
# 1444                                         loss
# 1486                                         draw
# 751                                           win
# 156                                          loss
# 1493                                         draw
# 177                                          loss
# 1458                                          win
# 254                                          loss
# 1801                                         draw
# 13                                           loss
# 1119                                         loss
# 636                                          draw
# 1567                                         loss
# 279                                          loss
# 2015                                          win
#
#      Match 3 (Queen's Park vs Livingston - Fri 19:45)  \
# 1132                                             draw
# 481                                              loss
# 1587                                              win
# 761                                              draw
# 1426                                             loss
# 1825                                             loss
# 703                                              draw
# 2061                                             loss
# 906                                              loss
# 367                                               win
# 1844                                              win
# 1718                                             draw
# 416                                               win
# 745                                              draw
# 1688                                              win
# 1380                                             loss
# 435                                               win
# 106                                              loss
# 4                                                draw
# 2111                                             draw
# 263                                               win
# 18                                                win
# 1271                                             draw
# 1289                                              win
# 386                                              loss
# 844                                              draw
# 1747                                              win
# 1047                                              win
# 81                                               loss
# 1712                                             draw
# 1240                                             draw
# 620                                               win
# 1456                                              win
# 819                                              draw
# 1211                                              win
# 1444                                              win
# 1486                                              win
# 751                                               win
# 156                                               win
# 1493                                              win
# 177                                               win
# 1458                                              win
# 254                                              loss
# 1801                                              win
# 13                                                win
# 1119                                              win
# 636                                              loss
# 1567                                             loss
# 279                                              loss
# 2015                                             loss
#
#      Match 2 (FCSB vs FCV Farul Constanța - Fri 19:00)  \
# 1132                                              draw
# 481                                               loss
# 1587                                              draw
# 761                                               loss
# 1426                                              loss
# 1825                                              loss
# 703                                                win
# 2061                                              loss
# 906                                                win
# 367                                                win
# 1844                                              loss
# 1718                                              loss
# 416                                               draw
# 745                                               loss
# 1688                                              loss
# 1380                                              draw
# 435                                               draw
# 106                                                win
# 4                                                 loss
# 2111                                              loss
# 263                                               loss
# 18                                                 win
# 1271                                              loss
# 1289                                               win
# 386                                                win
# 844                                                win
# 1747                                               win
# 1047                                               win
# 81                                                 win
# 1712                                               win
# 1240                                              loss
# 620                                               draw
# 1456                                              loss
# 819                                                win
# 1211                                              loss
# 1444                                              loss
# 1486                                               win
# 751                                               loss
# 156                                               loss
# 1493                                              draw
# 177                                               loss
# 1458                                              loss
# 254                                                win
# 1801                                               win
# 13                                                 win
# 1119                                              draw
# 636                                               loss
# 1567                                              loss
# 279                                                win
# 2015                                              draw
#
#      Match 4 (Ayr United vs Airdrieonians - Fri 19:45)  \
# 1132                                               win
# 481                                               draw
# 1587                                              loss
# 761                                               loss
# 1426                                              draw
# 1825                                              draw
# 703                                                win
# 2061                                               win
# 906                                                win
# 367                                               draw
# 1844                                               win
# 1718                                               win
# 416                                               draw
# 745                                               draw
# 1688                                              loss
# 1380                                              loss
# 435                                               loss
# 106                                               loss
# 4                                                 loss
# 2111                                               win
# 263                                               draw
# 18                                                loss
# 1271                                              loss
# 1289                                              draw
# 386                                               draw
# 844                                               draw
# 1747                                               win
# 1047                                              draw
# 81                                                loss
# 1712                                              draw
# 1240                                              loss
# 620                                               loss
# 1456                                               win
# 819                                               draw
# 1211                                              loss
# 1444                                               win
# 1486                                               win
# 751                                               loss
# 156                                               loss
# 1493                                               win
# 177                                               loss
# 1458                                              loss
# 254                                               loss
# 1801                                               win
# 13                                                loss
# 1119                                              loss
# 636                                               draw
# 1567                                              draw
# 279                                               draw
# 2015                                              draw
#
#      Match 5 (Blackburn Rovers vs Derby County - Fri 20:00)  \
# 1132                                               draw
# 481                                                draw
# 1587                                                win
# 761                                                draw
# 1426                                                win
# 1825                                                win
# 703                                                draw
# 2061                                               loss
# 906                                                draw
# 367                                                draw
# 1844                                               draw
# 1718                                               draw
# 416                                                draw
# 745                                                loss
# 1688                                                win
# 1380                                                win
# 435                                                loss
# 106                                                loss
# 4                                                  draw
# 2111                                                win
# 263                                                loss
# 18                                                 loss
# 1271                                               loss
# 1289                                                win
# 386                                                draw
# 844                                                loss
# 1747                                               draw
# 1047                                               draw
# 81                                                 draw
# 1712                                                win
# 1240                                                win
# 620                                                loss
# 1456                                               loss
# 819                                                draw
# 1211                                               draw
# 1444                                               draw
# 1486                                               draw
# 751                                                loss
# 156                                                draw
# 1493                                               draw
# 177                                                loss
# 1458                                               loss
# 254                                                draw
# 1801                                                win
# 13                                                 draw
# 1119                                                win
# 636                                                draw
# 1567                                                win
# 279                                                loss
# 2015                                                win
#
#      Match 6 (Preston North End vs Sheffield United - Fri 20:00)  \
# 1132                                               loss
# 481                                                loss
# 1587                                               draw
# 761                                                 win
# 1426                                               draw
# 1825                                               loss
# 703                                                loss
# 2061                                               draw
# 906                                                loss
# 367                                                 win
# 1844                                                win
# 1718                                               loss
# 416                                                 win
# 745                                                loss
# 1688                                                win
# 1380                                                win
# 435                                                loss
# 106                                                 win
# 4                                                   win
# 2111                                               loss
# 263                                                 win
# 18                                                  win
# 1271                                               draw
# 1289                                               draw
# 386                                                 win
# 844                                                 win
# 1747                                                win
# 1047                                                win
# 81                                                 loss
# 1712                                                win
# 1240                                               draw
# 620                                                draw
# 1456                                               draw
# 819                                                loss
# 1211                                               draw
# 1444                                               draw
# 1486                                               draw
# 751                                                loss
# 156                                                 win
# 1493                                               draw
# 177                                                loss
# 1458                                               draw
# 254                                                draw
# 1801                                               loss
# 13                                                 loss
# 1119                                                win
# 636                                                draw
# 1567                                               draw
# 279                                                loss
# 2015                                                win
#
#       Total Probability   Total Odds  Expected Value  Desired Column
# 1132           0.000372  2657.953868       -0.010620            1.80
# 481            0.000118  8448.677266       -0.001882            1.80
# 1587           0.000445  2213.346658       -0.013509            1.80
# 761            0.000207  4793.899968       -0.008804            1.80
# 1426           0.000248  3992.004000       -0.011732            1.80
# 1825           0.000520  1885.712400       -0.019381            1.80
# 703            0.000517  1917.559987       -0.008494            2.00
# 2061           0.000182  5367.027600       -0.021677            2.00
# 906            0.000369  2681.902080       -0.009632            2.00
# 367            0.000472  2112.169316       -0.001527            2.00
# 1844           0.000425  2304.759600       -0.019476            2.00
# 1718           0.000372  2636.644982       -0.018549            2.00
# 416            0.000236  4224.338633       -0.001764            2.00
# 745            0.000265  3745.234350       -0.008746            2.00
# 1688           0.000693  1415.700000       -0.018227            2.20
# 1380           0.000325  3041.523816       -0.011655            2.20
# 435            0.000189  5280.423291       -0.001811            2.20
# 106            0.000262  3809.520000        0.000261            2.20
# 4              0.000153  6543.680000        0.002154            2.20
# 2111           0.001091   890.758440       -0.026668            2.20
# 263            0.000202  4955.352188       -0.000799            2.20
# 18             0.000350  2860.000000        0.001350            2.20
# 1271           0.000142  6977.135880       -0.010849            2.20
# 1289           0.000990   998.001000       -0.010989            2.20
# 386            0.000295  3379.470906       -0.001705            2.20
# 844            0.000496  1995.460862       -0.009506            2.20
# 1747           0.001063   921.903840       -0.018838            2.20
# 1047           0.000709  1395.427176       -0.010282            2.20
# 81             0.000328  3047.616000        0.000327            2.20
# 1712           0.001364   718.365910       -0.018538            2.20
# 1240           0.000217  4566.852576       -0.010774            2.20
# 620            0.000162  6148.185161       -0.003832            2.20
# 1456           0.000162  6098.895000       -0.011817            2.25
# 819            0.000620  1596.368689       -0.009382            2.25
# 1211           0.000270  3663.000000       -0.010720            2.25
# 1444           0.000203  4879.116000       -0.011777            2.50
# 1486           0.000607  1624.745628       -0.012360            2.50
# 751            0.000252  3932.500000       -0.008758            2.50
# 156            0.000131  7619.040000        0.000130            2.50
# 1493           0.000486  2030.932035       -0.012481            2.50
# 177            0.000105  9523.800000        0.000104            2.50
# 1458           0.000162  6098.895000       -0.011817            2.50
# 254            0.000234  4262.400000       -0.000766            2.50
# 1801           0.001559   627.942229       -0.019322            2.50
# 13             0.000437  2288.000000        0.001437            2.86
# 1119           0.000433  2283.426288       -0.010558            2.86
# 636            0.000101  9837.096257       -0.003893            2.86
# 1567           0.000186  5317.349328       -0.012781            2.86
# 279            0.000197  5074.280640       -0.000804            2.86
# 2015           0.000585  1672.838099       -0.021275            2.86

# %%
df.loc[150:500,:].sample(50).sort_values(by = ['Total Probability'],ascending = False)
# Out:
#     Match 7 (Paysandu vs Santos - Sat 00:00)  \
# 193                                      win
# 366                                      win
# 367                                     draw
# 197                                     loss
# 202                                      win
# 207                                     loss
# 204                                     draw
# 205                                     loss
# 210                                     draw
# 218                                     loss
# 221                                     draw
# 232                                     loss
# 230                                     loss
# 225                                      win
# 384                                     draw
# 393                                      win
# 239                                      win
# 246                                     draw
# 250                                     draw
# 400                                      win
# 404                                     draw
# 416                                     draw
# 415                                     loss
# 254                                      win
# 420                                     draw
# 421                                     loss
# 424                                      win
# 271                                     loss
# 445                                     loss
# 442                                     draw
# 438                                     loss
# 444                                     draw
# 288                                     loss
# 289                                     draw
# 300                                     draw
# 465                                     loss
# 467                                      win
# 469                                     draw
# 319                                     draw
# 477                                     draw
# 485                                     draw
# 484                                     loss
# 482                                     loss
# 168                                     loss
# 170                                     loss
# 349                                     loss
# 345                                     loss
# 353                                     loss
# 500                                     draw
# 191                                     loss
#
#     Match 1 (Jahn Regensburg vs Ulm - Fri 17:30)  \
# 193                                         draw
# 366                                         draw
# 367                                         draw
# 197                                         draw
# 202                                         draw
# 207                                         draw
# 204                                         draw
# 205                                         draw
# 210                                         loss
# 218                                         draw
# 221                                         draw
# 232                                         loss
# 230                                         loss
# 225                                         draw
# 384                                         draw
# 393                                         loss
# 239                                         draw
# 246                                         draw
# 250                                         loss
# 400                                         draw
# 404                                         draw
# 416                                         loss
# 415                                         draw
# 254                                         loss
# 420                                         loss
# 421                                         loss
# 424                                         loss
# 271                                         loss
# 445                                         loss
# 442                                         loss
# 438                                         draw
# 444                                         loss
# 288                                         draw
# 289                                         loss
# 300                                         loss
# 465                                         loss
# 467                                         draw
# 469                                         loss
# 319                                         draw
# 477                                         draw
# 485                                         loss
# 484                                         loss
# 482                                         draw
# 168                                         loss
# 170                                         loss
# 349                                         loss
# 345                                         draw
# 353                                         loss
# 500                                         draw
# 191                                         loss
#
#     Match 3 (Queen's Park vs Livingston - Fri 19:45)  \
# 193                                              win
# 366                                             draw
# 367                                              win
# 197                                             draw
# 202                                             loss
# 207                                              win
# 204                                              win
# 205                                              win
# 210                                              win
# 218                                             draw
# 221                                              win
# 232                                              win
# 230                                              win
# 225                                             loss
# 384                                             draw
# 393                                             loss
# 239                                              win
# 246                                             loss
# 250                                             loss
# 400                                             draw
# 404                                             draw
# 416                                              win
# 415                                              win
# 254                                             loss
# 420                                              win
# 421                                              win
# 424                                              win
# 271                                             draw
# 445                                              win
# 442                                              win
# 438                                              win
# 444                                              win
# 288                                             draw
# 289                                             draw
# 300                                              win
# 465                                             loss
# 467                                              win
# 469                                             loss
# 319                                             draw
# 477                                             draw
# 485                                             loss
# 484                                             loss
# 482                                             loss
# 168                                             draw
# 170                                             draw
# 349                                             loss
# 345                                             loss
# 353                                             loss
# 500                                             loss
# 191                                             loss
#
#     Match 2 (FCSB vs FCV Farul Constanța - Fri 19:00)  \
# 193                                               win
# 366                                               win
# 367                                               win
# 197                                               win
# 202                                               win
# 207                                               win
# 204                                               win
# 205                                               win
# 210                                               win
# 218                                               win
# 221                                               win
# 232                                               win
# 230                                               win
# 225                                               win
# 384                                               win
# 393                                               win
# 239                                              draw
# 246                                               win
# 250                                               win
# 400                                              draw
# 404                                               win
# 416                                              draw
# 415                                              draw
# 254                                               win
# 420                                               win
# 421                                               win
# 424                                              draw
# 271                                               win
# 445                                              draw
# 442                                              draw
# 438                                              loss
# 444                                              draw
# 288                                              draw
# 289                                              draw
# 300                                              loss
# 465                                              draw
# 467                                              loss
# 469                                               win
# 319                                              loss
# 477                                              loss
# 485                                              draw
# 484                                              draw
# 482                                              loss
# 168                                              loss
# 170                                              loss
# 349                                              draw
# 345                                              loss
# 353                                              loss
# 500                                              loss
# 191                                              loss
#
#     Match 4 (Ayr United vs Airdrieonians - Fri 19:45)  \
# 193                                              draw
# 366                                              draw
# 367                                              draw
# 197                                              draw
# 202                                              draw
# 207                                              loss
# 204                                              loss
# 205                                              loss
# 210                                              draw
# 218                                              draw
# 221                                              loss
# 232                                              draw
# 230                                              draw
# 225                                              draw
# 384                                              loss
# 393                                              draw
# 239                                              loss
# 246                                              loss
# 250                                              draw
# 400                                              loss
# 404                                              loss
# 416                                              draw
# 415                                              loss
# 254                                              loss
# 420                                              loss
# 421                                              loss
# 424                                              loss
# 271                                              loss
# 445                                              draw
# 442                                              draw
# 438                                              draw
# 444                                              draw
# 288                                              loss
# 289                                              draw
# 300                                              draw
# 465                                              draw
# 467                                              loss
# 469                                              loss
# 319                                              draw
# 477                                              loss
# 485                                              draw
# 484                                              draw
# 482                                              draw
# 168                                              draw
# 170                                              draw
# 349                                              loss
# 345                                              loss
# 353                                              draw
# 500                                              draw
# 191                                              loss
#
#     Match 5 (Blackburn Rovers vs Derby County - Fri 20:00)  \
# 193                                               draw
# 366                                               draw
# 367                                               draw
# 197                                               draw
# 202                                               draw
# 207                                               draw
# 204                                               draw
# 205                                               draw
# 210                                               draw
# 218                                               loss
# 221                                               loss
# 232                                               loss
# 230                                               loss
# 225                                               loss
# 384                                               draw
# 393                                               draw
# 239                                               loss
# 246                                               draw
# 250                                               draw
# 400                                               draw
# 404                                               loss
# 416                                               draw
# 415                                               draw
# 254                                               draw
# 420                                               loss
# 421                                               loss
# 424                                               draw
# 271                                               loss
# 445                                               loss
# 442                                               loss
# 438                                               draw
# 444                                               loss
# 288                                               loss
# 289                                               loss
# 300                                               draw
# 465                                               draw
# 467                                               loss
# 469                                               loss
# 319                                               loss
# 477                                               draw
# 485                                               loss
# 484                                               loss
# 482                                               draw
# 168                                               loss
# 170                                               loss
# 349                                               loss
# 345                                               draw
# 353                                               draw
# 500                                               loss
# 191                                               loss
#
#     Match 6 (Preston North End vs Sheffield United - Fri 20:00)  \
# 193                                               loss
# 366                                               draw
# 367                                                win
# 197                                                win
# 202                                               loss
# 207                                               loss
# 204                                                win
# 205                                                win
# 210                                               loss
# 218                                               loss
# 221                                                win
# 232                                               loss
# 230                                                win
# 225                                                win
# 384                                               draw
# 393                                               draw
# 239                                               loss
# 246                                               loss
# 250                                                win
# 400                                               draw
# 404                                               draw
# 416                                                win
# 415                                               loss
# 254                                               draw
# 420                                               draw
# 421                                               draw
# 424                                               draw
# 271                                               draw
# 445                                               loss
# 442                                                win
# 438                                                win
# 444                                               loss
# 288                                               loss
# 289                                                win
# 300                                               loss
# 465                                               loss
# 467                                               draw
# 469                                               draw
# 319                                                win
# 477                                               draw
# 485                                               loss
# 484                                                win
# 482                                               loss
# 168                                                win
# 170                                               loss
# 349                                               loss
# 345                                               loss
# 353                                               loss
# 500                                               loss
# 191                                               loss
#
#      Total Probability    Total Odds  Expected Value  Desired Column
# 193           0.000630   1585.712700       -0.000371            2.20
# 366           0.000473   2112.169316       -0.001527            2.50
# 367           0.000472   2112.169316       -0.001527            2.00
# 197           0.000413   2416.321698       -0.000589            2.20
# 202           0.000394   2537.140320       -0.000607            2.86
# 207           0.000394   2537.140320       -0.000607            2.20
# 204           0.000394   2537.140320       -0.000607            2.20
# 205           0.000394   2537.140320       -0.000607            2.50
# 210           0.000394   2537.140320       -0.000607            2.25
# 218           0.000331   3020.402122       -0.000671            2.20
# 221           0.000315   3171.425400       -0.000686            2.20
# 232           0.000315   3171.425400       -0.000686            2.20
# 230           0.000315   3171.425400       -0.000686            2.86
# 225           0.000315   3171.425400       -0.000686            2.20
# 384           0.000295   3379.470906       -0.001705            2.86
# 393           0.000281   3548.448000       -0.001718            2.20
# 239           0.000252   3964.281750       -0.000749            2.20
# 246           0.000246   4059.424512       -0.000755            2.20
# 250           0.000246   4059.424512       -0.000755            1.80
# 400           0.000236   4224.338633       -0.001764            2.20
# 404           0.000236   4224.338633       -0.001764            1.80
# 416           0.000236   4224.338633       -0.001764            2.00
# 415           0.000236   4224.338633       -0.001764            2.50
# 254           0.000234   4262.400000       -0.000766            2.50
# 420           0.000225   4435.560000       -0.001774            2.25
# 421           0.000225   4435.560000       -0.001774            2.20
# 424           0.000225   4435.560000       -0.001774            2.20
# 271           0.000197   5074.280640       -0.000804            1.80
# 445           0.000189   5280.423291       -0.001811            2.20
# 442           0.000189   5280.423291       -0.001811            2.20
# 438           0.000189   5280.423291       -0.001811            2.20
# 444           0.000189   5280.423291       -0.001811            2.00
# 288           0.000165   6040.804245       -0.000837            2.20
# 289           0.000165   6040.804245       -0.000837            2.50
# 300           0.000158   6342.850800       -0.000843            2.86
# 465           0.000148   6758.941812       -0.001852            2.00
# 467           0.000144   6930.562500       -0.001855            1.80
# 469           0.000141   7096.896000       -0.001858            2.25
# 319           0.000132   7551.005306       -0.000870            2.20
# 477           0.000118   8448.677266       -0.001882            2.20
# 485           0.000118   8448.677266       -0.001882            2.50
# 484           0.000118   8448.677266       -0.001882            2.20
# 482           0.000118   8448.677266       -0.001882            2.86
# 168           0.000110   9070.276644        0.000108            2.25
# 170           0.000110   9070.276644        0.000108            2.50
# 349           0.000098  10148.561280       -0.000903            2.86
# 345           0.000098  10148.561280       -0.000903            2.50
# 353           0.000098  10148.561280       -0.000903            2.00
# 500           0.000094  10560.846582       -0.001905            2.00
# 191           0.000066  15238.080000        0.000065            2.50

# %%
len(df)
# Out:
# 2187

# %%
df.loc[500:,:].sample(50).sort_values(by = ['Total Probability'],ascending = False)
# Out:
#      Match 7 (Paysandu vs Santos - Sat 00:00)  \
# 2135                                      win
# 1715                                     loss
# 1028                                     draw
# 648                                       win
# 2132                                     loss
# 1893                                     loss
# 1904                                      win
# 1909                                     loss
# 2077                                     loss
# 1932                                      win
# 2023                                      win
# 2027                                      win
# 1076                                      win
# 656                                       win
# 848                                      loss
# 1942                                     draw
# 875                                       win
# 1697                                     loss
# 879                                      draw
# 1839                                     loss
# 2087                                     loss
# 1357                                     draw
# 884                                       win
# 1510                                      win
# 897                                      draw
# 2046                                     draw
# 928                                      loss
# 1536                                     loss
# 1190                                      win
# 1209                                     loss
# 528                                      draw
# 747                                       win
# 973                                       win
# 1606                                     draw
# 1225                                     loss
# 1243                                     loss
# 1438                                     loss
# 614                                       win
# 989                                      loss
# 642                                      draw
# 994                                      draw
# 996                                      draw
# 1250                                     loss
# 1573                                     loss
# 1468                                     draw
# 634                                      draw
# 636                                      draw
# 500                                      draw
# 504                                      draw
# 592                                      draw
#
#      Match 1 (Jahn Regensburg vs Ulm - Fri 17:30)  \
# 2135                                          win
# 1715                                          win
# 1028                                         draw
# 648                                          loss
# 2132                                          win
# 1893                                         draw
# 1904                                         draw
# 1909                                          win
# 2077                                         loss
# 1932                                          win
# 2023                                          win
# 2027                                         loss
# 1076                                         draw
# 656                                          loss
# 848                                          draw
# 1942                                          win
# 875                                          draw
# 1697                                          win
# 879                                          loss
# 1839                                          win
# 2087                                          win
# 1357                                          win
# 884                                           win
# 1510                                         draw
# 897                                          loss
# 2046                                          win
# 928                                          draw
# 1536                                         loss
# 1190                                         draw
# 1209                                         loss
# 528                                          loss
# 747                                          draw
# 973                                           win
# 1606                                          win
# 1225                                         draw
# 1243                                         loss
# 1438                                         loss
# 614                                          draw
# 989                                          draw
# 642                                          draw
# 994                                          loss
# 996                                           win
# 1250                                          win
# 1573                                         loss
# 1468                                          win
# 634                                          loss
# 636                                          draw
# 500                                          draw
# 504                                          loss
# 592                                          loss
#
#      Match 3 (Queen's Park vs Livingston - Fri 19:45)  \
# 2135                                              win
# 1715                                             draw
# 1028                                             draw
# 648                                              draw
# 2132                                             draw
# 1893                                             draw
# 1904                                             loss
# 1909                                              win
# 2077                                              win
# 1932                                             loss
# 2023                                              win
# 2027                                             loss
# 1076                                              win
# 656                                              draw
# 848                                              draw
# 1942                                             loss
# 875                                               win
# 1697                                             draw
# 879                                              loss
# 1839                                             draw
# 2087                                             loss
# 1357                                              win
# 884                                              draw
# 1510                                              win
# 897                                              draw
# 2046                                              win
# 928                                              draw
# 1536                                              win
# 1190                                             loss
# 1209                                              win
# 528                                               win
# 747                                              draw
# 973                                              loss
# 1606                                             loss
# 1225                                              win
# 1243                                             loss
# 1438                                             draw
# 614                                              loss
# 989                                              draw
# 642                                               win
# 994                                               win
# 996                                               win
# 1250                                             loss
# 1573                                             loss
# 1468                                             loss
# 634                                              loss
# 636                                              loss
# 500                                              loss
# 504                                               win
# 592                                              loss
#
#      Match 2 (FCSB vs FCV Farul Constanța - Fri 19:00)  \
# 2135                                               win
# 1715                                               win
# 1028                                               win
# 648                                                win
# 2132                                              loss
# 1893                                              draw
# 1904                                              draw
# 1909                                              draw
# 2077                                              draw
# 1932                                               win
# 2023                                              draw
# 2027                                              draw
# 1076                                              loss
# 656                                                win
# 848                                                win
# 1942                                              draw
# 875                                               loss
# 1697                                              loss
# 879                                                win
# 1839                                              draw
# 2087                                              draw
# 1357                                               win
# 884                                               draw
# 1510                                              draw
# 897                                               draw
# 2046                                              loss
# 928                                               loss
# 1536                                              loss
# 1190                                              draw
# 1209                                              draw
# 528                                                win
# 747                                               loss
# 973                                               loss
# 1606                                              draw
# 1225                                              loss
# 1243                                              loss
# 1438                                              draw
# 614                                               draw
# 989                                               loss
# 642                                               draw
# 994                                               loss
# 996                                               loss
# 1250                                              draw
# 1573                                              draw
# 1468                                              loss
# 634                                               draw
# 636                                               loss
# 500                                               loss
# 504                                               loss
# 592                                               draw
#
#      Match 4 (Ayr United vs Airdrieonians - Fri 19:45)  \
# 2135                                               win
# 1715                                              draw
# 1028                                              draw
# 648                                               loss
# 2132                                               win
# 1893                                               win
# 1904                                               win
# 1909                                              loss
# 2077                                               win
# 1932                                               win
# 2023                                               win
# 2027                                               win
# 1076                                              draw
# 656                                                win
# 848                                                win
# 1942                                              loss
# 875                                               loss
# 1697                                              loss
# 879                                               loss
# 1839                                               win
# 2087                                              loss
# 1357                                              loss
# 884                                               draw
# 1510                                               win
# 897                                               loss
# 2046                                               win
# 928                                               loss
# 1536                                              draw
# 1190                                               win
# 1209                                               win
# 528                                               draw
# 747                                                win
# 973                                               draw
# 1606                                              draw
# 1225                                               win
# 1243                                              draw
# 1438                                               win
# 614                                               draw
# 989                                                win
# 642                                               draw
# 994                                                win
# 996                                               loss
# 1250                                              loss
# 1573                                               win
# 1468                                              loss
# 634                                               draw
# 636                                               draw
# 500                                               draw
# 504                                               loss
# 592                                               loss
#
#      Match 5 (Blackburn Rovers vs Derby County - Fri 20:00)  \
# 2135                                                win
# 1715                                                win
# 1028                                                win
# 648                                                 win
# 2132                                                win
# 1893                                                win
# 1904                                                win
# 1909                                                win
# 2077                                                win
# 1932                                               loss
# 2023                                               loss
# 2027                                                win
# 1076                                                win
# 656                                                loss
# 848                                                loss
# 1942                                                win
# 875                                                 win
# 1697                                                win
# 879                                                 win
# 1839                                               loss
# 2087                                                win
# 1357                                               loss
# 884                                                loss
# 1510                                               loss
# 897                                                 win
# 2046                                               draw
# 928                                                 win
# 1536                                                win
# 1190                                               loss
# 1209                                               loss
# 528                                                loss
# 747                                                loss
# 973                                                draw
# 1606                                               draw
# 1225                                               loss
# 1243                                                win
# 1438                                               loss
# 614                                                draw
# 989                                                loss
# 642                                                loss
# 994                                                loss
# 996                                                loss
# 1250                                               loss
# 1573                                               loss
# 1468                                               loss
# 634                                                loss
# 636                                                draw
# 500                                                loss
# 504                                                loss
# 592                                                loss
#
#      Match 6 (Preston North End vs Sheffield United - Fri 20:00)  \
# 2135                                               draw
# 1715                                               loss
# 1028                                               loss
# 648                                                 win
# 2132                                               loss
# 1893                                                win
# 1904                                                win
# 1909                                               loss
# 2077                                               draw
# 1932                                               draw
# 2023                                               draw
# 2027                                               draw
# 1076                                               loss
# 656                                                 win
# 848                                                 win
# 1942                                               loss
# 875                                                 win
# 1697                                               loss
# 879                                                loss
# 1839                                               loss
# 2087                                               draw
# 1357                                               draw
# 884                                                loss
# 1510                                               draw
# 897                                                loss
# 2046                                               draw
# 928                                                loss
# 1536                                               draw
# 1190                                               loss
# 1209                                               loss
# 528                                                draw
# 747                                                loss
# 973                                                loss
# 1606                                               draw
# 1225                                               loss
# 1243                                                win
# 1438                                               draw
# 614                                                draw
# 989                                                 win
# 642                                                draw
# 994                                                loss
# 996                                                 win
# 1250                                               loss
# 1573                                               draw
# 1468                                               draw
# 634                                                draw
# 636                                                draw
# 500                                                loss
# 504                                                draw
# 592                                                draw
#
#       Total Probability    Total Odds  Expected Value  Desired Column
# 2135           0.002673    362.637000       -0.027998            2.25
# 1715           0.001364    718.365910       -0.018538            2.25
# 1028           0.000910   1087.344764       -0.010082            2.86
# 648            0.000842   1177.862400       -0.007177            2.20
# 2132           0.000819   1186.490242       -0.027913            2.20
# 1893           0.000819   1196.079240       -0.020063            2.00
# 1904           0.000780   1255.884458       -0.020101            2.25
# 1909           0.000780   1255.884458       -0.020101            1.80
# 2077           0.000668   1462.271065       -0.022169            1.80
# 1932           0.000608   1611.720000       -0.020273            2.25
# 2023           0.000583   1677.196125       -0.021276            2.25
# 2027           0.000557   1756.481760       -0.021302            2.20
# 1076           0.000554   1783.926788       -0.010437            1.80
# 656            0.000551   1799.512000       -0.007468            1.80
# 848            0.000496   1995.460862       -0.009506            2.20
# 1942           0.000487   2009.415133       -0.020394            2.00
# 875            0.000462   2142.855000       -0.009539            2.25
# 1697           0.000455   2157.254986       -0.018466            2.00
# 879            0.000451   2194.283520       -0.009550            2.20
# 1839           0.000447   2195.006948       -0.019455            1.80
# 2087           0.000418   2339.633704       -0.022420            2.20
# 1357           0.000405   2439.558000       -0.011574            2.86
# 884            0.000397   2494.326077       -0.009605            2.50
# 1510           0.000389   2538.665044       -0.012578            1.80
# 897            0.000379   2612.239673       -0.009623            2.20
# 2046           0.000365   2683.513800       -0.021495            2.50
# 928            0.000303   3265.299592       -0.009699            2.20
# 1536           0.000297   3323.343330       -0.012670            2.00
# 1190           0.000284   3488.567940       -0.010707            2.25
# 1209           0.000284   3488.567940       -0.010707            1.80
# 528            0.000270   3692.603700       -0.002727            2.00
# 747            0.000265   3745.234350       -0.008746            1.80
# 973            0.000236   4190.472000       -0.009765            2.25
# 1606           0.000228   4328.322353       -0.013726            2.00
# 1225           0.000227   4360.709925       -0.010764            2.25
# 1243           0.000217   4566.852576       -0.010774            2.20
# 1438           0.000213   4646.772496       -0.011767            2.00
# 614            0.000202   4918.548128       -0.003792            1.80
# 989            0.000198   4988.652154       -0.009804            2.50
# 642            0.000194   5118.364146       -0.004796            1.80
# 994            0.000189   5238.090000       -0.009812            2.25
# 996            0.000189   5238.090000       -0.009812            2.50
# 1250           0.000177   5581.708704       -0.010814            2.20
# 1573           0.000152   6498.982512       -0.012815            1.80
# 1468           0.000101   9758.232000       -0.011878            1.80
# 634            0.000101   9837.096257       -0.003893            2.20
# 636            0.000101   9837.096257       -0.003893            2.86
# 500            0.000094  10560.846582       -0.001905            2.00
# 504            0.000090  11088.900000       -0.001909            2.25
# 592            0.000084  11816.331840       -0.002913            2.20

# %%
import itertools
import pandas as pd

# Define probabilities and odds for each match
matches = [
    {'team': 'Jahn Regensburg vs Ulm', 'win': 0.45, 'draw': 0.30, 'loss': 0.25, 'win_odds': 2.20, 'draw_odds': 3.33, 'loss_odds': 4.00},
    {'team': 'FCSB vs FCV Farul Constanța', 'win': 0.50, 'draw': 0.30, 'loss': 0.20, 'win_odds': 2.00, 'draw_odds': 3.33, 'loss_odds': 5.00},
    {'team': 'Queen\'s Park vs Livingston', 'win': 0.40, 'draw': 0.35, 'loss': 0.25, 'win_odds': 2.50, 'draw_odds': 2.86, 'loss_odds': 4.00},
    {'team': 'Ayr United vs Airdrieonians', 'win': 0.45, 'draw': 0.30, 'loss': 0.25, 'win_odds': 2.20, 'draw_odds': 3.33, 'loss_odds': 4.00},
    {'team': 'Blackburn Rovers vs Derby County', 'win': 0.55, 'draw': 0.25, 'loss': 0.20, 'win_odds': 1.80, 'draw_odds': 4.00, 'loss_odds': 5.00},
    {'team': 'Preston North End vs Sheffield United', 'win': 0.35, 'draw': 0.30, 'loss': 0.35, 'win_odds': 2.86, 'draw_odds': 3.33, 'loss_odds': 2.86},
    {'team': 'Paysandu vs Santos', 'win': 0.40, 'draw': 0.30, 'loss': 0.30, 'win_odds': 2.50, 'draw_odds': 3.33, 'loss_odds': 3.33},
]

# Generate all possible combinations of outcomes (win, draw, loss)
outcomes = ['win', 'draw', 'loss']
combinations = list(itertools.product(outcomes, repeat=len(matches)))

# Calculate total probability and total odds for each combination
results = []
for combo in combinations:
    total_prob = 1.0
    total_odds = 1.0
    for i, outcome in enumerate(combo):
        match = matches[i]
        total_prob *= match[outcome]
        total_odds *= match[f'{outcome}_odds']
    expected_value = (total_prob * total_odds) - (1 - total_prob)  # Calculate expected value
    results.append((combo, total_prob, total_odds, expected_value))

# Sort the results by expected value in descending order
results.sort(key=lambda x: x[3], reverse=True)

# Create a DataFrame with each match in its own column, including team names and outcomes
columns = [
    'Match 7 (Paysandu vs Santos - Sat 00:00)',
    'Match 1 (Jahn Regensburg vs Ulm - Fri 17:30)',
    'Match 3 (Queen\'s Park vs Livingston - Fri 19:45)',
    'Match 2 (FCSB vs FCV Farul Constanța - Fri 19:00)',
    'Match 4 (Ayr United vs Airdrieonians - Fri 19:45)',
    'Match 5 (Blackburn Rovers vs Derby County - Fri 20:00)',
    'Match 6 (Preston North End vs Sheffield United - Fri 20:00)',
]
columns.extend(['Total Probability', 'Total Odds', 'Expected Value'])
data = []

for combo, prob, odds, ev in results:
    reordered_combo = [combo[6], combo[0], combo[2], combo[1], combo[3], combo[4], combo[5]]
    data.append(reordered_combo + [prob, odds, ev])

df = pd.DataFrame(data, columns=columns)

# Extend the list to match the number of rows in the DataFrame
desired_column_values = [2.25, 2.20, 2.50, 2.00, 2.20, 1.80, 2.86]
desired_column_values *= (len(df) // len(desired_column_values)) + 1
desired_column_values = desired_column_values[:len(df)]

# Add the desired column to the DataFrame
df['Desired Column'] = desired_column_values

# Sort by multiple columns
df_sorted = df.sort_values(by=['Expected Value', 'Total Probability', 'Total Odds'], ascending=[False, False, True])
df_sorted.head(100).sample(10)

# %%
import itertools
import pandas as pd

# Step 1: Define probabilities and odds for each match
matches = [
    {'team': 'Šibenik vs Slaven Koprivnica - Fri 17:30', 'win': 0.42, 'draw': 0.32, 'loss': 0.31, 'win_odds': 2.30, 'draw_odds': 3.10, 'loss_odds': 3.20},
    {'team': 'Standard Liège vs Mechelen - Fri 19:45', 'win': 0.57, 'draw': 0.26, 'loss': 0.21, 'win_odds': 1.75, 'draw_odds': 3.70, 'loss_odds': 4.75},
    {'team': 'Kaiserslautern vs Greuther Fürth - Fri 17:30', 'win': 0.45, 'draw': 0.29, 'loss': 0.31, 'win_odds': 2.20, 'draw_odds': 3.40, 'loss_odds': 3.20},
    {'team': 'Eindhoven vs Den Bosch - Fri 19:00', 'win': 0.56, 'draw': 0.27, 'loss': 0.22, 'win_odds': 1.80, 'draw_odds': 3.60, 'loss_odds': 4.50},
    {'team': 'Emmen vs Dordrecht - Fri 19:00', 'win': 0.63, 'draw': 0.23, 'loss': 0.17, 'win_odds': 1.55, 'draw_odds': 4.20, 'loss_odds': 5.75},
    {'team': 'MVV vs Cambuur - Fri 19:00', 'win': 0.32, 'draw': 0.28, 'loss': 0.47, 'win_odds': 3.10, 'draw_odds': 3.50, 'loss_odds': 2.10},
    {'team': 'Vitesse vs Telstar - Fri 19:00', 'win': 0.67, 'draw': 0.21, 'loss': 0.14, 'win_odds': 1.45, 'draw_odds': 4.60, 'loss_odds': 7.00},
]

# Step 2: Generate all possible combinations of outcomes (win, draw, loss)
outcomes = ['win', 'draw', 'loss']
combinations = list(itertools.product(outcomes, repeat=len(matches)))

# Step 3: Calculate total probability, total odds, and expected value for each combination
results = []
for combo in combinations:
    total_prob = 1.0
    total_odds = 1.0
    for i, outcome in enumerate(combo):
        match = matches[i]
        total_prob *= match[outcome]
        total_odds *= match[f'{outcome}_odds']
    expected_value = (total_prob * total_odds) - (1 - total_prob)
    results.append((combo, total_prob, total_odds, expected_value))

# Step 4: Convert results to DataFrame
df = pd.DataFrame(results, columns=['Combo', 'Total Probability', 'Total Odds', 'Expected Value'])

# Step 5: Sort by Expected Value, Total Probability, and Total Odds
df_sorted = df.sort_values(by=['Expected Value', 'Total Probability', 'Total Odds'], ascending=[False, False, True])

# Check the columns of the DataFrame
print(df_sorted.columns)

# Step 6: Reorder the columns to match the desired sequence of matches
# You don't need to rename the columns for the "Combo" column since it's a tuple, but let's add labels for clarity:
df_sorted[['Šibenik vs Slaven Koprivnica', 
           'Standard Liège vs Mechelen', 
           'Kaiserslautern vs Greuther Fürth', 
           'Eindhoven vs Den Bosch', 
           'Emmen vs Dordrecht', 
           'MVV vs Cambuur', 
           'Vitesse vs Telstar']] = pd.DataFrame(df_sorted['Combo'].tolist(), index=df_sorted.index)

# Now drop the original 'Combo' column
df_sorted = df_sorted.drop(columns=['Combo'])

# Reorder the columns correctly
columns_order = [
    'Šibenik vs Slaven Koprivnica', 
    'Standard Liège vs Mechelen', 
    'Kaiserslautern vs Greuther Fürth', 
    'Eindhoven vs Den Bosch', 
    'Emmen vs Dordrecht', 
    'MVV vs Cambuur', 
    'Vitesse vs Telstar',
    'Total Probability', 
    'Total Odds', 
    'Expected Value'
]

df_sorted = df_sorted[columns_order]

# Step 7: Determine best bets by looking at the top results
df_sorted.head(10) # Display the top 10 combinations
# Out:
# Index(['Combo', 'Total Probability', 'Total Odds', 'Expected Value'], dtype='object')
#      Šibenik vs Slaven Koprivnica Standard Liège vs Mechelen  \
# 911                          draw                        win
# 1640                         loss                        win
# 1397                         draw                       loss
# 2126                         loss                       loss
# 893                          draw                        win
# 1622                         loss                        win
# 1379                         draw                       loss
# 2108                         loss                       loss
# 749                          draw                        win
# 1478                         loss                        win
#
#      Kaiserslautern vs Greuther Fürth Eindhoven vs Den Bosch  \
# 911                              loss                    win
# 1640                             loss                    win
# 1397                             loss                    win
# 2126                             loss                    win
# 893                              loss                    win
# 1622                             loss                    win
# 1379                             loss                    win
# 2108                             loss                    win
# 749                               win                    win
# 1478                              win                    win
#
#      Emmen vs Dordrecht MVV vs Cambuur Vitesse vs Telstar  Total Probability  \
# 911                loss            win               loss           0.000241
# 1640               loss            win               loss           0.000234
# 1397               loss            win               loss           0.000089
# 2126               loss            win               loss           0.000086
# 893                 win            win               loss           0.000894
# 1622                win            win               loss           0.000866
# 1379                win            win               loss           0.000329
# 2108                win            win               loss           0.000319
# 749                loss            win               loss           0.000350
# 1478               loss            win               loss           0.000339
#
#         Total Odds  Expected Value
# 911    3898.969200       -0.059492
# 1640   4024.742400       -0.059499
# 1397  10582.916400       -0.059644
# 2126  10924.300800       -0.059647
# 893    1051.026480       -0.059801
# 1622   1084.930560       -0.059829
# 1379   2852.786160       -0.060365
# 2108   2944.811520       -0.060376
# 749    2680.541325       -0.061278
# 1478   2767.010400       -0.061289

# %%
len(df)
# Out:
# 2187

# %%
import itertools
import pandas as pd

# Step 1: Define probabilities and odds for each match
matches = [
    {'team': 'Šibenik vs Slaven Koprivnica - Fri 17:30', 'win': 0.42, 'draw': 0.32, 'loss': 0.31, 'win_odds': 2.30, 'draw_odds': 3.10, 'loss_odds': 3.20},
    {'team': 'Standard Liège vs Mechelen - Fri 19:45', 'win': 0.57, 'draw': 0.26, 'loss': 0.21, 'win_odds': 1.75, 'draw_odds': 3.70, 'loss_odds': 4.75},
    {'team': 'Kaiserslautern vs Greuther Fürth - Fri 17:30', 'win': 0.45, 'draw': 0.29, 'loss': 0.31, 'win_odds': 2.20, 'draw_odds': 3.40, 'loss_odds': 3.20},
    {'team': 'Eindhoven vs Den Bosch - Fri 19:00', 'win': 0.56, 'draw': 0.27, 'loss': 0.22, 'win_odds': 1.80, 'draw_odds': 3.60, 'loss_odds': 4.50},
    {'team': 'Emmen vs Dordrecht - Fri 19:00', 'win': 0.63, 'draw': 0.23, 'loss': 0.17, 'win_odds': 1.55, 'draw_odds': 4.20, 'loss_odds': 5.75},
    {'team': 'MVV vs Cambuur - Fri 19:00', 'win': 0.32, 'draw': 0.28, 'loss': 0.47, 'win_odds': 3.10, 'draw_odds': 3.50, 'loss_odds': 2.10},
    {'team': 'Vitesse vs Telstar - Fri 19:00', 'win': 0.67, 'draw': 0.21, 'loss': 0.14, 'win_odds': 1.45, 'draw_odds': 4.60, 'loss_odds': 7.00},
]

# Step 2: Generate all possible combinations of outcomes (win, draw, loss)
outcomes = ['win', 'draw', 'loss']
combinations = list(itertools.product(outcomes, repeat=len(matches)))

# Step 3: Calculate total probability, total odds, and expected value for each combination
results = []
for combo in combinations:
    total_prob = 1.0
    total_odds = 1.0
    for i, outcome in enumerate(combo):
        match = matches[i]
        total_prob *= match[outcome]
        total_odds *= match[f'{outcome}_odds']
    expected_value = (total_prob * total_odds) - (1 - total_prob)
    results.append((combo, total_prob, total_odds, expected_value))

# Step 4: Convert results to DataFrame
df = pd.DataFrame(results, columns=['Combo', 'Total Probability', 'Total Odds', 'Expected Value'])

# Step 5: Sort by Expected Value, Total Probability, and Total Odds
df_sorted = df.sort_values(by=['Total Probability'], ascending=[False])

# Check the columns of the DataFrame
print(df_sorted.columns)

# Step 6: Reorder the columns to match the desired sequence of matches
# You don't need to rename the columns for the "Combo" column since it's a tuple, but let's add labels for clarity:
df_sorted[['Šibenik vs Slaven Koprivnica', 
           'Standard Liège vs Mechelen', 
           'Kaiserslautern vs Greuther Fürth', 
           'Eindhoven vs Den Bosch', 
           'Emmen vs Dordrecht', 
           'MVV vs Cambuur', 
           'Vitesse vs Telstar']] = pd.DataFrame(df_sorted['Combo'].tolist(), index=df_sorted.index)

# Now drop the original 'Combo' column
df_sorted = df_sorted.drop(columns=['Combo'])

# Reorder the columns correctly
columns_order = [
    'Šibenik vs Slaven Koprivnica', 
    'Standard Liège vs Mechelen', 
    'Kaiserslautern vs Greuther Fürth', 
    'Eindhoven vs Den Bosch', 
    'Emmen vs Dordrecht', 
    'MVV vs Cambuur', 
    'Vitesse vs Telstar',
    'Total Probability', 
    'Total Odds', 
    'Expected Value'
]

df_sorted = df_sorted[columns_order]

# Step 7: Determine best bets by looking at the top results

df_sorted.head(10)  # Display the top 10 combinations
# Out:
# Index(['Combo', 'Total Probability', 'Total Odds', 'Expected Value'], dtype='object')
#      Šibenik vs Slaven Koprivnica Standard Liège vs Mechelen  \
# 6                             win                        win
# 735                          draw                        win
# 1464                         loss                        win
# 168                           win                        win
# 0                             win                        win
# 87                            win                        win
# 3                             win                        win
# 897                          draw                        win
# 729                          draw                        win
# 1626                         loss                        win
#
#      Kaiserslautern vs Greuther Fürth Eindhoven vs Den Bosch  \
# 6                                 win                    win
# 735                               win                    win
# 1464                              win                    win
# 168                              loss                    win
# 0                                 win                    win
# 87                               draw                    win
# 3                                 win                    win
# 897                              loss                    win
# 729                               win                    win
# 1626                             loss                    win
#
#      Emmen vs Dordrecht MVV vs Cambuur Vitesse vs Telstar  Total Probability  \
# 6                   win           loss                win           0.011968
# 735                 win           loss                win           0.009119
# 1464                win           loss                win           0.008834
# 168                 win           loss                win           0.008245
# 0                   win            win                win           0.008149
# 87                  win           loss                win           0.007713
# 3                   win           draw                win           0.007130
# 897                 win           loss                win           0.006282
# 729                 win            win                win           0.006209
# 1626                win           loss                win           0.006086
#
#       Total Odds  Expected Value
# 6      75.228095       -0.087668
# 735   101.394389       -0.066284
# 1464  104.665176       -0.066569
# 168   109.422684       -0.089572
# 0     111.050998       -0.086926
# 87    116.261602       -0.095561
# 3     125.380159       -0.098892
# 897   147.482748       -0.067253
# 729   149.677432       -0.064511
# 1626  152.240256       -0.067450

# %%
import itertools
import pandas as pd

# Step 1: Define probabilities and odds for each match
matches = [
    {'team': 'Sassuolo vs Cittadella - Fri 17:00', 'win': 0.60, 'draw': 0.26, 'loss': 0.20, 'win_odds': 1.67, 'draw_odds': 3.75, 'loss_odds': 5.00},
    {'team': 'Udinese vs Avellino - Fri 17:30', 'win': 0.70, 'draw': 0.21, 'loss': 0.12, 'win_odds': 1.35, 'draw_odds': 4.80, 'loss_odds': 7.50},
    {'team': 'Jahn Regensburg vs Ulm - Fri 17:30', 'win': 0.54, 'draw': 0.29, 'loss': 0.24, 'win_odds': 1.85, 'draw_odds': 3.40, 'loss_odds': 4.20},
    {'team': 'Vitesse vs Telstar - Fri 19:00', 'win': 0.67, 'draw': 0.21, 'loss': 0.14, 'win_odds': 1.45, 'draw_odds': 4.60, 'loss_odds': 7.00},
    {'team': 'Queen\'s Park vs Livingston - Fri 19:45', 'win': 0.36, 'draw': 0.31, 'loss': 0.40, 'win_odds': 2.75, 'draw_odds': 3.25, 'loss_odds': 2.50},
    {'team': 'Barnsley vs Mansfield Town - Fri 20:00', 'win': 0.47, 'draw': 0.29, 'loss': 0.29, 'win_odds': 2.10, 'draw_odds': 3.40, 'loss_odds': 3.50},
    {'team': 'Chesterfield vs Swindon Town - Fri 20:00', 'win': 0.45, 'draw': 0.28, 'loss': 0.32, 'win_odds': 2.20, 'draw_odds': 3.50, 'loss_odds': 3.10},
]

# Step 2: Generate all possible combinations of outcomes (win, draw, loss)
outcomes = ['win', 'draw', 'loss']
combinations = list(itertools.product(outcomes, repeat=len(matches)))

# Step 3: Calculate total probability, total odds, and expected value for each combination
results = []
for combo in combinations:
    total_prob = 1.0
    total_odds = 1.0
    for i, outcome in enumerate(combo):
        match = matches[i]
        total_prob *= match[outcome]
        total_odds *= match[f'{outcome}_odds']
    expected_value = (total_prob * total_odds) - (1 - total_prob)
    results.append((combo, total_prob, total_odds, expected_value))

# Step 4: Convert results to DataFrame
df = pd.DataFrame(results, columns=['Combo', 'Total Probability', 'Total Odds', 'Expected Value'])

# Step 5: Sort by Expected Value, Total Probability, and Total Odds
df_sorted = df.sort_values(by=['Expected Value', 'Total Probability', 'Total Odds'], ascending=[False, False, True])

# Step 6: Reorder the columns to match the desired sequence of matches
df_sorted[['Sassuolo vs Cittadella', 
           'Udinese vs Avellino', 
           'Jahn Regensburg vs Ulm', 
           'Vitesse vs Telstar', 
           'Queen\'s Park vs Livingston', 
           'Barnsley vs Mansfield Town', 
           'Chesterfield vs Swindon Town']] = pd.DataFrame(df_sorted['Combo'].tolist(), index=df_sorted.index)

# Drop the original 'Combo' column
df_sorted = df_sorted.drop(columns=['Combo'])

# Reorder the columns correctly
columns_order = [
    'Sassuolo vs Cittadella', 
    'Udinese vs Avellino', 
    'Jahn Regensburg vs Ulm', 
    'Vitesse vs Telstar', 
    'Queen\'s Park vs Livingston', 
    'Barnsley vs Mansfield Town', 
    'Chesterfield vs Swindon Town',
    'Total Probability', 
    'Total Odds', 
    'Expected Value'
]

df_sorted = df_sorted[columns_order]

# Step 7: Determine best bets by looking at the top results
df_sorted.head(60) # Display the top 10 combinations
# Out:
#      Sassuolo vs Cittadella Udinese vs Avellino Jahn Regensburg vs Ulm  \
# 476                     win                draw                   loss
# 474                     win                draw                   loss
# 1934                   loss                draw                   loss
# 1932                   loss                draw                   loss
# 485                     win                draw                   loss
# 422                     win                draw                   loss
# 314                     win                draw                    win
# 483                     win                draw                   loss
# 1943                   loss                draw                   loss
# 420                     win                draw                   loss
# 1880                   loss                draw                   loss
# 312                     win                draw                    win
# 1772                   loss                draw                    win
# 1941                   loss                draw                   loss
# 475                     win                draw                   loss
# 1878                   loss                draw                   loss
# 1770                   loss                draw                    win
# 1933                   loss                draw                   loss
# 449                     win                draw                   loss
# 431                     win                draw                   loss
# 323                     win                draw                    win
# 447                     win                draw                   loss
# 1907                   loss                draw                   loss
# 260                     win                draw                    win
# 429                     win                draw                   loss
# 467                     win                draw                   loss
# 258                     win                draw                    win
# 1889                   loss                draw                   loss
# 321                     win                draw                    win
# 1905                   loss                draw                   loss
# 1781                   loss                draw                    win
# 1718                   loss                draw                    win
# 465                     win                draw                   loss
# 1925                   loss                draw                   loss
# 484                     win                draw                   loss
# 1887                   loss                draw                   loss
# 1779                   loss                draw                    win
# 421                     win                draw                   loss
# 313                     win                draw                    win
# 1716                   loss                draw                    win
# 1923                   loss                draw                   loss
# 1942                   loss                draw                   loss
# 458                     win                draw                   loss
# 395                     win                draw                   draw
# 1879                   loss                draw                   loss
# 287                     win                draw                    win
# 1771                   loss                draw                    win
# 269                     win                draw                    win
# 456                     win                draw                   loss
# 1916                   loss                draw                   loss
# 393                     win                draw                   draw
# 1853                   loss                draw                   draw
# 267                     win                draw                    win
# 285                     win                draw                    win
# 1745                   loss                draw                    win
# 413                     win                draw                   loss
# 1914                   loss                draw                   loss
# 1851                   loss                draw                   draw
# 305                     win                draw                    win
# 448                     win                draw                   loss
#
#      Vitesse vs Telstar Queen's Park vs Livingston Barnsley vs Mansfield Town  \
# 476                loss                       draw                       loss
# 474                loss                       draw                       loss
# 1934               loss                       draw                       loss
# 1932               loss                       draw                       loss
# 485                loss                       loss                       loss
# 422                 win                       draw                       loss
# 314                loss                       draw                       loss
# 483                loss                       loss                       loss
# 1943               loss                       loss                       loss
# 420                 win                       draw                       loss
# 1880                win                       draw                       loss
# 312                loss                       draw                       loss
# 1772               loss                       draw                       loss
# 1941               loss                       loss                       loss
# 475                loss                       draw                       loss
# 1878                win                       draw                       loss
# 1770               loss                       draw                       loss
# 1933               loss                       draw                       loss
# 449                draw                       draw                       loss
# 431                 win                       loss                       loss
# 323                loss                       loss                       loss
# 447                draw                       draw                       loss
# 1907               draw                       draw                       loss
# 260                 win                       draw                       loss
# 429                 win                       loss                       loss
# 467                loss                        win                       loss
# 258                 win                       draw                       loss
# 1889                win                       loss                       loss
# 321                loss                       loss                       loss
# 1905               draw                       draw                       loss
# 1781               loss                       loss                       loss
# 1718                win                       draw                       loss
# 465                loss                        win                       loss
# 1925               loss                        win                       loss
# 484                loss                       loss                       loss
# 1887                win                       loss                       loss
# 1779               loss                       loss                       loss
# 421                 win                       draw                       loss
# 313                loss                       draw                       loss
# 1716                win                       draw                       loss
# 1923               loss                        win                       loss
# 1942               loss                       loss                       loss
# 458                draw                       loss                       loss
# 395                loss                       draw                       loss
# 1879                win                       draw                       loss
# 287                draw                       draw                       loss
# 1771               loss                       draw                       loss
# 269                 win                       loss                       loss
# 456                draw                       loss                       loss
# 1916               draw                       loss                       loss
# 393                loss                       draw                       loss
# 1853               loss                       draw                       loss
# 267                 win                       loss                       loss
# 285                draw                       draw                       loss
# 1745               draw                       draw                       loss
# 413                 win                        win                       loss
# 1914               draw                       loss                       loss
# 1851               loss                       draw                       loss
# 305                loss                        win                       loss
# 448                draw                       draw                       loss
#
#      Chesterfield vs Swindon Town  Total Probability    Total Odds  \
# 476                          loss           0.000122   8310.327480
# 474                           win           0.000171   5897.651760
# 1934                         loss           0.000041  24881.220000
# 1932                          win           0.000057  17657.640000
# 485                          loss           0.000157   6392.559600
# 422                          loss           0.000583   1721.424978
# 314                          loss           0.000274   3660.501390
# 483                           win           0.000221   4536.655200
# 1943                         loss           0.000052  19139.400000
# 420                           win           0.000820   1221.656436
# 1880                         loss           0.000194   5153.967000
# 312                           win           0.000385   2597.775180
# 1772                         loss           0.000091  10959.585000
# 1941                          win           0.000074  13582.800000
# 475                          draw           0.000107   9382.627800
# 1878                          win           0.000273   3657.654000
# 1770                          win           0.000128   7777.770000
# 1933                         draw           0.000036  28091.700000
# 449                          loss           0.000183   5461.072344
# 431                          loss           0.000752   1324.173060
# 323                          loss           0.000354   2815.770300
# 447                           win           0.000257   3875.599728
# 1907                         loss           0.000061  16350.516000
# 260                          loss           0.001311    758.246716
# 429                           win           0.001058    939.735720
# 467                          loss           0.000141   7031.815560
# 258                           win           0.001844    538.110573
# 1889                         loss           0.000251   3964.590000
# 321                           win           0.000497   1998.288600
# 1905                          win           0.000086  11603.592000
# 1781                         loss           0.000118   8430.450000
# 1718                         loss           0.000437   2270.199750
# 465                           win           0.000199   4990.320720
# 1925                         loss           0.000047  21053.340000
# 484                          draw           0.000138   7217.406000
# 1887                          win           0.000353   2813.580000
# 1779                          win           0.000166   5982.900000
# 421                          draw           0.000510   1943.544330
# 313                          draw           0.000240   4132.824150
# 1716                          win           0.000615   1611.109500
# 1923                          win           0.000066  14941.080000
# 1942                         draw           0.000046  21609.000000
# 458                          loss           0.000236   4200.824880
# 395                          loss           0.000147   6727.407960
# 1879                         draw           0.000170   5818.995000
# 287                          loss           0.000411   2405.472342
# 1771                         draw           0.000080  12373.725000
# 269                          loss           0.001692    583.266705
# 456                           win           0.000331   2981.230560
# 1916                         loss           0.000079  12577.320000
# 393                           win           0.000207   4774.289520
# 1853                         loss           0.000049  20141.940000
# 267                           win           0.002380    413.931210
# 285                           win           0.000578   1707.109404
# 1745                         loss           0.000137   7202.013000
# 413                          loss           0.000677   1456.590366
# 1914                          win           0.000110   8925.840000
# 1851                          win           0.000069  14294.280000
# 305                          loss           0.000318   3097.347330
# 448                          draw           0.000160   6165.726840
#
#       Expected Value
# 476         0.012255
# 474         0.010264
# 1934        0.010153
# 1932        0.008133
# 485         0.004756
# 422         0.003937
# 314         0.003370
# 483         0.002794
# 1943        0.002646
# 420         0.002151
# 1880        0.001546
# 312         0.001459
# 1772        0.001185
# 1941        0.000646
# 475        -0.000004
# 1878       -0.000394
# 1770       -0.000796
# 1933       -0.002071
# 449        -0.002143
# 431        -0.003363
# 323        -0.004017
# 447        -0.004080
# 1907       -0.004256
# 260        -0.004293
# 429        -0.005065
# 467        -0.005306
# 258        -0.005765
# 1889       -0.005852
# 321        -0.005881
# 1905       -0.006239
# 1781       -0.006240
# 1718       -0.007152
# 465        -0.007254
# 1925       -0.007385
# 484        -0.007416
# 1887       -0.007754
# 1779       -0.008196
# 421        -0.008273
# 313        -0.008798
# 1716       -0.008975
# 1923       -0.009367
# 1942       -0.009489
# 458        -0.009517
# 395        -0.009810
# 1879       -0.010591
# 287        -0.010823
# 1771       -0.010936
# 269        -0.011314
# 456        -0.011418
# 1916       -0.011651
# 393        -0.011746
# 1853       -0.011884
# 267        -0.012617
# 285        -0.012649
# 1745       -0.013070
# 413        -0.013397
# 1914       -0.013611
# 1851       -0.013856
# 305        -0.014009
# 448        -0.014235

# %%
import itertools
import pandas as pd

# Step 1: Define probabilities and odds for each match
matches = [
    {'team': 'Sassuolo vs Cittadella - Fri 17:00', 'win': 0.60, 'draw': 0.26, 'loss': 0.20, 'win_odds': 1.67, 'draw_odds': 3.75, 'loss_odds': 5.00},
    {'team': 'Udinese vs Avellino - Fri 17:30', 'win': 0.70, 'draw': 0.21, 'loss': 0.12, 'win_odds': 1.35, 'draw_odds': 4.80, 'loss_odds': 7.50},
    {'team': 'Jahn Regensburg vs Ulm - Fri 17:30', 'win': 0.54, 'draw': 0.29, 'loss': 0.24, 'win_odds': 1.85, 'draw_odds': 3.40, 'loss_odds': 4.20},
    {'team': 'Vitesse vs Telstar - Fri 19:00', 'win': 0.67, 'draw': 0.21, 'loss': 0.14, 'win_odds': 1.45, 'draw_odds': 4.60, 'loss_odds': 7.00},
    {'team': 'Queen\'s Park vs Livingston - Fri 19:45', 'win': 0.36, 'draw': 0.31, 'loss': 0.40, 'win_odds': 2.75, 'draw_odds': 3.25, 'loss_odds': 2.50},
    {'team': 'Barnsley vs Mansfield Town - Fri 20:00', 'win': 0.47, 'draw': 0.29, 'loss': 0.29, 'win_odds': 2.10, 'draw_odds': 3.40, 'loss_odds': 3.50},
    {'team': 'Chesterfield vs Swindon Town - Fri 20:00', 'win': 0.45, 'draw': 0.28, 'loss': 0.32, 'win_odds': 2.20, 'draw_odds': 3.50, 'loss_odds': 3.10},
]

# Step 2: Generate all possible combinations of outcomes (win, draw, loss)
outcomes = ['win', 'draw', 'loss']
combinations = list(itertools.product(outcomes, repeat=len(matches)))

# Step 3: Calculate total probability, total odds, and expected value for each combination
results = []
for combo in combinations:
    total_prob = 1.0
    total_odds = 1.0
    for i, outcome in enumerate(combo):
        match = matches[i]
        total_prob *= match[outcome]
        total_odds *= match[f'{outcome}_odds']
    expected_value = (total_prob * total_odds) - (1 - total_prob)
    results.append((combo, total_prob, total_odds, expected_value))

# Step 4: Convert results to DataFrame
df = pd.DataFrame(results, columns=['Combo', 'Total Probability', 'Total Odds', 'Expected Value'])

# Step 5: Sort by Expected Value, Total Probability, and Total Odds
df_sorted = df.sort_values(by=['Total Probability'], ascending=[False])

# Step 6: Reorder the columns to match the desired sequence of matches
df_sorted[['Sassuolo vs Cittadella', 
           'Udinese vs Avellino', 
           'Jahn Regensburg vs Ulm', 
           'Vitesse vs Telstar', 
           'Queen\'s Park vs Livingston', 
           'Barnsley vs Mansfield Town', 
           'Chesterfield vs Swindon Town']] = pd.DataFrame(df_sorted['Combo'].tolist(), index=df_sorted.index)

# Drop the original 'Combo' column
df_sorted = df_sorted.drop(columns=['Combo'])

# Reorder the columns correctly
columns_order = [
    'Sassuolo vs Cittadella', 
    'Udinese vs Avellino', 
    'Jahn Regensburg vs Ulm', 
    'Vitesse vs Telstar', 
    'Queen\'s Park vs Livingston', 
    'Barnsley vs Mansfield Town', 
    'Chesterfield vs Swindon Town',
    'Total Probability', 
    'Total Odds', 
    'Expected Value'
]

df_sorted = df_sorted[columns_order]

# Step 7: Determine best bets by looking at the top results
df_sorted.head(10)  # Display the top 10 combinations
# Out:
#    Sassuolo vs Cittadella Udinese vs Avellino Jahn Regensburg vs Ulm  \
# 18                    win                 win                    win
# 0                     win                 win                    win
# 9                     win                 win                    win
# 20                    win                 win                    win
# 2                     win                 win                    win
# 19                    win                 win                    win
# 24                    win                 win                    win
# 21                    win                 win                    win
# 1                     win                 win                    win
# 6                     win                 win                    win
#
#    Vitesse vs Telstar Queen's Park vs Livingston Barnsley vs Mansfield Town  \
# 18                win                       loss                        win
# 0                 win                        win                        win
# 9                 win                       draw                        win
# 20                win                       loss                        win
# 2                 win                        win                        win
# 19                win                       loss                        win
# 24                win                       loss                       loss
# 21                win                       loss                       draw
# 1                 win                        win                        win
# 6                 win                        win                       loss
#
#    Chesterfield vs Swindon Town  Total Probability  Total Odds  Expected Value
# 18                          win           0.012855   69.850892       -0.089178
# 0                           win           0.011570   76.835981       -0.099443
# 9                           win           0.009963   90.806159       -0.085336
# 20                         loss           0.009142   98.426256       -0.091078
# 2                          loss           0.008228  108.268882       -0.100990
# 19                         draw           0.007999  111.126419       -0.103105
# 24                          win           0.007932  116.418153       -0.068627
# 21                          win           0.007932  113.091920       -0.095011
# 1                          draw           0.007199  122.239060       -0.112794
# 6                           win           0.007139  128.059968       -0.078655

# %%
import itertools
import pandas as pd

# Step 1: Define probabilities and odds for each match
matches = [
    {'team': 'FC Emmen vs FC Dordrecht', 'win': 0.44, 'draw': 0.29, 'loss': 0.29, 'win_odds': 2.25, 'draw_odds': 3.40, 'loss_odds': 3.50},
    {'team': 'Preston North End vs Sheffield United', 'win': 0.32, 'draw': 0.31, 'loss': 0.42, 'win_odds': 3.10, 'draw_odds': 3.20, 'loss_odds': 2.37},
    {'team': 'Blackburn Rovers vs Derby County', 'win': 0.44, 'draw': 0.30, 'loss': 0.29, 'win_odds': 2.25, 'draw_odds': 3.30, 'loss_odds': 3.40},
    {'team': 'MVV Maastricht vs SC Cambuur', 'win': 0.42, 'draw': 0.29, 'loss': 0.32, 'win_odds': 2.37, 'draw_odds': 3.40, 'loss_odds': 3.10},
    {'team': 'Jahn Regensburg vs SSV Ulm 1846', 'win': 0.42, 'draw': 0.29, 'loss': 0.32, 'win_odds': 2.37, 'draw_odds': 3.40, 'loss_odds': 3.10},
    {'team': 'FC Schalke 04 II vs SV Rödinghausen', 'win': 0.42, 'draw': 0.29, 'loss': 0.32, 'win_odds': 2.37, 'draw_odds': 3.40, 'loss_odds': 3.10},
    {'team': 'SKN St. Pölten vs Austria Lustenau', 'win': 0.41, 'draw': 0.30, 'loss': 0.31, 'win_odds': 2.45, 'draw_odds': 3.30, 'loss_odds': 3.20},
]

# Step 2: Generate all possible combinations of outcomes (win, draw, loss)
outcomes = ['win', 'draw', 'loss']
combinations = list(itertools.product(outcomes, repeat=len(matches)))

# Step 3: Calculate total probability, total odds, and expected value for each combination
results = []
for combo in combinations:
    total_prob = 1.0
    total_odds = 1.0
    for i, outcome in enumerate(combo):
        match = matches[i]
        total_prob *= match[outcome]
        total_odds *= match[f'{outcome}_odds']
    expected_value = (total_prob * total_odds) - (1 - total_prob)
    results.append((combo, total_prob, total_odds, expected_value))

# Step 4: Convert results to DataFrame
df = pd.DataFrame(results, columns=['Combo', 'Total Probability', 'Total Odds', 'Expected Value'])

# Step 5: Sort by Expected Value, Total Probability, and Total Odds
df_sorted = df.sort_values(by=['Expected Value'], ascending=[False])

# Step 6: Reorder the columns to match the desired sequence of matches
df_sorted[['FC Emmen vs FC Dordrecht', 
           'Preston North End vs Sheffield United', 
           'Blackburn Rovers vs Derby County', 
           'MVV Maastricht vs SC Cambuur', 
           'Jahn Regensburg vs SSV Ulm 1846', 
           'FC Schalke 04 II vs SV Rödinghausen', 
           'SKN St. Pölten vs Austria Lustenau']] = pd.DataFrame(df_sorted['Combo'].tolist(), index=df_sorted.index)

# Drop the original 'Combo' column
df_sorted = df_sorted.drop(columns=['Combo'])

# Reorder the columns correctly
columns_order = [
    'FC Emmen vs FC Dordrecht', 
    'Preston North End vs Sheffield United', 
    'Blackburn Rovers vs Derby County', 
    'MVV Maastricht vs SC Cambuur', 
    'Jahn Regensburg vs SSV Ulm 1846', 
    'FC Schalke 04 II vs SV Rödinghausen', 
    'SKN St. Pölten vs Austria Lustenau',
    'Total Probability', 
    'Total Odds', 
    'Expected Value'
]

df_sorted = df_sorted[columns_order]

# Step7: Determine best bets by looking at the top results
df_sorted.sample(100)# Display the top 10 combinations
# Out:
#      FC Emmen vs FC Dordrecht Preston North End vs Sheffield United  \
# 1897                     loss                                  draw
# 1377                     draw                                  loss
# 674                       win                                  loss
# 469                       win                                  draw
# 758                      draw                                   win
# ...                       ...                                   ...
# 1035                     draw                                  draw
# 866                      draw                                   win
# 1637                     loss                                   win
# 2151                     loss                                  loss
# 369                       win                                  draw
#
#      Blackburn Rovers vs Derby County MVV Maastricht vs SC Cambuur  \
# 1897                             loss                         draw
# 1377                             loss                          win
# 674                              loss                          win
# 469                              loss                         loss
# 758                               win                         draw
# ...                               ...                          ...
# 1035                              win                         loss
# 866                              draw                         loss
# 1637                             loss                          win
# 2151                             loss                         draw
# 369                              draw                         draw
#
#      Jahn Regensburg vs SSV Ulm 1846 FC Schalke 04 II vs SV Rödinghausen  \
# 1897                             win                                loss
# 1377                             win                                 win
# 674                             loss                                loss
# 469                             draw                                 win
# 758                              win                                 win
# ...                              ...                                 ...
# 1035                            draw                                 win
# 866                              win                                 win
# 1637                            draw                                loss
# 2151                            loss                                 win
# 369                             loss                                 win
#
#      SKN St. Pölten vs Austria Lustenau  Total Probability   Total Odds  \
# 1897                               draw           0.000305  3139.061587
# 1377                                win           0.001073   893.546797
# 674                                loss           0.000715  1321.391452
# 469                                draw           0.000463  2017.968163
# 758                                loss           0.000648  1449.268044
# ...                                 ...                ...          ...
# 1035                                win           0.000632  1498.188485
# 866                                loss           0.000487  1938.040797
# 1637                               loss           0.000325  2948.815430
# 2151                                win           0.000564  1726.037984
# 369                                 win           0.000654  1454.124118
#
#       Expected Value
# 1897       -0.042774
# 1377       -0.040201
# 674        -0.055132
# 469        -0.066186
# 758        -0.060910
# ...              ...
# 1035       -0.052346
# 866        -0.055360
# 1637       -0.040821
# 2151       -0.025171
# 369        -0.048482
#
# [100 rows x 10 columns]

# %%
import itertools
import pandas as pd

# Step 1: Define probabilities and odds for each match
matches = [
    {'team': 'Jahn Regensburg vs Ulm', 'win': 0.45, 'draw': 0.30, 'loss': 0.25, 'win_odds': 2.20, 'draw_odds': 3.33, 'loss_odds': 4.00},
    {'team': 'FCSB vs FCV Farul Constanța', 'win': 0.50, 'draw': 0.30, 'loss': 0.20, 'win_odds': 2.00, 'draw_odds': 3.33, 'loss_odds': 5.00},
    {'team': 'Queen\'s Park vs Livingston', 'win': 0.40, 'draw': 0.35, 'loss': 0.25, 'win_odds': 2.50, 'draw_odds': 2.86, 'loss_odds': 4.00},
    {'team': 'Ayr United vs Airdrieonians', 'win': 0.45, 'draw': 0.30, 'loss': 0.25, 'win_odds': 2.20, 'draw_odds': 3.33, 'loss_odds': 4.00},
    {'team': 'Blackburn Rovers vs Derby County', 'win': 0.55, 'draw': 0.25, 'loss': 0.20, 'win_odds': 1.80, 'draw_odds': 4.00, 'loss_odds': 5.00},
    {'team': 'Preston North End vs Sheffield United', 'win': 0.35, 'draw': 0.30, 'loss': 0.35, 'win_odds': 2.86, 'draw_odds': 3.33, 'loss_odds': 2.86},
    {'team': 'Paysandu vs Santos', 'win': 0.40, 'draw': 0.30, 'loss': 0.30, 'win_odds': 2.50, 'draw_odds': 3.33, 'loss_odds': 3.33},
]

# Step 2: Generate all possible combinations of outcomes (win, draw, loss)
outcomes = ['win', 'draw', 'loss']
combinations = list(itertools.product(outcomes, repeat=len(matches)))

# Step 3: Calculate total probability, total odds, and expected value for each combination
results = []
for combo in combinations:
    total_prob = 1.0
    total_odds = 1.0
    for i, outcome in enumerate(combo):
        match = matches[i]
        total_prob *= match[outcome]
        total_odds *= match[f'{outcome}_odds']
    # Calculate the expected value for the combination
    expected_value = (total_prob * total_odds) - (1 - total_prob)
    results.append((combo, total_prob, total_odds, expected_value))

# Step 4: Sort the results by Total Odds (ascending), then Total Probability (descending), then Expected Value (descending)
results.sort(key=lambda x: x[2])  # Sort by Total Odds (ascending)
results.sort(key=lambda x: x[1], reverse=True)  # Sort by Total Probability (descending)
results.sort(key=lambda x: x[3], reverse=True)  # Sort by Expected Value (descending)

# Step 5: Calculate the desired proportions based on win percentages
total_combinations = len(combinations)
desired_counts = {outcome: sum(match[outcome] for match in matches) / len(matches) for outcome in outcomes}
desired_counts = {outcome: int(total_combinations * proportion) for outcome, proportion in desired_counts.items()}

# Step 6: Collect top combinations ensuring desired proportions
selected_combinations = []
outcome_counts = {outcome: 0 for outcome in outcomes}

for result in results:
    combo, prob, odds, ev = result
    temp_counts = outcome_counts.copy()
    for outcome in combo:
        temp_counts[outcome] += 1
    
    if all(temp_counts[outcome] <= desired_counts[outcome] for outcome in outcomes):
        selected_combinations.append(result)
        for outcome in combo:
            outcome_counts[outcome] += 1
    
    if all(outcome_counts[outcome] >= desired_counts[outcome] for outcome in outcomes):
        break

# Step 7: Create a DataFrame with each match in its own column, including team names and outcomes
columns = [f'Match {i+1} ({matches[i]["team"]})' for i in range(len(matches))]
columns.extend(['Total Probability', 'Total Odds', 'Expected Value'])
data = []

for combo, prob, odds, ev in selected_combinations:
    data.append(list(combo) + [prob, odds, ev])

df = pd.DataFrame(data, columns=columns)

# Step 8: Ensure the proportions are correct
outcome_counts_df = pd.DataFrame()
for column in columns[:-3]:  # Exclude 'Total Probability', 'Total Odds', and 'Expected Value'
    counts = df[column].value_counts()
    outcome_counts_df[column] = counts

# Step 9: Extend the list to match the number of rows in the DataFrame (optional step from your original code)
desired_column_values = [1.8, 2.45, 3.00, 2.38, 2.25, 1.40, 2.25]
desired_column_values *= (len(df) // len(desired_column_values)) + 1
desired_column_values = desired_column_values[:len(df)]

# Add the desired column to the DataFrame
df['Desired Column'] = desired_column_values

# Step 10: Display the sorted DataFrame
df.head(10) # Display the top 10 combinations
# Out:
#   Match 1 (Jahn Regensburg vs Ulm) Match 2 (FCSB vs FCV Farul Constanța)  \
# 0                             loss                                   win
# 1                             loss                                   win
# 2                             loss                                   win
# 3                             loss                                   win
# 4                             loss                                  loss
# 5                             loss                                  loss
# 6                             loss                                  loss
# 7                             loss                                  loss
# 8                             draw                                   win
# 9                             draw                                   win
#
#   Match 3 (Queen's Park vs Livingston) Match 4 (Ayr United vs Airdrieonians)  \
# 0                                 draw                                  loss
# 1                                 draw                                  loss
# 2                                 draw                                  loss
# 3                                 draw                                  loss
# 4                                 draw                                  loss
# 5                                 draw                                  loss
# 6                                 draw                                  loss
# 7                                 draw                                  loss
# 8                                 draw                                  loss
# 9                                 draw                                  loss
#
#   Match 5 (Blackburn Rovers vs Derby County)  \
# 0                                       draw
# 1                                       draw
# 2                                       loss
# 3                                       loss
# 4                                       draw
# 5                                       draw
# 6                                       loss
# 7                                       loss
# 8                                       draw
# 9                                       draw
#
#   Match 6 (Preston North End vs Sheffield United)  \
# 0                                             win
# 1                                            loss
# 2                                             win
# 3                                            loss
# 4                                             win
# 5                                            loss
# 6                                             win
# 7                                            loss
# 8                                             win
# 9                                            loss
#
#   Match 7 (Paysandu vs Santos)  Total Probability  Total Odds  Expected Value  \
# 0                          win           0.000383  2617.47200        0.002384
# 1                          win           0.000383  2617.47200        0.002384
# 2                          win           0.000306  3271.84000        0.002307
# 3                          win           0.000306  3271.84000        0.002307
# 4                          win           0.000153  6543.68000        0.002154
# 5                          win           0.000153  6543.68000        0.002154
# 6                          win           0.000122  8179.60000        0.002123
# 7                          win           0.000122  8179.60000        0.002123
# 8                          win           0.000459  2179.04544        0.001458
# 9                          win           0.000459  2179.04544        0.001458
#
#    Desired Column
# 0            1.80
# 1            2.45
# 2            3.00
# 3            2.38
# 4            2.25
# 5            1.40
# 6            2.25
# 7            1.80
# 8            2.45
# 9            3.00

# %%
import itertools
import pandas as pd

# Step 1: Define probabilities and odds for each match
matches = [
    {'team': 'Preston North End vs Sheffield United', 'win': 0.32, 'draw': 0.31, 'loss': 0.42, 'win_odds': 3.10, 'draw_odds': 3.20, 'loss_odds': 2.37},
    {'team': 'Jahn Regensburg vs Ulm', 'win': 0.42, 'draw': 0.29, 'loss': 0.32, 'win_odds': 2.37, 'draw_odds': 3.40, 'loss_odds': 3.10},
    {'team': 'Šibenik vs Slaven Koprivnica', 'win': 0.43, 'draw': 0.32, 'loss': 0.31, 'win_odds': 2.30, 'draw_odds': 3.10, 'loss_odds': 3.20},
    {'team': 'Sassuolo vs Cittadella', 'win': 0.60, 'draw': 0.26, 'loss': 0.20, 'win_odds': 1.67, 'draw_odds': 3.75, 'loss_odds': 5.00},
    {'team': 'Sandefjord vs Strømsgodset', 'win': 0.34, 'draw': 0.30, 'loss': 0.40, 'win_odds': 2.90, 'draw_odds': 3.30, 'loss_odds': 2.50},
    {'team': 'Eindhoven vs Den Bosch', 'win': 0.56, 'draw': 0.27, 'loss': 0.22, 'win_odds': 1.80, 'draw_odds': 3.60, 'loss_odds': 4.50},
    {'team': 'TOP Oss vs Excelsior', 'win': 0.27, 'draw': 0.29, 'loss': 0.50, 'win_odds': 3.60, 'draw_odds': 3.50, 'loss_odds': 2.00},
]

# Step 2: Generate all possible combinations of outcomes (win, draw, loss)
outcomes = ['win', 'draw', 'loss']
combinations = list(itertools.product(outcomes, repeat=len(matches)))

# Step 3: Calculate total probability, total odds, and expected value for each combination
results = []
for combo in combinations:
    total_prob = 1.0
    total_odds = 1.0
    for i, outcome in enumerate(combo):
        match = matches[i]
        total_prob *= match[outcome]
        total_odds *= match[f'{outcome}_odds']
    # Calculate the expected value for the combination
    expected_value = (total_prob * total_odds) - (1 - total_prob)
    results.append((combo, total_prob, total_odds, expected_value))

# Step 4: Sort the results by Total Odds (ascending), then Total Probability (descending), then Expected Value (descending)
results.sort(key=lambda x: x[2])  # Sort by Total Odds (ascending)
results.sort(key=lambda x: x[1], reverse=True)  # Sort by Total Probability (descending)
results.sort(key=lambda x: x[3], reverse=True)  # Sort by Expected Value (descending)

# Step 5: Calculate the desired proportions based on win percentages
total_combinations = len(combinations)
desired_counts = {outcome: sum(match[outcome] for match in matches) / len(matches) for outcome in outcomes}
desired_counts = {outcome: int(total_combinations * proportion) for outcome, proportion in desired_counts.items()}

# Step 6: Collect top combinations ensuring desired proportions
selected_combinations = []
outcome_counts = {outcome: 0 for outcome in outcomes}

for result in results:
    combo, prob, odds, ev = result
    temp_counts = outcome_counts.copy()
    for outcome in combo:
        temp_counts[outcome] += 1
    
    if all(temp_counts[outcome] <= desired_counts[outcome] for outcome in outcomes):
        selected_combinations.append(result)
        for outcome in combo:
            outcome_counts[outcome] += 1
    
    if all(outcome_counts[outcome] >= desired_counts[outcome] for outcome in outcomes):
        break

# Step 7: Create a DataFrame with each match in its own column, including team names and outcomes
columns = [f'Match {i+1} ({matches[i]["team"]})' for i in range(len(matches))]
columns.extend(['Total Probability', 'Total Odds', 'Expected Value'])
data = []

for combo, prob, odds, ev in selected_combinations:
    data.append(list(combo) + [prob, odds, ev])

df = pd.DataFrame(data, columns=columns)

# Step 8: Ensure the proportions are correct
outcome_counts_df = pd.DataFrame()
for column in columns[:-3]:  # Exclude 'Total Probability', 'Total Odds', and 'Expected Value'
    counts = df[column].value_counts()
    outcome_counts_df[column] = counts

# Step 9: Extend the list to match the number of rows in the DataFrame (optional step from your original code)
desired_column_values = [1.8, 2.45, 3.00, 2.38, 2.25, 1.40, 2.25]
desired_column_values *= (len(df) // len(desired_column_values)) + 1
desired_column_values = desired_column_values[:len(df)]

# Add the desired column to the DataFrame
df['Desired Column'] = desired_column_values

# Step 10: Display the sorted DataFrame
df.head(40)  # Display the top 10 combinations
# Out:
#    Match 1 (Preston North End vs Sheffield United)  \
# 0                                             loss
# 1                                             loss
# 2                                             loss
# 3                                             loss
# 4                                             loss
# 5                                              win
# 6                                             loss
# 7                                              win
# 8                                             loss
# 9                                             draw
# 10                                            draw
# 11                                            loss
# 12                                             win
# 13                                            loss
# 14                                            draw
# 15                                             win
# 16                                            loss
# 17                                             win
# 18                                            loss
# 19                                            draw
# 20                                            draw
# 21                                             win
# 22                                             win
# 23                                            draw
# 24                                            draw
# 25                                             win
# 26                                            loss
# 27                                            draw
# 28                                            loss
# 29                                            loss
# 30                                             win
# 31                                            draw
# 32                                            loss
# 33                                             win
# 34                                             win
# 35                                            draw
# 36                                            draw
# 37                                            loss
# 38                                            loss
# 39                                            loss
#
#    Match 2 (Jahn Regensburg vs Ulm) Match 3 (Šibenik vs Slaven Koprivnica)  \
# 0                               win                                   draw
# 1                               win                                   loss
# 2                               win                                    win
# 3                               win                                   draw
# 4                               win                                   loss
# 5                               win                                   draw
# 6                              loss                                   draw
# 7                               win                                   loss
# 8                              loss                                   loss
# 9                               win                                   draw
# 10                              win                                   loss
# 11                              win                                    win
# 12                              win                                    win
# 13                             loss                                    win
# 14                              win                                    win
# 15                              win                                   draw
# 16                             loss                                   draw
# 17                              win                                   loss
# 18                             loss                                   loss
# 19                              win                                   draw
# 20                              win                                   loss
# 21                             loss                                   draw
# 22                             loss                                   loss
# 23                             loss                                   draw
# 24                             loss                                   loss
# 25                              win                                    win
# 26                             loss                                    win
# 27                              win                                    win
# 28                             draw                                   draw
# 29                             draw                                   loss
# 30                             loss                                    win
# 31                             loss                                    win
# 32                              win                                   draw
# 33                             loss                                   draw
# 34                             loss                                   loss
# 35                             loss                                   draw
# 36                             loss                                   loss
# 37                              win                                   loss
# 38                             draw                                    win
# 39                              win                                    win
#
#    Match 4 (Sassuolo vs Cittadella) Match 5 (Sandefjord vs Strømsgodset)  \
# 0                               win                                 loss
# 1                               win                                 loss
# 2                               win                                 loss
# 3                              loss                                 loss
# 4                              loss                                 loss
# 5                               win                                 loss
# 6                               win                                 loss
# 7                               win                                 loss
# 8                               win                                 loss
# 9                               win                                 loss
# 10                              win                                 loss
# 11                             loss                                 loss
# 12                              win                                 loss
# 13                              win                                 loss
# 14                              win                                 loss
# 15                             loss                                 loss
# 16                             loss                                 loss
# 17                             loss                                 loss
# 18                             loss                                 loss
# 19                             loss                                 loss
# 20                             loss                                 loss
# 21                              win                                 loss
# 22                              win                                 loss
# 23                              win                                 loss
# 24                              win                                 loss
# 25                             loss                                 loss
# 26                             loss                                 loss
# 27                             loss                                 loss
# 28                              win                                 loss
# 29                              win                                 loss
# 30                              win                                 loss
# 31                              win                                 loss
# 32                              win                                 draw
# 33                             loss                                 loss
# 34                             loss                                 loss
# 35                             loss                                 loss
# 36                             loss                                 loss
# 37                              win                                 draw
# 38                              win                                 loss
# 39                              win                                 draw
#
#    Match 6 (Eindhoven vs Den Bosch) Match 7 (TOP Oss vs Excelsior)  \
# 0                               win                           draw
# 1                               win                           draw
# 2                               win                           draw
# 3                               win                           draw
# 4                               win                           draw
# 5                               win                           draw
# 6                               win                           draw
# 7                               win                           draw
# 8                               win                           draw
# 9                               win                           draw
# 10                              win                           draw
# 11                              win                           draw
# 12                              win                           draw
# 13                              win                           draw
# 14                              win                           draw
# 15                              win                           draw
# 16                              win                           draw
# 17                              win                           draw
# 18                              win                           draw
# 19                              win                           draw
# 20                              win                           draw
# 21                              win                           draw
# 22                              win                           draw
# 23                              win                           draw
# 24                              win                           draw
# 25                              win                           draw
# 26                              win                           draw
# 27                              win                           draw
# 28                              win                           draw
# 29                              win                           draw
# 30                              win                           draw
# 31                              win                           draw
# 32                              win                           draw
# 33                              win                           draw
# 34                              win                           draw
# 35                              win                           draw
# 36                              win                           draw
# 37                              win                           draw
# 38                              win                           draw
# 39                              win                           draw
#
#     Total Probability   Total Odds  Expected Value  Desired Column
# 0            0.002200   457.989388        0.009830            1.80
# 1            0.002131   472.763239        0.009762            2.45
# 2            0.002956   339.798578        0.007539            3.00
# 3            0.000733  1371.225713        0.006352            2.38
# 4            0.000710  1415.458800        0.006330            2.25
# 5            0.001676   599.057849        0.005865            1.40
# 6            0.001676   599.057849        0.005865            2.25
# 7            0.001624   618.382296        0.005812            1.80
# 8            0.001624   618.382296        0.005812            2.45
# 9            0.001624   618.382296        0.005812            3.00
# 10           0.001573   638.330112        0.005762            2.38
# 11           0.000985  1017.361013        0.003563            2.25
# 12           0.002253   444.462275        0.003404            1.40
# 13           0.002253   444.462275        0.003404            2.25
# 14           0.002182   458.799768        0.003334            1.80
# 15           0.000559  1793.586375        0.002743            2.45
# 16           0.000559  1793.586375        0.002743            3.00
# 17           0.000541  1851.444000        0.002726            2.38
# 18           0.000541  1851.444000        0.002726            2.25
# 19           0.000541  1851.444000        0.002726            1.40
# 20           0.000524  1911.168000        0.002709            2.25
# 21           0.001277   783.577778        0.002036            1.80
# 22           0.001237   808.854480        0.001996            2.45
# 23           0.001237   808.854480        0.001996            3.00
# 24           0.001199   834.946560        0.001957            2.38
# 25           0.000751  1330.725375       -0.000096            2.25
# 26           0.000751  1330.725375       -0.000096            1.40
# 27           0.000727  1373.652000       -0.000119            2.25
# 28           0.001519   657.031189       -0.000366            1.80
# 29           0.001472   678.225744       -0.000413            2.45
# 30           0.001716   581.364158       -0.000552            3.00
# 31           0.001663   600.117840       -0.000605            2.38
# 32           0.001650   604.545992       -0.000796            2.25
# 33           0.000426  2346.041250       -0.000813            1.40
# 34           0.000412  2421.720000       -0.000827            2.25
# 35           0.000412  2421.720000       -0.000827            1.80
# 36           0.000400  2499.840000       -0.000839            2.45
# 37           0.001599   624.047476       -0.000847            3.00
# 38           0.002041   487.474753       -0.002862            2.38
# 39           0.002217   448.534123       -0.003245            2.25

# %%
import itertools
import pandas as pd

# Step 1: Define probabilities and odds for each match
matches = [
    {'team': 'Midtjylland vs Vejle', 'win': 0.65, 'draw': 0.27, 'loss': 0.20, 'win_odds': 11/20, 'draw_odds': 3.75, 'loss_odds': 5.00},
    {'team': 'Sandefjord vs Strømsgodset', 'win': 0.34, 'draw': 0.30, 'loss': 0.36, 'win_odds': 2.90, 'draw_odds': 3.30, 'loss_odds': 7/4},
    {'team': 'FCSB vs FCV Farul Constanța', 'win': 0.47, 'draw': 0.29, 'loss': 0.29, 'win_odds': 2.10, 'draw_odds': 5/2, 'loss_odds': 3.50},
    {'team': 'Galatasaray vs Hatayspor', 'win': 0.83, 'draw': 0.18, 'loss': 0.11, 'win_odds': 1.20, 'draw_odds': 5.50, 'loss_odds': 17/2},
    {'team': 'Groningen vs NAC Breda', 'win': 0.62, 'draw': 0.26, 'loss': 0.20, 'win_odds': 8/13, 'draw_odds': 3.80, 'loss_odds': 5.00},
    {'team': 'Emmen vs Dordrecht', 'win': 0.44, 'draw': 0.29, 'loss': 0.28, 'win_odds': 5/4, 'draw_odds': 3.40, 'loss_odds': 3.60},
    {'team': 'Eindhoven vs Den Bosch', 'win': 0.53, 'draw': 0.29, 'loss': 0.22, 'win_odds': 9/10, 'draw_odds': 3.50, 'loss_odds': 4.50},
]

# Step 2: Convert fractional odds to decimal
for match in matches:
    for key in ['win_odds', 'loss_odds']:
        match[key] = match[key] if isinstance(match[key], float) else eval(f"{match[key].numerator}/{match[key].denominator}")

# Step 3: Generate all possible combinations of outcomes (win, draw, loss)
outcomes = ['win', 'draw', 'loss']
combinations = list(itertools.product(outcomes, repeat=len(matches)))

# Step 4: Calculate total probability, total odds, and expected value for each combination
results = []
for combo in combinations:
    total_prob = 1.0
    total_odds = 1.0
    for i, outcome in enumerate(combo):
        match = matches[i]
        total_prob *= match[outcome]
        total_odds *= match[f'{outcome}_odds']
    # Calculate the expected value for the combination
    expected_value = (total_prob * total_odds) - (1 - total_prob)
    results.append((combo, total_prob, total_odds, expected_value))

# Step 5: Sort the results by Total Odds (ascending), then Total Probability (descending), then Expected Value (descending)
results.sort(key=lambda x: x[2])  # Sort by Total Odds (ascending)
results.sort(key=lambda x: x[1], reverse=True)  # Sort by Total Probability (descending)
results.sort(key=lambda x: x[3], reverse=True)  # Sort by Expected Value (descending)

# Step 6: Calculate the desired proportions based on win percentages
total_combinations = len(combinations)
desired_counts = {outcome: sum(match[outcome] for match in matches) / len(matches) for outcome in outcomes}
desired_counts = {outcome: int(total_combinations * proportion) for outcome, proportion in desired_counts.items()}

# Step 7: Collect top combinations ensuring desired proportions
selected_combinations = []
outcome_counts = {outcome: 0 for outcome in outcomes}

for result in results:
    combo, prob, odds, ev = result
    temp_counts = outcome_counts.copy()
    for outcome in combo:
        temp_counts[outcome] += 1
    
    if all(temp_counts[outcome] <= desired_counts[outcome] for outcome in outcomes):
        selected_combinations.append(result)
        for outcome in combo:
            outcome_counts[outcome] += 1
    
    if all(outcome_counts[outcome] >= desired_counts[outcome] for outcome in outcomes):
        break

# Step 8: Create a DataFrame with each match in its own column, including team names and outcomes
columns = [f'Match {i+1} ({matches[i]["team"]})' for i in range(len(matches))]
columns.extend(['Total Probability', 'Total Odds', 'Expected Value'])
data = []

for combo, prob, odds, ev in selected_combinations:
    data.append(list(combo) + [prob, odds, ev])

df = pd.DataFrame(data, columns=columns)

# Step 9: Ensure the proportions are correct
outcome_counts_df = pd.DataFrame()
for column in columns[:-3]:  # Exclude 'Total Probability', 'Total Odds', and 'Expected Value'
    counts = df[column].value_counts()
    outcome_counts_df[column] = counts

# Step 10: Display the sorted DataFrame
df.head(10)  # Display the top 10 combinations
# Out:
#   Match 1 (Midtjylland vs Vejle) Match 2 (Sandefjord vs Strømsgodset)  \
# 0                           draw                                 draw
# 1                           draw                                  win
# 2                           draw                                 draw
# 3                           draw                                  win
# 4                           draw                                 draw
# 5                           loss                                 draw
# 6                           draw                                  win
# 7                           loss                                  win
# 8                           draw                                 draw
# 9                           loss                                 draw
#
#   Match 3 (FCSB vs FCV Farul Constanța) Match 4 (Galatasaray vs Hatayspor)  \
# 0                                  loss                                win
# 1                                  loss                                win
# 2                                  loss                               draw
# 3                                  loss                               draw
# 4                                  loss                                win
# 5                                  loss                                win
# 6                                  loss                                win
# 7                                  loss                                win
# 8                                  loss                               draw
# 9                                  loss                               draw
#
#   Match 5 (Groningen vs NAC Breda) Match 6 (Emmen vs Dordrecht)  \
# 0                             loss                         loss
# 1                             loss                         loss
# 2                             loss                         loss
# 3                             loss                         loss
# 4                             draw                         loss
# 5                             loss                         loss
# 6                             draw                         loss
# 7                             loss                         loss
# 8                             draw                         loss
# 9                             loss                         loss
#
#   Match 7 (Eindhoven vs Den Bosch)  Total Probability   Total Odds  \
# 0                             draw           0.000317   3274.42500
# 1                             draw           0.000359   2877.52500
# 2                             draw           0.000069  15007.78125
# 3                             draw           0.000078  13188.65625
# 4                             draw           0.000412   2488.56300
# 5                             draw           0.000235   4365.90000
# 6                             draw           0.000466   2186.91900
# 7                             draw           0.000266   3836.70000
# 8                             draw           0.000089  11405.91375
# 9                             draw           0.000051  20010.37500
#
#    Expected Value
# 0        0.037086
# 1        0.032939
# 2        0.030592
# 3        0.026438
# 4        0.024740
# 5        0.024204
# 6        0.020656
# 7        0.020098
# 8        0.018247
# 9        0.017852

# %%
import itertools
import pandas as pd

# Step 1: Define probabilities and odds for each match
matches = [
    {'team': 'Midtjylland vs Vejle', 'win': 0.65, 'draw': 0.27, 'loss': 0.20, 'win_odds': 11/20, 'draw_odds': 3.75, 'loss_odds': 5.00},
    {'team': 'Sandefjord vs Strømsgodset', 'win': 0.34, 'draw': 0.30, 'loss': 0.36, 'win_odds': 2.90, 'draw_odds': 3.30, 'loss_odds': 7/4},
    {'team': 'FCSB vs FCV Farul Constanța', 'win': 0.47, 'draw': 0.29, 'loss': 0.29, 'win_odds': 2.10, 'draw_odds': 5/2, 'loss_odds': 3.50},
    {'team': 'Galatasaray vs Hatayspor', 'win': 0.83, 'draw': 0.18, 'loss': 0.11, 'win_odds': 1.20, 'draw_odds': 5.50, 'loss_odds': 17/2},
    {'team': 'Groningen vs NAC Breda', 'win': 0.62, 'draw': 0.26, 'loss': 0.20, 'win_odds': 8/13, 'draw_odds': 3.80, 'loss_odds': 5.00},
    {'team': 'Emmen vs Dordrecht', 'win': 0.44, 'draw': 0.29, 'loss': 0.28, 'win_odds': 5/4, 'draw_odds': 3.40, 'loss_odds': 3.60},
    {'team': 'Eindhoven vs Den Bosch', 'win': 0.53, 'draw': 0.29, 'loss': 0.22, 'win_odds': 9/10, 'draw_odds': 3.50, 'loss_odds': 4.50},
]

# Step 2: Convert fractional odds to decimal
for match in matches:
    for key in ['win_odds', 'loss_odds']:
        match[key] = match[key] if isinstance(match[key], float) else eval(f"{match[key].numerator}/{match[key].denominator}")

# Step 3: Generate all possible combinations of outcomes (win, draw, loss)
outcomes = ['win', 'draw', 'loss']
combinations = list(itertools.product(outcomes, repeat=len(matches)))

# Step 4: Calculate total probability, total odds, and expected value for each combination
results = []
for combo in combinations:
    total_prob = 1.0
    total_odds = 1.0
    for i, outcome in enumerate(combo):
        match = matches[i]
        total_prob *= match[outcome]
        total_odds *= match[f'{outcome}_odds']
    # Calculate the expected value for the combination
    expected_value = (total_prob * total_odds) - (1 - total_prob)
    results.append((combo, total_prob, total_odds, expected_value))

# Step 5: Sort the results by Total Odds (ascending), then Total Probability (descending), then Expected Value (descending)
# results.sort(key=lambda x: x[2])  # Sort by Total Odds (ascending)
results.sort(key=lambda x: x[1], reverse=True)  # Sort by Total Probability (descending)
# results.sort(key=lambda x: x[3], reverse=True)  # Sort by Expected Value (descending)

# Step 6: Calculate the desired proportions based on win percentages
total_combinations = len(combinations)
desired_counts = {outcome: sum(match[outcome] for match in matches) / len(matches) for outcome in outcomes}
desired_counts = {outcome: int(total_combinations * proportion) for outcome, proportion in desired_counts.items()}

# Step 7: Collect top combinations ensuring desired proportions
selected_combinations = []
outcome_counts = {outcome: 0 for outcome in outcomes}

for result in results:
    combo, prob, odds, ev = result
    temp_counts = outcome_counts.copy()
    for outcome in combo:
        temp_counts[outcome] += 1
    
    if all(temp_counts[outcome] <= desired_counts[outcome] for outcome in outcomes):
        selected_combinations.append(result)
        for outcome in combo:
            outcome_counts[outcome] += 1
    
    if all(outcome_counts[outcome] >= desired_counts[outcome] for outcome in outcomes):
        break

# Step 8: Create a DataFrame with each match in its own column, including team names and outcomes
columns = [f'Match {i+1} ({matches[i]["team"]})' for i in range(len(matches))]
columns.extend(['Total Probability', 'Total Odds', 'Expected Value'])
data = []

for combo, prob, odds, ev in selected_combinations:
    data.append(list(combo) + [prob, odds, ev])

df = pd.DataFrame(data, columns=columns)

# Step 9: Ensure the proportions are correct
outcome_counts_df = pd.DataFrame()
for column in columns[:-3]:  # Exclude 'Total Probability', 'Total Odds', and 'Expected Value'
    counts = df[column].value_counts()
    outcome_counts_df[column] = counts

# Step 10: Display the sorted DataFrame
df.head(10) # Display the top 10 combinations
# Out:
#   Match 1 (Midtjylland vs Vejle) Match 2 (Sandefjord vs Strømsgodset)  \
# 0                            win                                 loss
# 1                            win                                  win
# 2                            win                                 draw
# 3                            win                                 loss
# 4                            win                                 loss
# 5                            win                                  win
# 6                            win                                 loss
# 7                            win                                 loss
# 8                            win                                  win
# 9                            win                                  win
#
#   Match 3 (FCSB vs FCV Farul Constanța) Match 4 (Galatasaray vs Hatayspor)  \
# 0                                   win                                win
# 1                                   win                                win
# 2                                   win                                win
# 3                                   win                                win
# 4                                   win                                win
# 5                                   win                                win
# 6                                  draw                                win
# 7                                  loss                                win
# 8                                   win                                win
# 9                                  draw                                win
#
#   Match 5 (Groningen vs NAC Breda) Match 6 (Emmen vs Dordrecht)  \
# 0                              win                          win
# 1                              win                          win
# 2                              win                          win
# 3                              win                         draw
# 4                              win                         loss
# 5                              win                         draw
# 6                              win                          win
# 7                              win                          win
# 8                              win                         loss
# 9                              win                          win
#
#   Match 7 (Eindhoven vs Den Bosch)  Total Probability  Total Odds  \
# 0                              win           0.013198    1.679192
# 1                              win           0.012465    2.782662
# 2                              win           0.010998    3.166477
# 3                              win           0.008699    4.567403
# 4                              win           0.008399    4.836074
# 5                              win           0.008215    7.568839
# 6                              win           0.008144    1.999038
# 7                              win           0.008144    2.798654
# 8                              win           0.007932    8.014065
# 9                              win           0.007691    3.312692
#
#    Expected Value
# 0       -0.964640
# 1       -0.952850
# 2       -0.954175
# 3       -0.951570
# 4       -0.950984
# 5       -0.929603
# 6       -0.975577
# 7       -0.969066
# 8       -0.928499
# 9       -0.966831

# %%
import itertools
import pandas as pd

# Step 1: Define probabilities and odds for each match
matches = [
    {'team': 'FCSB vs FCV Farul Constanța', 'win': 0.47, 'draw': 0.29, 'loss': 0.29, 'win_odds': 2.10, 'draw_odds': 3.40, 'loss_odds': 3.50},
    {'team': 'Eindhoven vs Den Bosch', 'win': 0.53, 'draw': 0.29, 'loss': 0.22, 'win_odds': 9/10, 'draw_odds': 3.50, 'loss_odds': 4.50},
    {'team': 'Emmen vs Dordrecht', 'win': 0.44, 'draw': 0.29, 'loss': 0.28, 'win_odds': 5/4, 'draw_odds': 3.40, 'loss_odds': 3.60},
    {'team': 'MVV vs Cambuur', 'win': 0.30, 'draw': 0.29, 'loss': 0.47, 'win_odds': 3.30, 'draw_odds': 3.50, 'loss_odds': 2.10},
    {'team': 'Ayr United vs Airdrieonians', 'win': 0.45, 'draw': 0.29, 'loss': 0.32, 'win_odds': 2.20, 'draw_odds': 3.40, 'loss_odds': 3.10},
    {'team': 'Queen\'s Park vs Livingston', 'win': 0.36, 'draw': 0.31, 'loss': 0.40, 'win_odds': 2.75, 'draw_odds': 3.25, 'loss_odds': 2.50},
    {'team': 'Genoa vs Reggiana', 'win': 0.63, 'draw': 0.27, 'loss': 0.18, 'win_odds': 1.60, 'draw_odds': 3.75, 'loss_odds': 5.50},
]

# Step 2: Convert fractional odds to decimal
for match in matches:
    for key in ['win_odds', 'loss_odds']:
        match[key] = match[key] if isinstance(match[key], float) else eval(f"{match[key].numerator}/{match[key].denominator}")

# Step 3: Generate all possible combinations of outcomes (win, draw, loss)
outcomes = ['win', 'draw', 'loss']
combinations = list(itertools.product(outcomes, repeat=len(matches)))

# Step 4: Calculate total probability, total odds, and expected value for each combination
results = []
for combo in combinations:
    total_prob = 1.0
    total_odds = 1.0
    for i, outcome in enumerate(combo):
        match = matches[i]
        total_prob *= match[outcome]
        total_odds *= match[f'{outcome}_odds']
    # Calculate the expected value for the combination
    expected_value = (total_prob * total_odds) - (1 - total_prob)
    results.append((combo, total_prob, total_odds, expected_value))

# Step 5: Sort the results by Total Odds (ascending), then Total Probability (descending), then Expected Value (descending)
results.sort(key=lambda x: x[2])  # Sort by Total Odds (ascending)
# results.sort(key=lambda x: x[1], reverse=True)  # Sort by Total Probability (descending)
results.sort(key=lambda x: x[3], reverse=True)  # Sort by Expected Value (descending)

# Step 6: Calculate the desired proportions based on win percentages
total_combinations = len(combinations)
desired_counts = {outcome: sum(match[outcome] for match in matches) / len(matches) for outcome in outcomes}
desired_counts = {outcome: int(total_combinations * proportion) for outcome, proportion in desired_counts.items()}

# Step 7: Collect top combinations ensuring desired proportions
selected_combinations = []
outcome_counts = {outcome: 0 for outcome in outcomes}

for result in results:
    combo, prob, odds, ev = result
    temp_counts = outcome_counts.copy()
    for outcome in combo:
        temp_counts[outcome] += 1
    
    if all(temp_counts[outcome] <= desired_counts[outcome] for outcome in outcomes):
        selected_combinations.append(result)
        for outcome in combo:
            outcome_counts[outcome] += 1
    
    if all(outcome_counts[outcome] >= desired_counts[outcome] for outcome in outcomes):
        break

# Step 8: Create a DataFrame with each match in its own column, including team names and outcomes
columns = [f'Match {i+1} ({matches[i]["team"]})' for i in range(len(matches))]
columns.extend(['Total Probability', 'Total Odds', 'Expected Value'])
data = []

for combo, prob, odds, ev in selected_combinations:
    data.append(list(combo) + [prob, odds, ev])

df = pd.DataFrame(data, columns=columns)

# Step 9: Ensure the proportions are correct
outcome_counts_df = pd.DataFrame()
for column in columns[:-3]:  # Exclude 'Total Probability', 'Total Odds', and 'Expected Value'
    counts = df[column].value_counts()
    outcome_counts_df[column] = counts

# Step 10: Display the sorted DataFrame
df.head(60)  # Display the top 10 combinations
# Out:
#    Match 1 (FCSB vs FCV Farul Constanța) Match 2 (Eindhoven vs Den Bosch)  \
# 0                                   loss                             draw
# 1                                   loss                             draw
# 2                                   loss                             draw
# 3                                   loss                             draw
# 4                                   loss                             draw
# 5                                   loss                             draw
# 6                                   loss                             draw
# 7                                   loss                             draw
# 8                                   loss                             draw
# 9                                   loss                             draw
# 10                                  loss                             draw
# 11                                  loss                             draw
# 12                                  loss                             draw
# 13                                  loss                             draw
# 14                                  loss                             draw
# 15                                  loss                             draw
# 16                                  loss                             draw
# 17                                  loss                             draw
# 18                                  loss                             draw
# 19                                  loss                             draw
# 20                                  loss                             draw
# 21                                  loss                             draw
# 22                                  loss                             loss
# 23                                  loss                             draw
# 24                                  loss                             draw
# 25                                  loss                             loss
# 26                                  loss                             draw
# 27                                   win                             draw
# 28                                  loss                             draw
# 29                                  loss                             draw
# 30                                  loss                             draw
# 31                                  loss                             draw
# 32                                  draw                             draw
# 33                                  loss                             draw
# 34                                  loss                             loss
# 35                                  loss                             draw
# 36                                  loss                             draw
# 37                                   win                             draw
# 38                                  loss                             draw
# 39                                  draw                             draw
# 40                                  loss                             draw
# 41                                  loss                             draw
# 42                                  loss                             loss
# 43                                  loss                             loss
# 44                                  loss                             draw
# 45                                  loss                             draw
# 46                                  loss                             draw
# 47                                   win                             draw
# 48                                  loss                             draw
# 49                                  loss                             draw
# 50                                  loss                             loss
# 51                                  draw                             draw
# 52                                  loss                             draw
# 53                                   win                             draw
# 54                                  loss                             draw
# 55                                  loss                             draw
# 56                                   win                             draw
# 57                                  loss                             draw
# 58                                  loss                             loss
# 59                                  draw                             draw
#
#    Match 3 (Emmen vs Dordrecht) Match 4 (MVV vs Cambuur)  \
# 0                          loss                     draw
# 1                          loss                     draw
# 2                          loss                     draw
# 3                          loss                     draw
# 4                          loss                     draw
# 5                          loss                     draw
# 6                          loss                     draw
# 7                          loss                     draw
# 8                          loss                     draw
# 9                          loss                     draw
# 10                         loss                     draw
# 11                         loss                     draw
# 12                         loss                     draw
# 13                         loss                     draw
# 14                         loss                     draw
# 15                         draw                     draw
# 16                         loss                     draw
# 17                         loss                     draw
# 18                         loss                     draw
# 19                         draw                     draw
# 20                         loss                     draw
# 21                         loss                      win
# 22                         loss                     draw
# 23                         draw                     draw
# 24                         loss                      win
# 25                         loss                     draw
# 26                         loss                     draw
# 27                         loss                     draw
# 28                         loss                     loss
# 29                         draw                     draw
# 30                         draw                     draw
# 31                         loss                     draw
# 32                         loss                     draw
# 33                         loss                      win
# 34                         loss                     draw
# 35                         draw                     draw
# 36                         loss                     loss
# 37                         loss                     draw
# 38                         loss                     draw
# 39                         loss                     draw
# 40                         loss                      win
# 41                         loss                      win
# 42                         loss                     draw
# 43                         loss                     draw
# 44                         draw                     draw
# 45                         loss                     draw
# 46                         loss                     loss
# 47                         loss                     draw
# 48                         loss                      win
# 49                         draw                     draw
# 50                         loss                     draw
# 51                         loss                     draw
# 52                         draw                     draw
# 53                         loss                     draw
# 54                         loss                     loss
# 55                         loss                     loss
# 56                         loss                     draw
# 57                         loss                      win
# 58                         loss                     draw
# 59                         loss                     draw
#
#    Match 5 (Ayr United vs Airdrieonians) Match 6 (Queen's Park vs Livingston)  \
# 0                                   loss                                 draw
# 1                                    win                                 draw
# 2                                   loss                                 draw
# 3                                    win                                 draw
# 4                                   draw                                 draw
# 5                                   loss                                 loss
# 6                                    win                                 loss
# 7                                   draw                                 draw
# 8                                   loss                                 loss
# 9                                    win                                 loss
# 10                                  draw                                 loss
# 11                                  loss                                  win
# 12                                  draw                                 loss
# 13                                   win                                  win
# 14                                  loss                                  win
# 15                                  loss                                 draw
# 16                                  loss                                 draw
# 17                                   win                                  win
# 18                                  draw                                  win
# 19                                   win                                 draw
# 20                                   win                                 draw
# 21                                  loss                                 draw
# 22                                  loss                                 draw
# 23                                  loss                                 draw
# 24                                   win                                 draw
# 25                                   win                                 draw
# 26                                  draw                                  win
# 27                                  loss                                 draw
# 28                                  loss                                 draw
# 29                                   win                                 draw
# 30                                  draw                                 draw
# 31                                  draw                                 draw
# 32                                  loss                                 draw
# 33                                  loss                                 draw
# 34                                  loss                                 draw
# 35                                  loss                                 loss
# 36                                   win                                 draw
# 37                                   win                                 draw
# 38                                  loss                                 loss
# 39                                   win                                 draw
# 40                                   win                                 draw
# 41                                  draw                                 draw
# 42                                  draw                                 draw
# 43                                   win                                 draw
# 44                                   win                                 loss
# 45                                   win                                 loss
# 46                                  loss                                 draw
# 47                                  loss                                 draw
# 48                                  loss                                 loss
# 49                                  draw                                 draw
# 50                                  loss                                 loss
# 51                                  loss                                 draw
# 52                                  loss                                 loss
# 53                                   win                                 draw
# 54                                   win                                 draw
# 55                                  draw                                 draw
# 56                                  draw                                 draw
# 57                                   win                                 loss
# 58                                   win                                 loss
# 59                                   win                                 draw
#
#    Match 7 (Genoa vs Reggiana)  Total Probability   Total Odds  Expected Value
# 0                         draw           0.000183  5831.535938        0.066805
# 1                         draw           0.000257  4138.509375        0.064728
# 2                          win           0.000427  2488.122000        0.062308
# 3                          win           0.000600  1765.764000        0.060340
# 4                         draw           0.000166  6395.878125        0.060336
# 5                         draw           0.000236  4485.796875        0.058918
# 6                         draw           0.000332  3183.468750        0.056879
# 7                          win           0.000387  2728.908000        0.055845
# 8                          win           0.000551  1913.940000        0.054527
# 9                          win           0.000774  1358.280000        0.052626
# 10                        draw           0.000214  4919.906250        0.052492
# 11                        draw           0.000212  4934.376562        0.048307
# 12                         win           0.000499  2099.160000        0.048101
# 13                        draw           0.000299  3501.815625        0.046280
# 14                         win           0.000496  2105.334000        0.043932
# 15                        draw           0.000189  5507.561719        0.043532
# 16                        loss           0.000122  8552.919375        0.043041
# 17                         win           0.000697  1494.108000        0.042030
# 18                        draw           0.000192  5411.896875        0.041948
# 19                        draw           0.000266  3908.592188        0.041505
# 20                        loss           0.000171  6069.813750        0.040988
# 21                        draw           0.000189  5498.305313        0.040539
# 22                        draw           0.000139  7497.689063        0.040489
# 23                         win           0.000442  2349.893000        0.039147
# 24                        draw           0.000266  3902.023125        0.038519
# 25                        draw           0.000195  5320.940625        0.038448
# 26                         win           0.000449  2309.076000        0.037575
# 27                        draw           0.000296  3498.921563        0.037494
# 28                        draw           0.000296  3498.921563        0.037494
# 29                         win           0.000622  1667.666000        0.037233
# 30                        draw           0.000172  6040.551562        0.037203
# 31                        loss           0.000111  9380.621250        0.036722
# 32                        draw           0.000183  5664.920625        0.036330
# 33                         win           0.000441  2345.943600        0.036168
# 34                         win           0.000324  3199.014000        0.036050
# 35                        draw           0.000244  4236.585938        0.035820
# 36                        draw           0.000417  2483.105625        0.035523
# 37                        draw           0.000417  2483.105625        0.035523
# 38                        loss           0.000157  6579.168750        0.035313
# 39                        draw           0.000257  4020.266250        0.034315
# 40                         win           0.000621  1664.863200        0.034259
# 41                        draw           0.000171  6030.399375        0.034229
# 42                        draw           0.000126  8223.271875        0.034184
# 43                         win           0.000455  2270.268000        0.034094
# 44                        draw           0.000344  3006.609375        0.033831
# 45                        loss           0.000221  4669.087500        0.033290
# 46                         win           0.000692  1492.873200        0.033280
# 47                         win           0.000692  1492.873200        0.033280
# 48                        draw           0.000244  4229.465625        0.032850
# 49                         win           0.000401  2577.302000        0.032823
# 50                        draw           0.000179  5767.453125        0.032785
# 51                         win           0.000427  2417.032800        0.031968
# 52                         win           0.000570  1807.610000        0.031543
# 53                         win           0.000973  1059.458400        0.031479
# 54                         win           0.000973  1059.458400        0.031479
# 55                        draw           0.000269  3837.526875        0.031193
# 56                        draw           0.000269  3837.526875        0.031193
# 57                        draw           0.000343  3001.556250        0.030867
# 58                        draw           0.000252  4093.031250        0.030776
# 59                         win           0.000600  1715.313600        0.030062

# %%
import itertools
import pandas as pd

# Step 1: Define probabilities and odds for each match
matches = [
    {'team': 'FCSB vs FCV Farul Constanța', 'win': 0.47, 'draw': 0.29, 'loss': 0.29, 'win_odds': 2.10, 'draw_odds': 3.40, 'loss_odds': 3.50},
    {'team': 'Eindhoven vs Den Bosch', 'win': 0.53, 'draw': 0.29, 'loss': 0.22, 'win_odds': 9/10, 'draw_odds': 3.50, 'loss_odds': 4.50},
    {'team': 'Emmen vs Dordrecht', 'win': 0.44, 'draw': 0.29, 'loss': 0.28, 'win_odds': 5/4, 'draw_odds': 3.40, 'loss_odds': 3.60},
    {'team': 'MVV vs Cambuur', 'win': 0.30, 'draw': 0.29, 'loss': 0.47, 'win_odds': 3.30, 'draw_odds': 3.50, 'loss_odds': 2.10},
    {'team': 'Ayr United vs Airdrieonians', 'win': 0.45, 'draw': 0.29, 'loss': 0.32, 'win_odds': 2.20, 'draw_odds': 3.40, 'loss_odds': 3.10},
    {'team': 'Queen\'s Park vs Livingston', 'win': 0.36, 'draw': 0.31, 'loss': 0.40, 'win_odds': 2.75, 'draw_odds': 3.25, 'loss_odds': 2.50},
    {'team': 'Genoa vs Reggiana', 'win': 0.63, 'draw': 0.27, 'loss': 0.18, 'win_odds': 1.60, 'draw_odds': 3.75, 'loss_odds': 5.50},
]

# Step 2: Convert fractional odds to decimal
for match in matches:
    for key in ['win_odds', 'loss_odds']:
        match[key] = match[key] if isinstance(match[key], float) else eval(f"{match[key].numerator}/{match[key].denominator}")

# Step 3: Generate all possible combinations of outcomes (win, draw, loss)
outcomes = ['win', 'draw', 'loss']
combinations = list(itertools.product(outcomes, repeat=len(matches)))

# Step 4: Calculate total probability, total odds, and expected value for each combination
results = []
for combo in combinations:
    total_prob = 1.0
    total_odds = 1.0
    for i, outcome in enumerate(combo):
        match = matches[i]
        total_prob *= match[outcome]
        total_odds *= match[f'{outcome}_odds']
    # Calculate the expected value for the combination
    expected_value = (total_prob * total_odds) - (1 - total_prob)
    results.append((combo, total_prob, total_odds, expected_value))

# Step 5: Sort the results by Total Odds (ascending), then Total Probability (descending), then Expected Value (descending)
# # Sort by Total Odds (ascending)
results.sort(key=lambda x: x[1], reverse=True)  # Sort by Total Probability (descending)
# results.sort(key=lambda x: x[3], reverse=True)  # Sort by Expected Value (descending)

# Step 6: Calculate the desired proportions based on win percentages
total_combinations = len(combinations)
desired_counts = {outcome: sum(match[outcome] for match in matches) / len(matches) for outcome in outcomes}
desired_counts = {outcome: int(total_combinations * proportion) for outcome, proportion in desired_counts.items()}

# Step 7: Collect top combinations ensuring desired proportions
selected_combinations = []
outcome_counts = {outcome: 0 for outcome in outcomes}

for result in results:
    combo, prob, odds, ev = result
    temp_counts = outcome_counts.copy()
    for outcome in combo:
        temp_counts[outcome] += 1
    
    if all(temp_counts[outcome] <= desired_counts[outcome] for outcome in outcomes):
        selected_combinations.append(result)
        for outcome in combo:
            outcome_counts[outcome] += 1
    
    if all(outcome_counts[outcome] >= desired_counts[outcome] for outcome in outcomes):
        break

# Step 8: Create a DataFrame with each match in its own column, including team names and outcomes
columns = [f'Match {i+1} ({matches[i]["team"]})' for i in range(len(matches))]
columns.extend(['Total Probability', 'Total Odds', 'Expected Value'])
data = []

for combo, prob, odds, ev in selected_combinations:
    data.append(list(combo) + [prob, odds, ev])

df = pd.DataFrame(data, columns=columns)

# Step 9: Ensure the proportions are correct
outcome_counts_df = pd.DataFrame()
for column in columns[:-3]:  # Exclude 'Total Probability', 'Total Odds', and 'Expected Value'
    counts = df[column].value_counts()
    outcome_counts_df[column] = counts

# Step 10: Display the sorted DataFrame
df.head(10)  # Display the top 10 combinations
# Out:
#   Match 1 (FCSB vs FCV Farul Constanța) Match 2 (Eindhoven vs Den Bosch)  \
# 0                                   win                              win
# 1                                   win                              win
# 2                                   win                              win
# 3                                   win                              win
# 4                                   win                              win
# 5                                   win                              win
# 6                                   win                              win
# 7                                   win                              win
# 8                                   win                              win
# 9                                  draw                              win
#
#   Match 3 (Emmen vs Dordrecht) Match 4 (MVV vs Cambuur)  \
# 0                          win                     loss
# 1                          win                     loss
# 2                          win                     loss
# 3                          win                     loss
# 4                         draw                     loss
# 5                          win                     loss
# 6                          win                     loss
# 7                          win                      win
# 8                         loss                     loss
# 9                          win                     loss
#
#   Match 5 (Ayr United vs Airdrieonians) Match 6 (Queen's Park vs Livingston)  \
# 0                                   win                                 loss
# 1                                   win                                  win
# 2                                   win                                 draw
# 3                                  loss                                 loss
# 4                                   win                                 loss
# 5                                  draw                                 loss
# 6                                  loss                                  win
# 7                                   win                                 loss
# 8                                   win                                 loss
# 9                                   win                                 loss
#
#   Match 7 (Genoa vs Reggiana)  Total Probability  Total Odds  Expected Value
# 0                         win           0.005842    43.65900       -0.739117
# 1                         win           0.005258    48.02490       -0.742251
# 2                         win           0.004527    56.75670       -0.738518
# 3                         win           0.004154    61.51950       -0.740289
# 4                         win           0.003850   118.75248       -0.538930
# 5                         win           0.003765    67.47300       -0.742224
# 6                         win           0.003739    67.67145       -0.743260
# 7                         win           0.003729    68.60700       -0.740454
# 8                         win           0.003717   125.73792       -0.528861
# 9                         win           0.003604    70.68600       -0.741612
